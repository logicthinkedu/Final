# %%
import pandas as pd
from collections import Counter
import spacy,re,json
from spacy.gold import GoldParse
from spacy.scorer import Scorer
from spacy import displacy  

from sklearn.metrics import classification_report
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import accuracy_score

import re
from pprint import pprint
import os
import warnings
warnings.filterwarnings('ignore')

from __future__ import unicode_literals, print_function
import plac
import random
from pathlib import Path
import spacy
from spacy.util import minibatch, compounding

# %% [markdown]
# # ============================================================
# ## 基于 Spacy 的 NER 模型

# %%
PATH ='data/file_ner.json1'

annotated_data = []
lines=[]
with open(PATH, 'r',encoding = 'utf-8 sig') as f:
    lines = f.readlines()

for line in lines:
    data = json.loads(line)
    text = data['text']
    entities = []
    for label in data['labels']:
        entities.append(label)
    annotated_data.append((text, {"entities": data['labels']}))

# %%
training_data=  annotated_data[0:200]
test_data = annotated_data[200:220]

# %%
print(len(training_data), len(test_data))
# Out:
# 200 20

# %%
training_data[0]
# Out:
# ('"Abhishek Jha Application Development Associate - Accenture  Bengaluru, Karnataka - Email me on Indeed: indeed.com/r/Abhishek-Jha/10e7a8cb732bc43a  • To work for an organization which provides me the opportunity to improve my skills and knowledge for my individual and company\'s growth in best possible ways.  Willing to relocate to: Bangalore, Karnataka  WORK EXPERIENCE  Application Development Associate  Accenture -  November 2017 to Present  Role: Currently working on Chat-bot. Developing Backend Oracle PeopleSoft Queries for the Bot which will be triggered based on given input. Also, Training the bot for different possible utterances (Both positive and negative), which will be given as input by the user.  EDUCATION  B.E in Information science and engineering  B.v.b college of engineering and technology -  Hubli, Karnataka  August 2013 to June 2017  12th in Mathematics  Woodbine modern school  April 2011 to March 2013  10th  Kendriya Vidyalaya  April 2001 to March 2011  SKILLS  C (Less than 1 year), Database (Less than 1 year), Database Management (Less than 1 year), Database Management System (Less than 1 year), Java (Less than 1 year)  ADDITIONAL INFORMATION  Technical Skills  https://www.indeed.com/r/Abhishek-Jha/10e7a8cb732bc43a?isid=rex-download&ikw=download-top&co=IN   • Programming language: C, C++, Java • Oracle PeopleSoft • Internet Of Things • Machine Learning • Database Management System • Computer Networks • Operating System worked on: Linux, Windows, Mac  Non - Technical Skills  • Honest and Hard-Working • Tolerant and Flexible to Different Situations • Polite and Calm • Team-Player"',
#  {'entities': [[994, 995, 'Skills'],
#    [1016, 1024, 'Skills'],
#    [1045, 1064, 'Skills'],
#    [1085, 1111, 'Skills'],
#    [1132, 1136, 'Skills'],
#    [1321, 1322, 'Skills'],
#    [1324, 1327, 'Skills'],
#    [1329, 1333, 'Skills'],
#    [1335, 1353, 'Skills'],
#    [1356, 1374, 'Skills'],
#    [1376, 1393, 'Skills'],
#    [1396, 1422, 'Skills'],
#    [1425, 1442, 'Skills'],
#    [1473, 1478, 'Skills'],
#    [1480, 1487, 'Skills'],
#    [1489, 1492, 'Skills'],
#    [1612, 1623, 'Skills']]})

# %%
def main(model=None, output_dir=None, n_iter=100):
    """Load the model, set up the pipeline and train the entity recognizer."""
    if model is not None:
        nlp = spacy.load(model)  # load existing spaCy model
        print("Loaded model '%s'" % model)
    else:
        nlp = spacy.blank("en")  # create blank Language class
        print("Created blank 'en' model")

    # create the built-in pipeline components and add them to the pipeline
    # nlp.create_pipe works for built-ins that are registered with spaCy
    if "ner" not in nlp.pipe_names:
        ner = nlp.create_pipe("ner")
        nlp.add_pipe(ner, last=True)
    # otherwise, get it so we can add labels
    else:
        ner = nlp.get_pipe("ner")

    # add labels
    for _, annotations in training_data:
        for ent in annotations.get("entities"):
            ner.add_label(ent[2])

    # get names of other pipes to disable them during training
    other_pipes = [pipe for pipe in nlp.pipe_names if pipe != "ner"]
    with nlp.disable_pipes(*other_pipes):  # only train NER
        # reset and initialize the weights randomly – but only if we're
        # training a new model
        if model is None:
            nlp.begin_training()
        for itn in range(n_iter):
            random.shuffle(training_data)
            losses = {}
            # batch up the examples using spaCy's minibatch
            batches = minibatch(training_data, size=compounding(4.0, 32.0, 1.001))
            for batch in batches:
                texts, annotations = zip(*batch)
                nlp.update(
                    texts,  # batch of texts
                    annotations,  # batch of annotations
                    drop=0.5,  # dropout - make it harder to memorise data
                    losses=losses,
                )
            print("Losses", losses)

    # test the trained model
    for text, _ in training_data:
        doc = nlp(text)
#         print("Entities", [(ent.text, ent.label_) for ent in doc.ents])
#         print("Tokens", [(t.text, t.ent_type_, t.ent_iob) for t in doc])

    # save model to output directory
    if output_dir is not None:
        output_dir = Path(output_dir)
        if not output_dir.exists():
            output_dir.mkdir()
        nlp.to_disk(output_dir)
        print("Saved model to", output_dir)

        # test the saved model
        print("Loading from", output_dir)
        nlp2 = spacy.load(output_dir)
        for text, _ in training_data:
            doc = nlp2(text)
#             print("Entities", [(ent.text, ent.label_) for ent in doc.ents])
#             print("Tokens", [(t.text, t.ent_type_, t.ent_iob) for t in doc])

# trained this model with 100 iterations in google colab using GPU runtime with loss: Losses {'ner': 465.24571515528373} 
main(output_dir='ner_model/')
# Out:
# Created blank 'en' model
# Losses {'ner': 16889.961593902088}
# Losses {'ner': 2697.5885606127285}
# Losses {'ner': 2744.089724993466}
# Losses {'ner': 2825.1706454027}
# Losses {'ner': 2487.06796729747}
# Losses {'ner': 2293.7671482911956}
# Losses {'ner': 2414.592029980423}
# Losses {'ner': 2079.5062248590334}
# Losses {'ner': 2140.9136387828835}
# Losses {'ner': 2115.5998387992677}
# Losses {'ner': 2140.5686549975217}
# Losses {'ner': 1773.3107981665094}
# Losses {'ner': 1749.3125200521604}
# Losses {'ner': 1783.7525714743247}
# Losses {'ner': 1749.503419123001}
# Losses {'ner': 1792.6353750283993}
# Losses {'ner': 1580.5342176150768}
# Losses {'ner': 1474.0500409663866}
# Losses {'ner': 1522.7503911667266}
# Losses {'ner': 1523.5194834165798}
# Losses {'ner': 1464.960874043458}
# Losses {'ner': 1388.104255991477}
# Losses {'ner': 1335.1260102155413}
# Losses {'ner': 1285.2708202728818}
# Losses {'ner': 1266.5353707549868}
# Losses {'ner': 1189.9840920108427}
# Losses {'ner': 1132.8286302185863}
# Losses {'ner': 1375.8248131792627}
# Losses {'ner': 1225.1096939132572}
# Losses {'ner': 1115.0166914542656}
# Losses {'ner': 1110.5900961058305}
# Losses {'ner': 1065.0372265800897}
# Losses {'ner': 1402.9082682347687}
# Losses {'ner': 1178.767328031175}
# Losses {'ner': 978.3528616138187}
# Losses {'ner': 996.0411495660171}
# Losses {'ner': 962.0909269721321}
# Losses {'ner': 987.4335628036797}
# Losses {'ner': 1003.5752356744273}
# Losses {'ner': 860.7937507407004}
# Losses {'ner': 993.578515284266}
# Losses {'ner': 954.3732591990236}
# Losses {'ner': 978.5874632946807}
# Losses {'ner': 926.4017999526548}
# Losses {'ner': 822.2015688974358}
# Losses {'ner': 922.9567733306336}
# Losses {'ner': 783.3110555320478}
# Losses {'ner': 801.5382428720658}
# Losses {'ner': 837.6203101805263}
# Losses {'ner': 816.9299454138044}
# Losses {'ner': 791.1156060413732}
# Losses {'ner': 830.2521700771698}
# Losses {'ner': 801.0770005667159}
# Losses {'ner': 746.8691632037404}
# Losses {'ner': 770.9427416143492}
# Losses {'ner': 784.7162913954234}
# Losses {'ner': 838.3209785424418}
# Losses {'ner': 797.8173818711832}
# Losses {'ner': 734.2136215648179}
# Losses {'ner': 671.7584413888873}
# Losses {'ner': 717.9167022847715}
# Losses {'ner': 653.2177064767275}
# Losses {'ner': 626.5924261538568}
# Losses {'ner': 584.1665078107211}
# Losses {'ner': 670.8216214113966}
# Losses {'ner': 753.3676962359968}
# Losses {'ner': 537.4473707174102}
# Losses {'ner': 582.0408162427813}
# Losses {'ner': 617.7092085020957}
# Losses {'ner': 623.4537241378291}
# Losses {'ner': 600.0451921625213}
# Losses {'ner': 629.9155933060651}
# Losses {'ner': 663.552412184682}
# Losses {'ner': 650.0777729646177}
# Losses {'ner': 662.2643104158865}
# Losses {'ner': 559.4624364131555}
# Losses {'ner': 455.76577329216633}
# Losses {'ner': 545.401549242156}
# Losses {'ner': 523.4322043183535}
# Losses {'ner': 551.3993961749134}
# Losses {'ner': 578.9013489406758}
# Losses {'ner': 545.1270927279029}
# Losses {'ner': 566.794497478174}
# Losses {'ner': 531.7843828281048}
# Losses {'ner': 472.7029043499579}
# Losses {'ner': 553.1409745115434}
# Losses {'ner': 547.3601177507906}
# Losses {'ner': 476.6035128666951}
# Losses {'ner': 439.08667831985537}
# Losses {'ner': 502.57618491097924}
# Losses {'ner': 472.16854653422644}
# Losses {'ner': 510.97085534257104}
# Losses {'ner': 499.0029820821942}
# Losses {'ner': 521.4192971610532}
# Losses {'ner': 507.207399003491}
# Losses {'ner': 517.1278039700381}
# Losses {'ner': 466.22150770557766}
# Losses {'ner': 552.1592378028373}
# Losses {'ner': 439.8095515070671}
# Losses {'ner': 439.0994020618054}
# Saved model to ner_model
# Loading from ner_model

# %% [markdown]
# # ==========================================================
# ## 导入 NER 模型，识别 JD 中的所有技能类关键词

# %%
ner_model = spacy.load('ner_model/')

# %%
skill_set = {}
link_set = {}

# %%
ind = 0

for root,dirs,files in os.walk(r"E:\dataset\dataset"):
    for file in files:
        ind += 1
        
        try:
            #获取文件路径
            my_file = open( os.path.join(root,file),encoding = 'utf-8' )
            my_string = my_file.readlines()

            for string in my_string[1:]:
                doc = ner_model( string )

                temp_list = []
                for chunk in doc.ents:
                    temp_list.append( chunk.text )
                    
                temp_set = set( temp_list )
                
                for tem in list(temp_set):
                    if tem not in skill_set.keys():
                        print( tem )
                        
                    if skill_set.get( tem, 0 ) == 0:
                        skill_set[tem] = 1
                    else:
                        skill_set[tem] += 1
                        
                for t1 in list(temp_set):
                    for t2 in list(temp_set):
                        if t1.text != t2.text:
                            if link_set.get( t1+'|'+t2, 0 ) == 0:
                                link_set[t1+'|'+t2] = 1
                            else:
                                link_set[t1+'|'+t2] += 1
                            

            my_file.close()
        
            if ind % 100 == 0:
                print( '------------------------------------------------------------------------',ind )
                
#             if ind > 2000:
#                 break
                
        except:
            pass
# Out:
# Machine Learning
# Python
# BlackRock
# SQL
# artificial intelligence
# R
# C++
# Map/Reduce
# Linux
# Java
# C
# SAS
# MATLAB
# PHP
# Data Pre
# data modeling
# Deep Learning
# via SQL
# software prototyping
# C ##
# Advanced knowledge
# Javascript
# C#
# Spark
# Practical experience
# Consumer experience
# TensorFlow
# Hadoop
# Data Analytics
# Adhoc analysis
# comparable NoSQL
# Monica
# ·
# Data Scientist
# PowerPoint
# Program Management Services; Testing
# Business Intelligence
# Infrastructure Support
# SAP HANA
# AWS
# Informatica
# Cloud Enablement Services
# Excel
# Redshift
# S3
# recruitment
# Athena
# Kinesis My
# SPSS
# Tensorflow
# feature engineering
# Matlab
# Microsoft Office
# problem-solving
# predictive
# Oracle
# non-parametric statistical
# MS Windows
# Visualization
# Data engineering
# Problem Solving
# Unit testing
# predictive analytics
# NoSQL 11
# Perl
# Analytics Experience
# Predictive
# ETL
# Context
# NoSQL
# Tennessee 38116
# machine learning
# Advanced SQL
# Data/Advanced Analytics
# Data Visualization
# Artificial Intelligence
# Data Platform
# Florida
# GitHub
# predictive modeling
# BigQuery
# Data Mining
# field
# PyTorch
# Docker
# Kubernetes
# Google Data Studio
# statistical modeling
# Caffe
# Madhukar Singh Office
# Torch
# MXNet
# MapReduce
# Cloud Computing
# Analytics
# MS Reporting
# Tableau
# Economics
# Elasticsearch
# Machine learning
# AI
# Python -Experience
# Perks
# statistical
# PA
# Hershey
# shell scripting
# JavaScript
# deep learning
# SPARK
# GCP
# models
# Sequence Modeling
# ECS
# artificial neural networks
# SSIS
# Microsoft T-SQL
# NLP
# reinforcement learning
# Optimization AI/MI
# GGlpot
# Map Reduce
# GLM/Regression
# SQL experience
# statistics
# SAS/R
# Software Development
# software engineering
# Google Analytics
# A/B Testing
# Product
# SQL advanced SQL
# Text Analysis
# Austin
# Microsoft SQL
# Finance
# SQL Server
# Equity
# modeling
# Puppet
# Ansible
# Jenkins
# SAP
# Marketing
# Engineering
# data exploration
# data visualization
# strategic analytics
# NYC office
# Advanced SAS
# GLM
# R statistical
# SaaS
# cloud computing
# Recommendation Systems
# Data Analysis
# Advanced degree
# Yield Management
# Direct Analytics
# Network Planning
# Airline Contracting
# query
# Data analytics
# Predictive Analytics
# Business Analytics
# NAM Marketing
# * Java
# Selenium
# Azure
# MS SQL
# MongoDB
# Data enrichment
# Git
# advanced SQL
# Data Warehousing - SPARK
# Data quality evaluations
# stacks
# MLlib
# Statistical Modeling
# R and/or Python
# Data
# AWS Redshift
# Recurrent Neural Networks
# Convolutional Neural Networks
# Cloud - Azure
# DataBricks
# image analysis
# operations research
# OF A RESUME IS
# Machine Vision
# SQL/RDBMs
# MySQL
# Vertica
# Python frameworks
# Data Science
# Data Modeling
# PostgreSQL
# Modeling experience
# Predictive Modeling
# Snowflake
# xgboost
# Inventory Management
# Statistics
# MS Access
# MS SQL Server
# Crimson Hexagon
# statistical analysis
# Palo Alto
# Splunk
# Google Cloud Stream Analytics
# Lisle
# IL
# credibility scoring
# Word
# ------------------------------------------------------------------------ 300
# then MATLAB
# Deep Reinforcement
# statistical concepts
# CPG firm
# Pandas
# GCP/BigQuery
# XGBoost
# Google / AWS
# Postgresql
# MYSQL
# Problem solving
# statistical learning
# a ?
# ?
# audit
# EC2
# EMR
# Stream Analytics
# Fargo Audit
# hypothesis testing
# MS Office
# Visio
# Predictive modeling
# Hypothesis testing
# statistical testing
# Functional Experience
# problem solving
# Teradata
# OpenCV
# non-linear regression
# linear
# Db2
# SQLite
# e.g. MySQL
# Baltimore
# LaTeX
# Data scientist
# Deep learning
# Map reduce
# Data analysis
# Oracle PL/SQL
# CS
# Apache Kafka
# Experienced
# Algorithms
# Power BI
# Analytics for Office
# Base SAS
# SAS QA
# AI
#
# text analytics
# Predictive model building
# Training / Development
# visualization
# non-parametric
# and parametric
# J2EE
# relational databases
# for predictive analytics
# T-SQL
# Visual Basic
# Oracle SQL
# audit experience
# EBS
# Microsoft SQL Server
# TOAD
# Application Testing
# Our direct
# Python script
# BI Dashboard
# OLAP Cube Studio
# Visual Analytics
# Information Map Studio
# Web Report Studio
# Data Management Studio
# Azure Cognitive
# Apache Hadoop
# Apache Spark
# machine-learning
# What began
# Businesses Intelligence
# logistic regression
# Apache Pig
# View EEO
# advanced analytics
# Vice President
# Github
# Managerial experience
# Python R
# Django
# kibana
# IBM ·
# Alpharetta
# GA Job
# Geomesa
# AWS/C2S
# creative problem solving
# any scripting language
# customer retention
# advanced computing
# Microsoft Visual Studio
# Access
# DevOps/
# PERL
# Matter Experts
# Advanced analytics
# AppSee
# Data Modeling experience
# BitBucket
# JIRA
# marital status
# Confluence
# Data & Analytics
# HR
# Sales & Marketing
# SAS/Access
# EQUAL OPPORTUNITY
# Network
#
# Google analytics
# Qlik
# TX - R
# IT - Analytics
# Broaden experience
# Training/Development
# Data Scientist/Developer
# Prescriptive
# AI/Client
# Google BigQuery
# Computer Vision
# Kafka
# CISSP
# CSS)Power BI
# HTML
# ·         Map Reduce
# radios
# technical knowledge
# By blending
# ------------------------------------------------------------------------ 700
# analytics
# social network analysis
# R-00007556
# Job #
# SQL 2
# python
# Modeling experience PostgreSQL
# HDFS
# Database Design
# scripting
# SQL/R
# Business Analysis
# sharing
# RDBMS
# Azure Data Lake Analytics
# Octopus Deploy
# DevOps
# CAHIMS
# Job requirements/ skills:﻿
# XSLT
# Azure XML
# Strong SQL
# regression analysis
# IA&A
# create SQL
# Digital Analytics
# Customer Analytics
# Loyalty Programs
# Reinforcement Learning
# DB2
# relational
# Data Scientist - (
# Revolution R
# programming SQL
# SSH
# Google or Redshift
# similar cloud computing
# scripting language
# Azure Analytics
# Data Warehouse / ETL
# Data Pipeline / Kafka
# Ruby / DynamoDB
# Azure / Cloud / AWS
# Data Lake
# & Hadoop
# selenium
# product
# MSSQL Experience
# XML
# IC GovCLoud
# Jira
# Unix
# Advanced experience
# architecture
# PMI
# Github Experience
# Microsoft office
# a Ph
# extract patterns
# Call analytics
# Day Job
# World leader
# Mathematics
# ------------------------------------------------------------------------ 900
# Political Methodology
# Cloud Architecture
# Azure ML
# create modular
# andor
# Python andor
# training necessary
# Environmental Management System
# DOE directives
# Data Management
# base
# A leader
# Lowell
# Lead strategic marketing
# e.g. SQL
# Workbench
# Datalake analytics
# Datalake
# CosmosDB
# EFS
# wrangling
# Power Point
# Autonomous
# Data Scientist - Austin
# TX
# Team player
# Mathematics
#
# data analytics
# Data wrangling
# * Hadoop
# machine leaning
# Jupyter Notebook ?
# - Designing
# Unlimited Vacation
# Position
# Job location
# optimization
# unsupervised learning
# supervised learning
# 3
# Models
# Java script
# Norwood
# WE ARE
# e.g. R
# research
# Data Integration
# data lake
# http://www.alelo.com
# Information Visualization
# Advanced Data Analytics
# Microsoft Excel
# Expertise
#
# deepl learning
# None
# a scripting
# Operational Management
# Design SQL
# actionable findings
# OPPORTUNITY
# ------------------------------------------------------------------------ 1200
# Peerless Building
# distributed computing
# subsystems
# Care/of
# Sales Operations
# Oracle database
# EDW
# campaign execution
# POSITION
# Experience
# 4866.00
# build things
# tweak things
# PURPOSE
# Asset Management
# Data Office
# 5
# Skills
# Ensembles
# Data exploration
# Optimization
# automation frameworks
# MS Power BI
# non-linear
# MS Excel
# ORACLE
# Data Scientist Pleasanton
# machine learning frameworks
# Research
# MD
#
# Suitland
# Azure cloud computing
# data engineering
# Clearly communicating findings
# Mode Analytics
# Modeling
# Database Management
# Space Programs
# Collaborative Filtering
# Product Management
# MS/Ph
# Elastic
# Data visualization
# Helpful
# TX / Cloud
# IoT
# Neural Networks
# Scoring
# Adversarial Networks
# Microsoft Azure
# Advanced Analytics
# business analytics
# ------------------------------------------------------------------------ 1400
# Linux scripting
# Statistical Modeling algorithms/techniques
# data analysis
# using SAS
# &bull
# Bayesian neural networks
# MA
#
# Lexington
# DATA SCIENTIST
# Software Engineer
# Artificial Intelligence sharing
# reverse engineering
# Advanced Structure
# Memphis
# TN
# Java required;
# R/R Studio
# preferably PostgreSQL
# Computer Research
# functional groups
# CSS
# technical analytics
# Analysis
# EEO
# Gigster
# simulation
# Problem solving & troubleshooting
# Management
# Office
# JOB
# Theano
# A successful
# Interested?
# Parsippany
# Google AdWords
# Bing Ads
# RedShift
# Bitbucket
# RESEARCH DEPARTMENT
# Apr 9
# Job Posting
# public speaking
# Analysis - R
# Data Integration - able
# Omaha
# Database
# Apr 11
# Supervised learning
# Chicago IL
# Programming/Development
# java
# MatLab
# Deep SQL expertise
# Sitecore Analytics
# Mongo DB
# Hadoop / Map-Reduce
# Mahout; Scripting
# BARRA; risk
# Business,
# Artificial intelligence
# Deep Neural Networks
# ------------------------------------------------------------------------ 1700
# e.g.
# GCP and/or
# statistical algorithms
# Dallas
# Microsoft Visio
# SCAN
# Microsoft Recruitment
# Pig
# Tableau R
# and/or NoSQL
# Prescriptive Analytics
# MS Word
# Application Development
# Operations
# Marketing Analytics
# Data Scientist Opening
# 5522
#
# CONSUMER BNKG
# enterprise analytics
# Random Forests
# Deterministic Forests
# xkcd
# Facebook Analytics
# Search Engine Marketing
# Python/R
# Technical Game Analytics
# Director
# Julia
# NOSQL
# team player
# SQUARESPACE
# CPT
# -----------------
# Data Integration patterns
# Data/Customer Analytics
# marketing analytics
# ------------------------------------------------------------------------ 1900
# Python/PySpark
# MIT 2014
# Text Analytics
# Azure Databricks
# Azure Kubernetes Services
# SystemML
# Neon
# Data Governance
# Data Intelligence
# R SQL
# Kafka Internet of Things
# Judgment/
# including JavaScript
# SQL Experience
# Powerpoint
# Assessments (A&A
# e.g. Java
# Network Management
# Distribution Management System (DMS)
# Ensembling
# Data Analyts
# Trianz
# ------------------------------------------------------------------------ 2000
# data blending
# course performance
# SageMaker
# Data Warehouses
# + SQL
# R studio
# graph analytics
# Data Labs
# SSL
# Work remote
# advanced expertise
# DynamoDB
# Google Cloud
# Client Analytics
# Digital Marketing
# Inventory Planning
# Hoboken
# H2O
# Spring
# TX
#
# ------------------------------------------------------------------------ 2100
# HR BI
# medical affairs
# Blueprism
# IT Application Developer
# Logistic Regression
# Five
# Fraud
# Digital and/or
# BMO Harris
# SAS Grid
# Advanced Analysis
# IBM SPSS
# SAP Hana
# cognitive services
# Cosmo DB
# Spark Sql
# Cognitive Sciences
# Apache
# Google Cloud Platform
# financial engineering
# Operations Research
# Restful API
# JAVA
# Angular
# WPAFB- Dayton
# Advanced Excel
# Apache Rya
# Atlassian Confluence
# Software Engineering
# TopBraid
# Protégé
# Tableau Eclipse
# Eclipse RDF4J
# Atlassian Crucible
# PyCharm
# Apache Maven
# CI/CD
# Radar Modeling
# ASP.net
# ------------------------------------------------------------------------ 2200
# Linux shell scripting
# and Pig
# statistical analysis system
# excel
# word
# neural networks
# R scripting
# Master’s/Ph
# Data Sciences
# QGIS/ArcGIS
# Michigan
# Detroit
# Theaters
# Biohazard Safety
# Columbus
# Division
# Epidemiology
# Business analytics
# Vision benefits
# automation
# Clickfox
# Createvisual analytics
# Privacy Notice
# Operational Research
# Operation Research
# U.Group
# People Analytics
# ------------------------------------------------------------------------ 2400
# Question Answering
# Base
# enjoys problem solving
# Data Center
# Jave
# Digital Industries
# SAP SLT
# Real World
# Conceptual modelling
# Predicate Modelling
# MS Azure
# Manchester
# NH
#
# Network Analysis
# ------------------------------------------------------------------------ 2500
# JS
# Flask
# MS-SQL
# Statistical Analysis
# Mathematical Optimization
# data management
# Lead Data Scientist
# Livonia
# May 7
# BigData and SQL
# REST API
# Spotfire
# RDS experience
# Kinsesis
# SQS
# RDS
# customer experience
# digital analytics
# cognitive analytics
# TX Job
# Plano
# Kinesis
# A full
# Systems Development
# Testing
# non-SQL
# One location
# Mac
# Technical Expertise
# Programming
# Algorithm Development experience
# Creates
# creative services
# databases
# Corp
# TX
#
# UCSF
# SQL; Python; R; VBA
# Apply Now
# Opendoor
# Nimble learning
# data scrubbing
# Internet of Things
# consumer analytics
# operations analysis
# ElasticSearch
# or R
# software design patterns
# Statistical modeling
# traditional risk management
# Product Development
# ------------------------------------------------------------------------ 2900
# Angular JS
# REACT JS
# VUE JS
# Jupyter
# our Palo Alto
# JDBC
# SOAP
# Fossil
# Azure IOT
# Microsoft Azure recruitment
# Technical Architecture
# Data warehouse/databases
# FLOMSTR
# Data Scientist - Manassas
# query reporting
# REMIS
# join?
# faster
# network modeling
# similar statistical
# statistical predictive modeling
# strategic partnerships
# statistical data analytics
# advanced Excel
# AB testing
# Thrift Savings
# engineering
# economics
# social sciences
# unit testing
# statistical model
# We care
# Deep Learning analytics
# SQL Hadoop
# ETL management
# sales analytics
# Norwell
# MA
# Nebraska
#
# AI; predictive
# cloud computation
# bioinformatics
# more Tableau
# technical support
# Competitive Intelligence
# Market Research
# sales/brand
# include planning
# Strong SQL Scripting
# advanced analytics experience
# Statistical
# Regression Analysis
# Six Sigma
# Industrial Engineering
# Next
# Data Models
# security systems
# AWK
# MA - Andover
# Modeling
# Job Expires
# GraphLab
# under privacy
# secure networks
# demonstrate
# Houston
# R
#
# Data Warehousing
# Technical Services
# Customer Service
# statistical analytics
# -performance algorithms
# Databricks
# Support patent
# Profit Sharing
# behavioral analytics
# Global Analytics
# Sas
# Power Query
# and/or R
# consumer credit
# conversion
# #CB
# ------------------------------------------------------------------------ 3400
# data
# telephone
# Silver Spring
# statistical models
# Python Scripting
# parametric
# Project leader
# Map-reduce
# ArcGIS
# BlueVoyant
# Data,
# shell experience
# PySpark
# tensorflow
# Portfolio Risk Analysis
# Internet Marketing experience
# MINIMUM EXPERIENCE
# extracting
# .NET
# H2O
#
# NE
#
# Data visualization experience
# Data Scientist - Predictive Analytics
# RocketChat
# syslog
# Chef
# Kibana
# Bamboo
# Kali
# Bash shell scripting
# SonarQube
# Project Planning
# MI 48226
# statistical language
# A Ph
# Streaming Analytics
# data ETL
# Ubuntu
# ------------------------------------------------------------------------ 3600
# Technical guru; SQL expert
# Multivariate regression
# HEALTH CARE
# MS/MA
# bash scripting
# T-sql
# Data Quality
# Neo4
# Tika
# Nifi
# MD
#
# Plot.ly
# D3
# Prometheus SQL
# Amazon Redshift
# Anomaly Detection
# Golang
# Relational DB
# Optimization Algorithms
# MATLAB; DB &amp; Management
# .net
# advanced Predictive
# specialized modeling
# designing
# social network modeling
# Corporate Quality
# Economic Researchers
# Azure Machine Learning
# CVS
# promoting internally
# Google Adwords
# Extension SQL
# Shinyapps
# POCs
# RESPONSIBILITIES:&nbsp;
# Compensation
# Microsoft BI
# Run SQL
# elastic cloud compute;
# Gephi
# Redis
# Assist sales
# SSRS
# and NoSQL
# BI
# LITECH
# testing
# statistical modelling
# Regression
# problem scoping
# necessary
# database
# Machines learning
# Consumer FY Sales
# Catalina
# Generate reports
# NLP experience
# using SQL
# Melbourne FL
# statistical software (R)
# and/or Java
# 17537BR
# Data Scientist-1903810
# storage systems
# Enlighten
# Hypothesis Testing
# including R
# and SQL
# Data Scientists
# Research Scientists
# sex
# http://www.ibm.com/ibm/responsibility/initiatives.html
# data science
# Nebraska
# SQL-like skills
# ICD-9 / 10
# Civis
# Core Engineering
# experimentation systems
# HL7
# summarize
# similar scripting
# ArangoDB
# MarkLogic
# Spark SQL
# strong problem-solving
# Oracle SQL Server
# Teradata SQL Server
# Technology
# technical leader
# Life Sciences
# BioInformatics
# PeopleSoft
# platforms
# Kelly
# Dynamo DB
# I4.0
# collegial team player
# TensorFlowDatabases
# Go
# git
# Microsoft Reporting Studio
# data mining
# Google Cloud Storage
# including SQL
# PostgresSQL
# OH; Boulder
# CA; Cincinnati
# Unlimited VacationHealth
# and solving
# JanusGraph
# Modeling •ETL
# Algorithm DesignPythonSQL
# Node.JS
# AWS EMR
# AWS Glue
# Azure Functions
# Azure HDInsight
# sales demos
# explore
# (Python
# QA/QC
# Our dynamic predictive
# lake
# QA/NLP
# elfa
# O365
# Microsoft (
# SharePoint
# NAV
# CPG
# Our next
# data sources
# recommendation systems
# prototyping
# Exceptional relationship building
# ------------------------------------------------------------------------ 4500
# (Redshift
# Data Engineering
# Data Scientist -
# Cloud Development
# social safety
# Populate SQL
# Team Player
# Fine
# editing
# VBScript
# linux
# R & MATLAB
# Jupyter Notebook Experience
# Analysis 8+SQL/R
# Computer Sciences
# Neural Nets
# Google
# Adobe Analytics
# andMongoDB
# PMML
# network protocols
# Electrical Engineering
# Python SQL
# operational analytics
# Keras
# MS PowerPoint
# Advanced PowerPoint
# SQL server)Visualization
# Learning
# portfolio
# Informatica/ ETL
# Office 365
# Microsoft Advertising
# Audit
# regression
# Forecast
# Digital Marketing spacePreferred
# Data Processing
# Azure Experience
# Geospatial Analytics
# Regression analysis
# Network analysis
# Software
# advanced statistical analysis
# consumer marketing
# sales
# Data Scientist - Ph
# A B.S.
# and/or SQL
# Windows 2003
# Specialized Experience
# provider analytics
# six
# learning
# Business Intelligence Engineer
# Data      analytics
# Azure
#
# Data Architect building
# ------------------------------------------------------------------------ 5000
# AWZ
# and Redshift
# similar distributed architecture
# EMR/Redshift
# Spark MLib
# Econometrics
# anomaly detection
# predictive analysis
# Mars Consulting
# Apache SOLR
# Bash Scripting
# and R
# MLib
# Comcast PABS
# ------------------------------------------------------------------------ 5100
# via cvojick@apexsystems.com
# Builds predictive
# TX 75014
# 4
# fraud detection
# Data management
# Menlo Ventures
# rapid prototyping
# Conduent
# Prototyping
# Power BI / Tableau
# using R
# strong SQL experience
# 2
# end
# Infosys Consulting
# javascript
# css
# Information Management
# software development experience
# Vrbo
# Data concepts
# problem solvers
# values fit
# relationship skills
# decision engineering support
# PowerShell
# Deep Learning networks
# similar field
# ------------------------------------------------------------------------ 5300
# Data ScientistPython
# Risk Analytics
# regression testing
# nginx
# php
# html
# GCP
#
# Linux shell script
# MS Visual Studio
# Windows
# differential privacy algorithms
# Linear
# Non-linear
# link analysis
# We’re growing;
# Data experts
# JMP
# Predictive analytics
# Google Cloud Composer
# PL/SQL/ MySQL
# Service Engineering Operations
# Plymouth Meeting
# Data systems
# speech analytics
# application server
# ------------------------------------------------------------------------ 5600
# Data Workbench
# PL/SQL
# troubleshooting
# e.g Hadoop
# autonomous systems
# Conshohocken
# query authoring
# JupyterHub
# e.g
# monitoring
# Statistical Model Development; Analytics
# patterns
# design researchers
# seven
# business judgment
# After all
# PowerPivot
# SQL database
# Microsoft .Net
# OAA
# �
# confluence
# Dealing
# variable selection
# analysis
# Java Script
# Explore
# SDLC
# Scripting
# Shell
# Data warehouse
# Prathap
# Artificial Intelligence team.&nbsp;
#
# AngularJS
# advanced data modeling
# PyScy
# packages
# Data Robot
# ------------------------------------------------------------------------ 6100
# web analytics
# Manufacturing
# Viacom
# Pac-12 Networks
# Hallmark
# DISABILITY
# Data Analysis experience
# SQL & R
# Redis Experience
# R-Studio
# Architects gaining
# C2S
# microservice
# data layers
# episode analytics
# power analysis
# software development
# National Offices
# Cloud systems
# ------------------------------------------------------------------------ 6200
# Model Risk Management
# surgical planning
# Excel Wizardry
# NoSql
# Dask
# Shell Scripting
# Minimum five
# Google Maps
# and/or maintaining SQL Server
# #AnalyticsEA
# Warehouses
# JEE
# Advanced Manufacturing
# and/or Google Cloud
# shell script
# Security Operations Center
# Peritus
# Cognitive Computing
# Some SQL
# Jupyter NotebookExperience
# Data VisualizationUnderstanding
# DALLAS
# Strategic Analytics
# Social Network Analysis
# visualization tooling
# experienced
# Risk Management
# exploitation
# - 11
# MS Office required
#
# ASA
# Manage hiring
# ------------------------------------------------------------------------ 6700
# Counterterrorism Division
# Paris
# Project Leader
# ------------------------------------------------------------------------ 6800
# cloud architecture
# REQUIRED EXPERIENCE
# Data scientist experience
# cloud services
# including Word
# JOB FUNCTIONS
#
# Geospatial Developer
# At Coinbase
# Shell scripting
# Lumiata
# M.S.
# SAS/GRAPH
# SAS/STAT
# NumPy
# Advanced Experience
# information visualization
# marketing
# credit/risk
# Research Computing
# Data Prep
# Wellness Programs
# ROI
# Oracle OBIEE
# AutoML
# Python and/or R
# LSTM Networks
# A bioinformatics
# deep learning frameworks
# Statistic Modeling/Predictive Modeling/AI/Algorithms
# SAP BI Hana
# network design;
#
# clean
# Black Swan
# MI
#
# Ada
# Math
# data
#
# ensemble learning
# various TPL
# Strategic Roadmap Planning
# Describe
# SQL MongoDB
# Ph
# Atos
# retention
# Neo4J
#
# Relational
# scientific computing
# management experience
# advanced predictive
# WAN
# Team building
# robotics
# Actively shares resources
# LI-JS1
# language understanding
# Html
# Numerical Analysis
# geospatial analytics
# Microsoft Access
# HQL
# Deep experience
# At Acorns
# technical documentation
# Architecture
# Project Management
# statistical software (R
# Data Visualization Experience
# ------------------------------------------------------------------------ 7700
# cGMP
# GMP
# manufacturing
# Deep learning frameworks
# Syapse
# ASR
# Predictive Modelling
# Optimizat
# CARE
# Microsoft Word
# graphics
# Excellent judgment
# FLSA Status
# DevOps (Jenkins
# in HDFS
# Python CICD
# Family Analytics
# Eden Prairie
# ------------------------------------------------------------------------ 7800
# sparklyr
# commercial cloud computing platforms
# Juno Beach
# Data Prepping
# Strong math
# Analysis ETL
# end performance
# Artificial Intelligence breakthroughs
# TX 75024
# SERC
# data scientist
# Investigation
# Java/R
# Cloud computing
# ------------------------------------------------------------------------ 8100
# /scripting
# TypeScript
# space
# portfolio management
# Marlboro
# Reporting
# Operations Analytics
# advanced statistical
# OpenNeuro
# Advanced Google Analytics
# political affiliation
# XMLor SQL
# 09/09/2019
# MINIMUM REQUIRED EXPERIENCE
# SQL servers)5
# HP Marketing
# NCR
# DNA/RNA
# Advanced Python
# Provides support
# temporal analytics
# 1st Shift
# ------------------------------------------------------------------------ 8400
# Assay Development
# Heroku
# Data Modeling techniques
# Azure Data Lake
# Azure streaming analytics
# Social Sciences
# credit risk
# Data scientist JD
# problem-solve
# Visual analytics
# MS-Excel
# Presentation graphics
# OPE001RORequisition #
# Google Cloud Services
# Software engineering
# Create
# Data Scientist - REMOTE
# Modeling &
# Design statistically sound
# UT office
# ACS GROUP
# Manufacturing Analytics
# MN 55021
# DNA Sequencing
# ------------------------------------------------------------------------ 8600
# Space/SOSI
# Lake
# SQL Server Management Studio
# Physical Sciences
# software; advanced analytics
# cyber
# especially Word
# Web analytics
# Google Cloud
#
# A/B testing
# Python experience
# hierarchical learning
# Automation
# advanced programmatic expertise
# 3rd-party
# Hive/ Impala/ BigQuery
# HighCharts
# Statistical analysis
# unit/integration testing
# Scala
# Advanced Analyses
# Non-SQL
# relational modeling
# a Unix
# Aug 9
# NAACL
# ACL
# Cloud platforms
# propose
# MS degree
# Documentation
# SQL)
# TX 78716
#
# CGIFederalERPJob
# Alberta
# Hierarchical Clustering
# Multiple Regression
# disciplineTypically
# - SPARK
# 1.Industry Leader
# Image Analytics
# programming experience
# Juice - The
# SQLData Visualization
# ex
# deep artificial
# Consumer Risk Management
# Banking
# Alternative data analytics
# Attribute development
# International Analytics
# API integration
# or Javascript
# industrial engineering
# ------------------------------------------------------------------------ 9200
# public cloud
# research analytics
# prescriptive analytics
# social network analytics
# ubiquitous computing
# core platforms
# Sciences
# SQL 3
# python/R
# Pattern Recognition
# Model building
# Model assessment
# GSE
# structured databases
# Arena
# C++/C#
# scrub
# DENSO
# Tx
# ------------------------------------------------------------------------ 9400
# Neo4J
# MS/PhD.
# Perform statistical
# AWS features
# job performance
# COX AUTOMOTIVE
# ------------------------------------------------------------------------ 9500
# Data Analytics/
# our Jobot Pro
# Luke Swift
# Author device
# technical personnel
# artificial networks
# Founders Fund
# Andreessen Horowitz
# digital marketing
# Google Ventures
# AND EXPERIENCE
# i.e.
# markdown
# SQL/NOSQL
# Minimum
# Microsoft SQL server
# ------------------------------------------------------------------------ 9600
# CI / CD
# advanced language expertise
# MuleSoft
# .Net
# consumer targeting
# action
# web scraping
# target marketing
# Microsoft AzureML
# IBM Watson Studio
# Google Cloud ML
# SAP Predictive Analytics
# next
# financial risk analytics
# Microsoft SQL Server Management Studio
# Hadoop/map-reduce
# SQL Python
# pymc Problem solving
# R/Python
# response models
# OpenShift
# Jupyter
#
# AR/
# Data Privacy
# generic SQL
# jQuery Experience
# Syder
# POSTGRESQL
# Mixpanel
# Periscopedata
# Marketing Science
# hierarchical clustering
# community
# Techniques;
# TX EXPERIENCE
# ScientistLOCATION Austin
# Data Processing/Analytics
# An M.S.
# My SQL
# and Kubernetes
# team problem
# Deep Networks
# ------------------------------------------------------------------------ 9800
# Weka
# query languages
# Microservices
# Mathematical Engineering
# Data Architecture
# customer relationship management
# develop Entry
# WORLD
# DoJ
# DoE
# spam
# noSQL
# ------------------------------------------------------------------------ 9900
# Shell script
# media analytics
# a Javascript framework
# SPLUS
# Reinforcement learning
# Statistical Modelling
# alongside experienced engineering
# Marketing Measurement Analytics
# for subsurface

# %%
skill_set = dict( Counter(skill_set).most_common(300) )
skill_set
# Out:
# {'Python': 950,
#  'SQL': 695,
#  'R': 502,
#  'machine learning': 485,
#  'Machine Learning': 334,
#  'SAS': 334,
#  'Data Scientist': 327,
#  'Java': 279,
#  'Spark': 264,
#  'C++': 258,
#  'Hadoop': 207,
#  'C': 169,
#  'AWS': 167,
#  'Deep Learning': 152,
#  'problem solving': 143,
#  'deep learning': 128,
#  'TensorFlow': 112,
#  'S3': 112,
#  'NoSQL': 110,
#  'predictive analytics': 101,
#  'Analytics': 100,
#  'Artificial Intelligence': 99,
#  'Linux': 94,
#  'SPSS': 91,
#  'Data Analytics': 87,
#  'problem-solving': 86,
#  'predictive modeling': 85,
#  'Tensorflow': 83,
#  'Oracle': 83,
#  'Azure': 83,
#  'EC2': 83,
#  'comparable NoSQL': 79,
#  'JavaScript': 74,
#  'artificial intelligence': 68,
#  'MATLAB': 66,
#  'Redshift': 65,
#  'Excel': 60,
#  'Data Visualization': 60,
#  'research': 60,
#  'Microsoft Office': 59,
#  'SQL Server': 57,
#  'C#': 56,
#  'Power BI': 55,
#  'MS Office': 54,
#  'PHP': 53,
#  'ETL': 53,
#  'PostgreSQL': 53,
#  'Tableau': 52,
#  'Predictive Analytics': 50,
#  'MySQL': 49,
#  'advanced analytics': 49,
#  'statistical modeling': 47,
#  'Unix': 47,
#  'Data Modeling': 46,
#  'PowerPoint': 44,
#  'Engineering': 43,
#  'NLP': 41,
#  'Kafka': 40,
#  'Javascript': 38,
#  'Matlab': 38,
#  'Google Analytics': 38,
#  'Apache Spark': 37,
#  'Machine learning': 36,
#  'Economics': 35,
#  'EMR': 32,
#  'HTML': 31,
#  'cloud computing': 30,
#  'Research': 30,
#  'Technical Expertise': 30,
#  'Data Lake': 29,
#  'Advanced Analytics': 29,
#  'Map/Reduce': 28,
#  'sex': 28,
#  'MapReduce': 27,
#  'MongoDB': 27,
#  'MS SQL Server': 25,
#  'PyTorch': 24,
#  'data visualization': 23,
#  'Data analytics': 23,
#  'Statistical Modeling': 23,
#  'Ruby / DynamoDB': 23,
#  'e.g.': 23,
#  'Operational Research': 23,
#  '2': 23,
#  'XML': 22,
#  'data analytics': 22,
#  'predictive': 21,
#  'Data Analysis': 21,
#  'hypothesis testing': 21,
#  'T-SQL': 21,
#  'Advanced SQL': 20,
#  'Kubernetes': 20,
#  'Neural Networks': 20,
#  'Microsoft Azure': 20,
#  'analytics': 19,
#  'text analytics': 18,
#  'scripting': 18,
#  'optimization': 18,
#  'CSS': 18,
#  'Business Intelligence': 17,
#  'Docker': 17,
#  'Cloud Computing': 17,
#  'shell scripting': 17,
#  'Git': 17,
#  'statistical testing': 17,
#  'Team player': 17,
#  'GCP and/or': 17,
#  'Google Cloud': 17,
#  'MS Azure': 17,
#  'statistical': 16,
#  'Predictive Modeling': 16,
#  'Word': 16,
#  'Data Warehouse / ETL': 16,
#  'Data Pipeline / Kafka': 16,
#  'Azure / Cloud / AWS': 16,
#  'Optimization': 16,
#  'Python/R': 16,
#  'software prototyping': 15,
#  'Marketing': 15,
#  'Jira': 15,
#  'Day Job': 15,
#  'PURPOSE': 15,
#  'testing': 15,
#  'AI': 14,
#  'artificial neural networks': 14,
#  'Jenkins': 14,
#  'Advanced degree': 14,
#  'Business Analytics': 14,
#  'Teradata': 14,
#  'regression analysis': 14,
#  'Statistical Analysis': 14,
#  'Problem Solving': 13,
#  'Perl': 13,
#  'statistics': 13,
#  'software engineering': 13,
#  'python': 13,
#  'Mode Analytics': 13,
#  'Operation Research': 13,
#  'Elasticsearch': 12,
#  'AWS Redshift': 12,
#  'Statistics': 12,
#  'statistical analysis': 12,
#  'WE ARE': 12,
#  'DATA SCIENTIST': 12,
#  'databases': 12,
#  'Data visualization experience': 12,
#  'statistical modelling': 12,
#  'PL/SQL': 12,
#  'R-Studio': 12,
#  'data modeling': 11,
#  'recruitment': 11,
#  'GitHub': 11,
#  'SAP': 11,
#  'advanced SQL': 11,
#  'Crimson Hexagon': 11,
#  'Deep learning': 11,
#  'visualization': 11,
#  'creative problem solving': 11,
#  'Access': 11,
#  'RDBMS': 11,
#  'Mathematics': 11,
#  'Google AdWords': 11,
#  'Bing Ads': 11,
#  'Powerpoint': 11,
#  'DynamoDB': 11,
#  'Operations Research': 11,
#  'neural networks': 11,
#  'Data Engineering': 11,
#  'Caffe': 10,
#  'SPARK': 10,
#  'Ansible': 10,
#  'relational databases': 10,
#  'Advanced analytics': 10,
#  'public speaking': 10,
#  'Mathematical Optimization': 10,
#  'Modeling': 10,
#  'Spark MLib': 10,
#  'Athena': 9,
#  'Austin': 9,
#  'Puppet': 9,
#  'Recommendation Systems': 9,
#  'Data': 9,
#  'any scripting language': 9,
#  'Confluence': 9,
#  'XSLT': 9,
#  '5': 9,
#  'Analysis': 9,
#  'Data/Customer Analytics': 9,
#  'Python/PySpark': 9,
#  'customer experience': 9,
#  'git': 9,
#  'JanusGraph': 9,
#  'Linux shell script': 9,
#  'Windows': 9,
#  'ensemble learning': 9,
#  'feature engineering': 8,
#  'Hershey': 8,
#  'GCP': 8,
#  'Problem solving': 8,
#  'Microsoft SQL Server': 8,
#  'CAHIMS': 8,
#  'Data Management': 8,
#  'e.g. R': 8,
#  'business analytics': 8,
#  'H2O': 8,
#  'JAVA': 8,
#  'Software Engineering': 8,
#  'statistical data analytics': 8,
#  'Industrial Engineering': 8,
#  '.NET': 8,
#  'AWS EMR': 8,
#  'Google': 8,
#  'Econometrics': 8,
#  'software development': 8,
#  'Visualization': 7,
#  'Microsoft SQL': 7,
#  'operations research': 7,
#  'Data Science': 7,
#  'statistical learning': 7,
#  'Base SAS': 7,
#  'Visual Analytics': 7,
#  'Python R': 7,
#  'Strong SQL': 7,
#  'DB2': 7,
#  'CosmosDB': 7,
#  'Power Point': 7,
#  'Position': 7,
#  'Experience': 7,
#  'machine learning frameworks': 7,
#  'Collaborative Filtering': 7,
#  'Product Management': 7,
#  'IoT': 7,
#  'Job Posting': 7,
#  'Prescriptive Analytics': 7,
#  'Digital Marketing': 7,
#  'TX \n': 7,
#  'SAP Hana': 7,
#  'Data Sciences': 7,
#  'RDS': 7,
#  'Testing': 7,
#  'MA': 7,
#  'AI; predictive': 7,
#  'Project Planning': 7,
#  'Neo4': 7,
#  'Tika': 7,
#  '.net': 7,
#  'database': 7,
#  'Hypothesis Testing': 7,
#  'Keras': 7,
#  'PowerShell': 7,
#  'SAP BI Hana': 7,
#  '·': 6,
#  'SAP HANA': 6,
#  'Predictive': 6,
#  'Data Mining': 6,
#  'Torch': 6,
#  'PA': 6,
#  'SQL experience': 6,
#  'SAS/R': 6,
#  'data exploration': 6,
#  'MS SQL': 6,
#  'MS Access': 6,
#  'credibility scoring': 6,
#  'XGBoost': 6,
#  'Stream Analytics': 6,
#  'Predictive modeling': 6,
#  'Hypothesis testing': 6,
#  'non-parametric': 6,
#  'What began': 6,
#  'Django': 6,
#  'customer retention': 6,
#  'JIRA': 6,
#  'sharing': 6,
#  'Microsoft office': 6,
#  'Call analytics': 6,
#  'e.g. SQL': 6,
#  'TX': 6,
#  '3': 6,
#  'non-linear': 6,
#  'data engineering': 6,
#  'MatLab': 6,
#  'Julia': 6,
#  'NOSQL': 6,
#  'advanced expertise': 6,
#  'excel': 6,
#  'Flask': 6,
#  'TX\n': 6,
#  'Apply Now': 6,
#  'ElasticSearch': 6,
#  'Jupyter': 6,
#  'JDBC': 6,
#  'SOAP': 6,
#  'unit testing': 6,
#  'Python Scripting': 6,
#  'PySpark': 6,
#  'Nifi': 6,
#  'promoting internally': 6,
#  'Node.JS': 6,
#  'AWS Glue': 6,
#  'Azure Functions': 6}

# %% [markdown]
# # ============================================================
# ## 基于句法分析抽取层级关系
#
# ### 根据每个技能类关键词，向上找最小分支树，判断依存关系

# %%
nlp = spacy.load("en_core_web_sm")

# %%
def is_father( word, root ):
    if word == root:
        return True
    
    while word != word.head:
        word = word.head
        if word == root:
            return True
    
    return False

# %%
ind = 0

total_link_list = []
for root,dirs,files in os.walk(r"E:\dataset\dataset"):
    for file in files:
        ind += 1
        
        my_file = open( os.path.join(root,file),encoding = 'utf-8' )

        my_string = my_file.readlines()
        for string_list in my_string[1:]:
            string_list = string_list.replace('e.g.','like')
            string_list = string_list.replace('.)',')')
#             for string in [sentence for sentence in re.split(r'[？?！!。；;：:\n\r·]', string_list) if sentence]:
            for string in re.split(r'[？?！!。.；;：:\n\r·•*]', string_list):
#                 try:
                doc = nlp( string )

                my_chunks_list = []
                roor_chunks_dict = {}

                for chunk in doc.noun_chunks:
                    if chunk.text in skill_set.keys():
                        my_chunks_list.append( chunk.root )
                        roor_chunks_dict[ str(chunk.root)] = str(chunk)

                if len( my_chunks_list ) > 1:
#                     print( 'skill word:', my_chunks_list )
                    Total_List = []

                    for word in my_chunks_list:
                        temp_list = []
                        temp_list.append(word)

                        pre = word
                        while word != word.head:
                            pre = word
                            relation = word.dep_
                            word = word.head

                            if 'N' in word.tag_ and (relation != 'conj' and relation != 'appos'):
                                if word in my_chunks_list:
                                    temp_list.append( word )

                                    if len( [str( roor_chunks_dict[str(w)] ) for w in temp_list if 'xperience' not in str(w)] ) == 2:
                                            print(string)
                                            print('result1:')  
                                            print( '-->'.join([str( roor_chunks_dict[str(w)] ) for w in temp_list]) )
                                            total_link_list.append( [str( roor_chunks_dict[str(w)] ) for w in temp_list] )
                                            print()

                                else:
                                    tree_list = []
                                    for t in my_chunks_list:
                                        if t.dep_ == 'compound' and is_father( t, word ) == True and is_father( t, pre ) == False:
                                            tree_list.append( t )

                                    if len(tree_list) == 1:
                                        key1 = roor_chunks_dict[ str(temp_list[0]) ]
                                        key2 = roor_chunks_dict[ str(tree_list[0]) ]
                                        
                                        if 'xperience' not in key1 and 'xperience' not in key2:
                                            print(string)
                                            print('result2:')  
                                            
                                            print( '-->'.join( [ key1, key2 ] ) )
                                            total_link_list.append( [ key1, key2 ] )
                                            print()
                                break
                
        my_file.close()

        if ind % 500 == 0:
            print( '==================================================',ind )
            
        if ind > 500:
            break
# Out:
# Experience with sophisticated analyses (like, longitudinal modeling, machine learning, non-parametric statistical modeling) and data visualization (like, Tableau, Qlik, R Shiny, Microstrategy) is preferred
# result1:
# Tableau-->data visualization
#
#  Experience with sophisticated analyses (like, longitudinal modeling, machine learning, non-parametric statistical modeling) and data visualization (like, Tableau, Qlik, R Shiny, Microstrategy) is preferred
# result1:
# Tableau-->data visualization
#
# Advanced skill in use of Microsoft Office, including Outlook, Excel, Word, PowerPoint, and other computer applications including but not limited to skill in using shortcuts, macros, visual basic editing and advanced formulas)
# result1:
# Excel-->Microsoft Office
#
# Advanced skill in use of Microsoft Office, including Outlook, Excel, Word, PowerPoint, and other computer applications including but not limited to skill in using shortcuts, macros, visual basic editing and advanced formulas)
# result1:
# Word-->Microsoft Office
#
# Advanced skill in use of Microsoft Office, including Outlook, Excel, Word, PowerPoint, and other computer applications including but not limited to skill in using shortcuts, macros, visual basic editing and advanced formulas)
# result1:
# PowerPoint-->Microsoft Office
#
# Strong programming proficiency and working experience (10+years) in a subset of Python, R, Scala, Java (Python preferred)
# result1:
# Python-->Java
#
#  Advanced skills and experience with R (required) and/or Python (desired) (including relevant packages) in support of advanced analytics Advanced-level skills with relational databases, including SQL and utilizing data stored in complex schemas Expert-level logical and analytic skills Broad experience and solid theoretical foundation on the modeling process using a variety of algorithms Data profiling, distributions, confidence intervals, hypothesis testing Holdout for testing, cross-validation Data pre-processing, exploratory data analysis using a variety of techniques Regression and classification using linear models, GLMs, and tree-based methods Interpretation of model results, consideration of causality, treatment of multicollinearity Strong synthesis and presentation skills Experience with Teradata
# result1:
# SQL-->relational databases
#
#  6+ Months Contract Advanced skills and experience with R (required) and/or Python (desired) (including relevant packages) in support of advanced analytics Advanced-level skills with relational databases, including SQL and utilizing data stored in complex schemas Expert-level logical and analytic skills Broad experience and solid theoretical foundation on the modelling process using a variety of algorithms Data profiling, distributions, confidence intervals, hypothesis testing Holdout for testing, cross-validation Data pre-processing, exploratory data analysis using a variety of techniques Regression and classification using linear models, GLMs, and tree-based methods Interpretation of model results, consideration of causality, treatment of multicollinearity Strong synthesis and presentation skills Experience with Teradata
# result1:
# SQL-->relational databases
#
#  problem formulation, requirements analysis, and planning Execute the full-scope of advanced analytic techniques Responsible for data surveying, profiling, and pre-processing Model data management for validation (like holdout, cross-validation) Selection of appropriate algorithms and execution Responsible for interpretation of results – for both causal inferences and predictive effectiveness Synthesize appropriate recommendations for action and changes Present findings, suggested actions and changes to a broad audience, and help manage follow-ups and execution Help teach and explain techniques and tools used to a broad set of business-intelligence, data, and analytics professionals with varied backgrounds Suggest tools, approaches, and data used to meet the needs of the particular problem REQUIRED QUALIFICATIONS Skills/Abilities and Knowledge Advanced skills and experience with R (required) and/or Python (desired) (including relevant packages) in support of advanced analytics Advanced-level skills with relational databases, including SQL and utilizing data stored in complex schemas Expert-level logical and analytic skills Broad experience and solid theoretical foundation on the modeling process using a variety of algorithms Data profiling, distributions, confidence intervals, hypothesis testing Holdout for testing, cross-validation Data pre-processing, exploratory data analysis using a variety of techniques Regression and classification using linear models, GLMs, and tree-based methods Interpretation of model results, consideration of causality, treatment of multicollinearity Strong synthesis and presentation skills Experience with Teradata
# result1:
# SQL-->relational databases
#
# ================================================== 500

# %%
ind = 0

total_link_list = []
for root,dirs,files in os.walk(r"E:\dataset\dataset"):
    for file in files:
        ind += 1
        
        my_file = open( os.path.join(root,file),encoding = 'utf-8' )

        my_string = my_file.readlines()
        for string_list in my_string[1:]:
            string_list = string_list.replace('e.g.','like')
            string_list = string_list.replace('.)',')')
#             for string in [sentence for sentence in re.split(r'[？?！!。；;：:\n\r·]', string_list) if sentence]:
            for string in re.split(r'[？?！!。.；;：:\n\r·•*]', string_list):
#                 try:
                doc = nlp( string )

                my_chunks_list = []
                roor_chunks_dict = {}

                for chunk in doc.noun_chunks:
                    if chunk.text in skill_set.keys():
                        my_chunks_list.append( chunk.root )
                        roor_chunks_dict[ str(chunk.root)] = str(chunk)

                if len( my_chunks_list ) > 1:
#                     print( 'skill word:', my_chunks_list )
                    Total_List = []

                    for word in my_chunks_list:
                        temp_list = []
                        temp_list.append(word)

                        pre = word
                        while word != word.head:
                            pre = word
                            relation = word.dep_
                            word = word.head

                            if 'N' in word.tag_ and (relation != 'conj' and relation != 'appos'):
                                if word in my_chunks_list:
                                    temp_list.append( word )

                                    if len( [str( roor_chunks_dict[str(w)] ) for w in temp_list if 'xperience' not in str(w)] ) == 2:
                                            print( '-->'.join([str( roor_chunks_dict[str(w)] ) for w in temp_list]) )
                                            total_link_list.append( [str( roor_chunks_dict[str(w)] ) for w in temp_list] )

                                else:
                                    tree_list = []
                                    for t in my_chunks_list:
                                        if t.dep_ == 'compound' and is_father( t, word ) == True and is_father( t, pre ) == False:
                                            tree_list.append( t )

                                    if len(tree_list) == 1:
                                        key1 = roor_chunks_dict[ str(temp_list[0]) ]
                                        key2 = roor_chunks_dict[ str(tree_list[0]) ]
                                        
                                        if 'xperience' not in key1 and 'xperience' not in key2:
                                            print( '-->'.join( [ key1, key2 ] ) )
                                            total_link_list.append( [ key1, key2 ] )
                                break
                                    
        my_file.close()

        if ind % 500 == 0:
            print( '==================================================',ind )

# %%
link_df = pd.DataFrame( total_link_list )
link_df = link_df.rename(columns = {0:'node1',1:'node2'})
link_df
# Out:
#                    node1               node2
# 0                Tableau  data visualization
# 1                Tableau  data visualization
# 2                  Excel    Microsoft Office
# 3                   Word    Microsoft Office
# 4             PowerPoint    Microsoft Office
# ..                   ...                 ...
# 448         optimization  advanced analytics
# 449  predictive modeling  advanced analytics
# 450     machine learning  advanced analytics
# 451         optimization  advanced analytics
# 452                  SQL           databases
#
# [453 rows x 2 columns]

# %% [markdown]
# # 关系绘制

# %%
from unittest.mock import patch
from nose.tools import assert_equal, assert_in
from pyecharts import options as opts
from pyecharts.charts.basic_charts.graph import Graph

from pyecharts import options as opts
from pyecharts.charts import Graph

nodes = []
links = []

nodes_set = []

for ind, row in link_df.iterrows():
    
    if row['node1'] != row['node2']:
        
        if row['node1'] not in nodes_set:
            nodes_set.append( row['node1'] )
            nodes.append( {'name': row['node1'] , "symbolSize": 15 + skill_set[row['node1']] / 20 } )
            
        if row['node2'] not in nodes_set:
            nodes_set.append( row['node2'] )
            nodes.append( {'name': row['node2'] , "symbolSize": 15 + skill_set[row['node2']] / 20 } )
        
        links.append({"source": row['node2'], "target": row['node1']})

Graph().add(
    "", 
    nodes, 
    links, 
    repulsion=8000,
#     linestyle_opts=opts.LineStyleOpts(width=2, curve=0.1, opacity=0.9),
    linestyle_opts=opts.LineStyleOpts(width=0.5, curve=0.3, opacity=0.7),
    label_opts=opts.LabelOpts( ),
    categories=None,
    is_focusnode=True,
#     layout="none",
    is_roam=True
    
).set_global_opts(title_opts=opts.TitleOpts(title="Graph-基本示例")).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="2a1f4375a0374f679d2e46d8e6b8d249" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_2a1f4375a0374f679d2e46d8e6b8d249 = echarts.init(
#                     document.getElementById('2a1f4375a0374f679d2e46d8e6b8d249'), 'white', {renderer: 'canvas'});
#                 var option_2a1f4375a0374f679d2e46d8e6b8d249 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "graph",
#             "layout": "force",
#             "symbolSize": 10,
#             "circular": {
#                 "rotateLabel": false
#             },
#             "force": {
#                 "repulsion": 8000,
#                 "edgeLength": 50,
#                 "gravity": 0.2
#             },
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 0.5,
#                 "opacity": 0.7,
#                 "curveness": 0.3,
#                 "type": "solid"
#             },
#             "roam": true,
#             "draggable": false,
#             "focusNodeAdjacency": true,
#             "data": [
#                 {
#                     "name": "Tableau",
#                     "symbolSize": 17.6
#                 },
#                 {
#                     "name": "data visualization",
#                     "symbolSize": 16.15
#                 },
#                 {
#                     "name": "Excel",
#                     "symbolSize": 18.0
#                 },
#                 {
#                     "name": "Microsoft Office",
#                     "symbolSize": 17.95
#                 },
#                 {
#                     "name": "Word",
#                     "symbolSize": 15.8
#                 },
#                 {
#                     "name": "PowerPoint",
#                     "symbolSize": 17.2
#                 },
#                 {
#                     "name": "Python",
#                     "symbolSize": 62.5
#                 },
#                 {
#                     "name": "Java",
#                     "symbolSize": 28.95
#                 },
#                 {
#                     "name": "SQL",
#                     "symbolSize": 49.75
#                 },
#                 {
#                     "name": "relational databases",
#                     "symbolSize": 15.5
#                 },
#                 {
#                     "name": "predictive modeling",
#                     "symbolSize": 19.25
#                 },
#                 {
#                     "name": "advanced analytics",
#                     "symbolSize": 17.45
#                 },
#                 {
#                     "name": "machine learning",
#                     "symbolSize": 39.25
#                 },
#                 {
#                     "name": "optimization",
#                     "symbolSize": 15.9
#                 },
#                 {
#                     "name": "hypothesis testing",
#                     "symbolSize": 16.05
#                 },
#                 {
#                     "name": "statistical analysis",
#                     "symbolSize": 15.6
#                 },
#                 {
#                     "name": "testing",
#                     "symbolSize": 15.75
#                 },
#                 {
#                     "name": "software development",
#                     "symbolSize": 15.4
#                 },
#                 {
#                     "name": "MySQL",
#                     "symbolSize": 17.45
#                 },
#                 {
#                     "name": "databases",
#                     "symbolSize": 15.6
#                 },
#                 {
#                     "name": "R",
#                     "symbolSize": 40.1
#                 },
#                 {
#                     "name": "MS Office",
#                     "symbolSize": 17.7
#                 },
#                 {
#                     "name": "SQL Server",
#                     "symbolSize": 17.85
#                 },
#                 {
#                     "name": "statistics",
#                     "symbolSize": 15.65
#                 },
#                 {
#                     "name": "research",
#                     "symbolSize": 18.0
#                 },
#                 {
#                     "name": "PyTorch",
#                     "symbolSize": 16.2
#                 },
#                 {
#                     "name": "machine learning frameworks",
#                     "symbolSize": 15.35
#                 },
#                 {
#                     "name": "neural networks",
#                     "symbolSize": 15.55
#                 },
#                 {
#                     "name": "deep learning",
#                     "symbolSize": 21.4
#                 },
#                 {
#                     "name": "scripting",
#                     "symbolSize": 15.9
#                 },
#                 {
#                     "name": "SAS",
#                     "symbolSize": 31.7
#                 },
#                 {
#                     "name": "MATLAB",
#                     "symbolSize": 18.3
#                 },
#                 {
#                     "name": "NoSQL",
#                     "symbolSize": 20.5
#                 },
#                 {
#                     "name": "MongoDB",
#                     "symbolSize": 16.35
#                 },
#                 {
#                     "name": "Data Management",
#                     "symbolSize": 15.4
#                 },
#                 {
#                     "name": "Data",
#                     "symbolSize": 15.45
#                 },
#                 {
#                     "name": "IoT",
#                     "symbolSize": 15.35
#                 },
#                 {
#                     "name": "JavaScript",
#                     "symbolSize": 18.7
#                 },
#                 {
#                     "name": "data exploration",
#                     "symbolSize": 15.3
#                 },
#                 {
#                     "name": "excel",
#                     "symbolSize": 15.3
#                 },
#                 {
#                     "name": "T-SQL",
#                     "symbolSize": 16.05
#                 },
#                 {
#                     "name": "Microsoft SQL Server",
#                     "symbolSize": 15.4
#                 },
#                 {
#                     "name": "S3",
#                     "symbolSize": 20.6
#                 },
#                 {
#                     "name": "EMR",
#                     "symbolSize": 16.6
#                 },
#                 {
#                     "name": "Access",
#                     "symbolSize": 15.55
#                 },
#                 {
#                     "name": "RDBMS",
#                     "symbolSize": 15.55
#                 },
#                 {
#                     "name": "data analytics",
#                     "symbolSize": 16.1
#                 },
#                 {
#                     "name": "Business Analytics",
#                     "symbolSize": 15.7
#                 },
#                 {
#                     "name": "Machine Learning",
#                     "symbolSize": 31.7
#                 },
#                 {
#                     "name": "Data Science",
#                     "symbolSize": 15.35
