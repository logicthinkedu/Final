# %%
from __future__ import unicode_literals, print_function

import pandas as pd
from collections import Counter
import json
from spacy.gold import GoldParse
from spacy.scorer import Scorer
from spacy import displacy

from sklearn.metrics import classification_report
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import accuracy_score

import random
import re
from pprint import pprint
import os
import warnings
warnings.filterwarnings('ignore')

import plac
import random
from pathlib import Path
import spacy
from spacy.util import minibatch, compounding

# %%
with open("NER_dataset/Ner_Train_Data.json", "r") as f:
    training_data = json.load(f)

training_data[0]
# Out:
# ['Experience in commonly used for data analysis such as Python, R, Julia, or SAS.\r',
#  {'entities': [[32, 45, 'SKILL'],
#    [54, 60, 'SKILL'],
#    [62, 63, 'SKILL'],
#    [65, 70, 'SKILL'],
#    [75, 78, 'SKILL']]}]

# %%
output_dir = 'ner_model_Skills_me/'
n_iter = 120
#######
nlp = spacy.load ( 'en_core_web_sm' )
print( nlp.pipe_names )

ner = nlp.create_pipe("ner")
nlp.replace_pipe(component=ner, name='ner')

# add labels
for _, annotations in training_data:
    for ent in annotations.get("entities"):
        ner.add_label(ent[2])

# other_pipes = []

# get names of other pipes to disable them during training
other_pipes = [pipe for pipe in nlp.pipe_names if pipe != "ner"]
with nlp.disable_pipes(*other_pipes):  # only train NER
#     if nlp is None:
    nlp.begin_training()
    for itn in range(n_iter):
        random.shuffle(training_data)
        losses = {}
        # batch up the examples using spaCy's minibatch
        batches = minibatch(training_data, size=compounding(4.0, 32.0, 1.001))
        for batch in batches:
            texts, annotations = zip(*batch)
            nlp.update(
                texts,  # batch of texts
                annotations,  # batch of annotations
                drop=0.5,  # dropout - make it harder to memorise data
                losses=losses,
            )
        print("Losses", losses)

# save model to output directory
nlp.to_disk(output_dir)
print("Saved model to", output_dir)
        
# trained this model with 100 iterations in google colab using GPU runtime with loss: Losses {'ner': 465.24571515528373}
# Out:
# ['tagger', 'parser', 'ner']
# Losses {'ner': 3513.0107858604156}
# Losses {'ner': 2241.33879684698}
# Losses {'ner': 1890.5465298151692}
# Losses {'ner': 1698.7312965243946}
# Losses {'ner': 1450.3776055092833}
# Losses {'ner': 1433.0762409560195}
# Losses {'ner': 1228.2183340281288}

# %% [markdown]
# # import NER model recognize SKILL words

# %%
nlp = spacy.load('ner_model_Skills_me/')

# %%
skill_set = {}

# %%
def remove_urls(vTEXT):
    vTEXT = re.sub(r'(https|http)?:\/\/(\w|\.|\/|\?|\=|\&|\%)*\b', '', vTEXT, flags=re.MULTILINE)
    return(vTEXT)

# %%
ind = 0
lower_skill_set = set()

for root,dirs,files in os.walk(r"../JD_files"):
    for file in files:
        ind += 1
#         try:
            
        my_file = open( os.path.join(root,file),encoding = 'utf-8' )
        my_string = my_file.readlines()

        doc_sentences = '\n'.join(my_string[1:])
        doc_sentences = remove_urls(doc_sentences)
        
        doc_sentences = doc_sentences.replace('www.','https://www.')
        doc_sentences = remove_urls(doc_sentences)
        
        doc_sentences = nlp(doc_sentences)
        
        doc_sentence_list = [str(sen).strip()  for sen in doc_sentences.sents if len(str(sen).strip()) > 0]

        file_list = []
        for tmp_sentences in doc_sentence_list:
            doc = nlp( tmp_sentences )

            temp_list = []
            for chunk in doc.ents:
                if chunk.root.ent_type_ == 'SKILL':
                    temp_list.append( chunk.text )

            file_list += temp_list

        for tem in list(set(file_list)):
            if tem.lower() not in skill_set.keys() and len(str(tem).strip()) > 0 :
                lower_skill_set.add( tem.lower() )
                
                if random.randint(0,300) == 0:
                    print( tem )

            if skill_set.get( tem, 0 ) == 0:
                skill_set[tem] = 1
            else:
                skill_set[tem] += 1

        my_file.close()
        if ind % 1000 == 0:
            print( '-' * 120, ind )
                
#         except:
#             pass
# Out:
# cloud-based data warehouses
# network
# relational database
# massive datasets
# PRIMARY DUTIES
# advanced mathematical techniques
# priority referrals
# Microsoft Corporation
# Hadoop
# enterprise-grade
# VBA
# MS
# Brand new office
# CA
# quantitative problem-solving
# True North re-imagines
# ENVI/IDL
# MD/PhD
# PROFESSIONAL
# framework
# SalesPlanning
# Dell EMC
# MR&A
# Microsoft Office
# warehouse(s
# validate new features
# Waste
# Pig
# Alpha
# MATLAB
# phone
# General Motors
# Django
# Conducts research
# Executive Orders
# Brand new office
# multi-discipline team
# measure results
# Linux
# banking sectors
# Corporate Technology
# R
# job qualifications
# optimization and validation
# USA
# Comcast Corporation
# data science community
# Repair Reports
# LDA
# SQL
# Oracle
# MAPReduce On-site
# CA
# TechCrunch
# ExperienceEducation
# R
# Ph.D.
# Teradata
# personal credibility
# NIBR
# SDLC
# Microsoft Cloud
# C++
# SQL
# NO PHONE
# research proposals
# SQL
# CESR
# CA
# ------------------------------------------------------------------------------------------------------------------------ 1000
# North America
# AWS
# veteran-friendly
# IDF
# ML technologies
# Chicago
# SQL
# SQL
# PySpark
# SCAN
# SQL
# SIT
# Model Risk Management
# SAS
# Windows
# data and things
# PowerBI
# North America
# customer-centric culture
# clearance after hire
# C++
# unsupervised learning models
# communicator -Masters degree
# FIT
# PHD
# SQL databases
# ProKarma
# IoT
# General Adversarial Networks
# collection/cleaning
# Solr
# Ushering
# PhD
# SQL
# Thinking
# CS
# Bio
# empower consumers
# data analysis systems
# ------------------------------------------------------------------------------------------------------------------------ 2000
# high-dimensional statistical methods
# volume prediction
# compute tools
# Team Problem Solving
# AWS
# Sunshine
# Position
# Seattle
# Travis CI
# Asia
# pursuing independent research
# Honestly
# GCP
# Julia
# kNN
# survey design
# NLSN
# Recurrent Neural Networks
# They
# data driven tools
# M.S.
# SAS
# sjsu.edu/up
# data quality management
# Improved Saving
# pig
# COBIT
# SCI
# Computer/IT Services
#
#
#
#
#
#
#
#
#
#
# NOTE
# Google-Solid
# Knowledge/Skills
# difficult modeling
# TS
# Ruby
# Seattle
# SAS
# RBF
# L
# Weka
# CA 94039
# Doctorate Degree
# ------------------------------------------------------------------------------------------------------------------------ 3000
# Scala -
# FOSS
# automotive retail
# Oracle
# Unix-based OS
# NoSQL databases
# MLKCH
# USA
# Protected Vet/
# SPSS
# privacy-preserving data
# AWS
# comprehensive compensation
# statistical inference tools
# computer tools
# Director
# MA
# Speed
# SCI
# distributed and parallel computing architectures
# Workday based data
# Big DataLocation
# SAS
# CRM
# Job ID
# OMS
# understanding trends
# business rules processing
# PMML
# High-Performance Parallel
# business and IT stakeholders
# IBKR’s
# NICE
# Computer/IT Services
# SparkExperience
# MongoDB
# PowerBI
# Waltham
# career at Hallmark
# IDL
# CyberCoders CyberCoders
# Seeing
# SUBSTITUTIONS
# ------------------------------------------------------------------------------------------------------------------------ 4000
# Martin MFC
# Regards
# TPG
# Data-oriented personality
# BI solutions
# Wealth
# stakeholder management
# Zürich/Seefeld
# SAS
# MicroStrategy
# CAP
# Expected skills
# requests
#
#
#
#
# AWS
# NREL
# TN
# Textio's superb
# USCIS
# San Francisco
# MS Office
# embark
# C++
# Prowess delivers
# SVM
# But
# Moreover
# OMS
# RStudio
# Staff
# View
# Google Cloud
# TASKS
# CND Tools
# SCI
# Spring Framework
# RDS/ Redshift
# RStudio Server
# Glendale
# critical-thinking
# City
# FL
# ------------------------------------------------------------------------------------------------------------------------ 5000
# Microsoft Pivot
# Perks
# C++
# executive communication skills
# General Information
# S3
# Eno
# ArcMap
# S/
# Washington
# C++
# KPIs
# NOTE
# Asia
# Frank
# DevOps market
# Bing
# 3M. Interns
# Michigan
# Savings
# Maintaining
# Multivariate Time Series
# Celonis Process Mining
# SAS
# Minorities/Females/Vets/Disability
# CRM
# Individuals
# MongoDB
# PA
# SPSS
# ML-driven actions
# sentiment extraction
# MD
# Fluency
# SSAS
# Career level
#
#
#
#                          Executive
# Cert/Lic
# Azure
# EDC
# AI research
# DSD
# TIAA's mission
# Vacation/PTO
# IE-Continuous
# comparable NoSQL
# Flagstaff
# San Francisco
# APIs
# ------------------------------------------------------------------------------------------------------------------------ 6000
# Palo Alto
# MD
# Microsoft/
# XML
# disadvantages
# Competency navigating
# C++
# Kafka
# Aptitude
#
#
#
# Bachelor’s Degree
# A proactive problem solver
# Seattle
# DC
# LAPack
# CNTK
# Cambridge-
# Documentation
#
#
#
# Documenting
# SAS
# ML-based models
# Sas
# HDFS
# California
# SVP
# Consumer Lifecycle
# business data Selecting features
# Thrilled
# interrogate
# June
# S3
# York|Rochester\
# When applying
# ENVA
# Shares information
# PTO
# unique features
# Director
# Google’s Cloud Platform
# AWS
# ECCV
# Workload Staffing Models
# TS
# DataBricks
# Columbia
# ------------------------------------------------------------------------------------------------------------------------ 7000
# MS degree
# DB2
# Some
# CyberCoders
# NJ
# Advanced SQL
# leading analysts
# Experienced
#
#
#
# Job
# REMOTE!
# Kingdom
# quantitative maven
# NYC
# Toyota
# TX
# CA
# PostgresSQL
# MA
# PowerShell
# EY
# PA
# Tacoma
# distillation
# bias and fairness Operationalization
# SMILF
# PhD
# Americans
# AI
# Sonalysts
# Alteryx
# CPG
# R.
# OIAA
# DNA
# ------------------------------------------------------------------------------------------------------------------------ 8000
# North America
# AHRQ
# RDMS
# Creative skills
# SPSS
# Taboola
# FPT Industrial
# dream AWS
# Required Skills
# 212
# Core Values
# English
# Send
# SAS
# 331
# GCP
# OOP
# Ph.D.
# Microsoft Office
# data analysis Benefits
# Visual Basic
# IoT
# estimation theory
# Innovators based
# ETL
# Display critical thinking
# MS
# KS-Topeka
# Burscheid
# NC-Asheville
# HuaiNan
# North America Soybeans through connection
# Sensitive Compartmented Information access
# C/C++
# MINIMUM
# vision/dental coverages
# ENVIRONMENTAL JOB
# CyberCoders CyberCoders
# Lead Data Scientist
# IoT
# Amazon S3
# MCR
# ML frameworks
# Pkwy
# Associate
# VLSI
# ------------------------------------------------------------------------------------------------------------------------ 9000
# Machine Learning techniquesBachelor’s Degree
# MongoDB
# Multivariable Calculus
# MA
# Utilize APIs
# Introduction
# Grid Solutions
# Assists
# TX
# ETL management
# Cassandra
# DoD
# Climate Corporation - The Technology
# POC
# IoT
# Hortonworks
# C#
# - C++
# Career
# Polygraph
# CHANGE THE WORLD
# NOT
# GPD
# discretization
# DLI
# C++
# Tribune
# Performance Based Logistics/contracting
# A.I.
# Power BI
# SAE
# SAS
# Ph.D.
# ------------------------------------------------------------------------------------------------------------------------ 10000

# %%
my_skill_set = dict( Counter(skill_set).most_common(300) )
my_skill_set
# Out:
# {'Python': 7645,
#  'R': 5665,
#  'machine learning': 5227,
#  'SQL': 5034,
#  'Data Scientist': 4213,
#  'Computer Science': 3384,
#  'Statistics': 3275,
#  'color': 3195,
#  'religion': 3147,
#  'race': 3052,
#  'data science': 3004,
#  'statistics': 2974,
#  'sexual orientation': 2803,
#  'Spark': 2559,
#  'Hadoop': 2508,
#  'Job': 2382,
#  'data analysis': 2339,
#  'Machine Learning': 2331,
#  'Data Science': 2254,
#  'data mining': 2211,
#  'Java': 2181,
#  'Tableau': 2090,
#  'sex': 2021,
#  'disability': 2011,
#  'SAS': 1979,
#  'Mathematics': 1954,
#  'analysis': 1831,
#  'Engineering': 1831,
#  'modeling': 1798,
#  'origin': 1725,
#  'receive consideration': 1645,
#  'without regard': 1571,
#  'statistical analysis': 1512,
#  'computer science': 1503,
#  'AWS': 1479,
#  'predictive modeling': 1469,
#  'analytics': 1405,
#  'Scala': 1388,
#  'AI': 1359,
#  'age': 1322,
#  'PhD': 1293,
#  'statistical': 1288,
#  'algorithms': 1281,
#  'data scientist': 1261,
#  'optimization': 1235,
#  'communication skills': 1221,
#  'Hive': 1220,
#  'advanced analytics': 1114,
#  'quantitative field': 1109,
#  'engineering': 1076,
#  'regression': 1074,
#  'data visualization': 1072,
#  'mathematics': 1063,
#  'deep learning': 1034,
#  'NLP': 1030,
#  'problem solving': 1023,
#  'data analytics': 1015,
#  'predictive models': 1004,
#  'visualization': 1002,
#  'Analytics': 934,
#  'statistical modeling': 922,
#  'clustering': 913,
#  'Economics': 897,
#  'artificial intelligence': 845,
#  'predictive analytics': 812,
#  'big data': 793,
#  'development': 790,
#  'MS': 777,
#  'ML': 772,
#  'Physics': 772,
#  'Linux': 765,
#  'problem-solving': 763,
#  'genetic information': 758,
#  'C++': 749,
#  'data': 746,
#  'classification': 745,
#  'Operations Research': 736,
#  'engineers': 723,
#  'testing': 722,
#  'interpersonal': 719,
#  'gender': 711,
#  'machine learning models': 709,
#  'design': 708,
#  'Bachelor’s degree': 702,
#  'TensorFlow': 701,
#  'data scientists': 699,
#  'programming languages': 684,
#  'reporting': 677,
#  'natural language processing': 675,
#  'Ph.D.': 668,
#  'marital': 664,
#  'contact': 655,
#  'expression': 648,
#  'Deep Learning': 648,
#  'statistical methods': 638,
#  'neural networks': 632,
#  'statistical models': 628,
#  'dashboards': 627,
#  'simulation': 620,
#  'Master’s degree': 619,
#  'economics': 613,
#  'relational databases': 603,
#  "Bachelor's degree": 601,
#  "Master's degree": 599,
#  'So': 595,
#  'agile': 585,
#  'Applied Mathematics': 581,
#  'operations research': 578,
#  'implementation': 575,
#  'Your': 574,
#  'marketing': 571,
#  'data modeling': 570,
#  'Career': 554,
#  'Agile': 551,
#  'Big Data': 550,
#  'Oracle': 548,
#  'Math': 546,
#  'decision trees': 545,
#  'data management': 543,
#  'Natural Language Processing': 533,
#  'Tensorflow': 519,
#  'ETL': 518,
#  'Time': 516,
#  'Data Scientists': 514,
#  'consulting': 513,
#  'CA': 513,
#  'Artificial Intelligence': 507,
#  'programming': 501,
#  'Keras': 495,
#  'SPSS': 492,
#  'Azure': 486,
#  'extract': 482,
#  'Veteran': 480,
#  'Position': 475,
#  'physics': 470,
#  'data models': 465,
#  'machine learning algorithms': 464,
#  'North America': 458,
#  'Matlab': 454,
#  'quantitative discipline': 446,
#  'software development': 444,
#  'Excel': 440,
#  'Masters': 440,
#  'so': 439,
#  'databases': 435,
#  'Pig': 433,
#  'technology': 427,
#  'feature engineering': 426,
#  'quantitative analysis': 422,
#  'RESPONSIBILITIES': 422,
#  'NoSQL': 420,
#  'creed': 416,
#  'Pandas': 415,
#  'statistical techniques': 413,
#  'test': 411,
#  'business problems': 410,
#  'Technology': 407,
#  'database': 406,
#  'scikit-learn': 402,
#  'forecasting': 402,
#  'building': 398,
#  'Bachelors': 395,
#  'CyberCoders': 390,
#  'Kafka': 386,
#  'Overview': 384,
#  'SCI': 381,
#  'reports': 379,
#  'BS': 378,
#  'data collection': 376,
#  'written and verbal communication skills': 376,
#  'MapReduce': 376,
#  'analytical skills': 375,
#  'Finance': 374,
#  'identify': 372,
#  'finance': 371,
#  'data structures': 371,
#  'Perl': 356,
#  'automation': 354,
#  'data visualization tools': 354,
#  'Unix': 354,
#  'MATLAB': 353,
#  'MA': 353,
#  'MySQL': 352,
#  'data engineering': 351,
#  'PyTorch': 342,
#  'statistical analyses': 341,
#  'business intelligence': 339,
#  'mining': 337,
#  'collect': 332,
#  'pandas': 331,
#  'software engineering': 328,
#  'text mining': 326,
#  'analyze': 325,
#  'Medical': 325,
#  'training': 323,
#  'Travel': 321,
#  'algorithmic': 317,
#  'Marketing': 316,
#  'programming language': 315,
#  'Teradata': 314,
#  'Advanced degree': 313,
#  'critical thinking': 313,
#  'review': 312,
#  'research': 312,
#  'visualizations': 312,
#  'data processing': 310,
#  'model development': 308,
#  'Power BI': 306,
#  'analytical': 305,
#  'product managers': 298,
#  'Amazon': 298,
#  'math': 294,
#  'machine learning techniques': 293,
#  'experimental design': 292,
#  'data engineers': 291,
#  'Data Analytics': 290,
#  'integrity': 290,
#  'patterns': 289,
#  'Docker': 288,
#  'TS': 286,
#  'scripting languages': 285,
#  'States': 285,
#  'hypothesis testing': 280,
#  'Git': 280,
#  'Vision': 279,
#  'anomaly detection': 274,
#  '401k': 273,
#  'ancestry': 273,
#  'random forest': 273,
#  'data manipulation': 272,
#  'STEM': 272,
#  'data exploration': 271,
#  'JavaScript': 271,
#  'SVM': 269,
#  'statistical software': 269,
#  'HBase': 268,
#  'Business Intelligence': 267,
#  'data visualizations': 266,
#  'IoT': 266,
#  'Identify': 265,
#  'programming skills': 264,
#  'S3': 262,
#  'python': 262,
#  'Information Technology': 262,
#  'decision making': 259,
#  'communication': 258,
#  'big data technologies': 258,
#  'processing': 257,
#  'Disability': 254,
#  "Master's Degree": 254,
#  'mathematical': 253,
#  'Cassandra': 252,
#  'Dental': 252,
#  'R.': 252,
#  'Redshift': 251,
#  'MongoDB': 251,
#  '2019': 251,
#  'analyze data': 249,
#  'data pipelines': 249,
#  'quantitative': 248,
#  'C/C++': 248,
#  'Advanced Analytics': 247,
#  'Microsoft Office': 247,
#  'software engineers': 247,
#  'Neural Networks': 247,
#  "Bachelor's Degree": 246,
#  'Data Mining': 246,
#  'verbal and written communication skills': 244,
#  'Apache Spark': 243,
#  'A/B testing': 243,
#  'prediction': 238,
#  'gender expression': 235,
#  'GCP': 235,
#  'BI': 234,
#  'applied mathematics': 233,
#  'data warehouse': 233,
#  'machine learning methods': 233,
#  'time series analysis': 232,
#  'supply chain': 231,
#  'NumPy': 230,
#  'teamwork': 227,
#  'team members': 225,
#  'matplotlib': 223,
#  'structured and unstructured data': 223,
#  'distributed computing': 222,
#  'USA': 220,
#  'Econometrics': 220,
#  'Applied Math': 220,
#  'large datasets': 220,
#  'visualization tools': 219,
#  'Master’s Degree': 219,
#  'information retrieval': 218,
#  'Establish': 217,
#  'HDFS': 216,
#  'econometrics': 215,
#  'data quality': 215,
#  'SQL Server': 215,
#  'Machine learning': 210,
#  'Google Analytics': 209,
#  'services': 209}

# %%
skill_set_lower = set([str(tem).lower() for tem in my_skill_set.keys()])

# %% [markdown]
# # ============================================================
# ## Hierarchical Relation Extract  base on Dependency analysis

# %%
delimiters = "？","?", "！","!",".","。","；",";","\n","\r","·","•"," -"," o"
regexPattern = '|'.join(map(re.escape, delimiters))
regexPattern
# Out:
# '？|\\?|！|!|\\.|。|；|;|\\\n|\\\r|·|•|\\ \\-|\\ o'

# %%
def is_father( word, root ):
    if word == root:
        return True
    
    while word != word.head:
        word = word.head
        if word == root:
            return True
    
    return False

# %%
def if_doc_id_is_left_punct( doc, my_id ):
    for ent in doc:
        if ent.idx == my_id and ent.is_left_punct:
            return True
    
    return False

# %%
def if_doc_id_is_right_punct( doc, my_id ):
    for ent in doc:
        if ent.idx == my_id and ent.is_right_punct:
            return True
    
    return False

# %%
def is_conj_or_appos( tem, word ):
    if tem == word:
        return False
    
    while tem.head != tem:
        if tem.head == word and (tem.dep_ == 'compound' or tem.dep_ == 'conj'):
            return True
        tem = tem.head
        
    return False

# %% [markdown]
# # Dependency analysis testing

# %%
def get_Date_attribute( string ):
    print( 'SENTENCE:',string )
    doc = nlp( string )

#     print( [ '[' + str(token) + ']' for token in doc.ents if token.root.ent_type_ == 'SKILL'] )
#     print( [ '[' + str(token) + ']' for token in doc.ents] )
    displacy.render(doc, style='dep', jupyter=True)

# %%
ss = 'Experience with large data sets and distributed computing (Hive/Hadoop) a plus'

ss = 'Experience with Hadoop stack (HIVE, Pig, Hadoop streaming) and/or Spark a plus'
ss = 'Build tools and support structures needed to analyze data, perform elements of data cleaning, feature selection and feature engineering and organize experiments in conjunction with best practices'
# ss = 'Strong programming skills (preferably with Python), and some C++ knowledge and experience'
# ss 
# ss = 'Proficiency in SQL and one of Python/R for programming, data analysis, and modelling'

# ss = 'We are looking for a very motivated technical analyst to help build the framework of data reporting and analysis for our licensing partners – Labels and Publishers'

ss = 'Experience with languages used for querying (like SQL/Hive)'
ss = 'Advanced knowledge of SAS, C ##, Java, Perl, Python, Scala and r programming'
ss = 'Three years’ experience working with one of the following programming languages: Python, Java, C#, Javascript, R'
ss = 'Web Frameworks (like Django, Flask)'

ss = 'Data Scientist role to work on model building and feature engineering for client protection AI/ML Projects'
ss = 'Machine learning algorithms (supervised, unsupervised learning)'
ss = 'Hadoop stack (HIVE, Pig, Hadoop streaming)'
# ss = 'We are looking for highly motivated Data Scientists with a strong background in applied statistics, Machine Learning and large scale data analysis'

# ss = 'js Basic proficiency in SQL Able to implement and utilize advanced statistical and machine learning techniques (GLMs, PCA, cluster analyses, ARIMA, ETS, decision trees, SVM, neural networks, ensemble methods, etc) Basic familiarity with project management tools (Asana, Basecamp, LiquidPlanner)'
get_Date_attribute(ss)
# Out:
# SENTENCE: Hadoop stack (HIVE, Pig, Hadoop streaming)
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="9612d1da7d5341a7b262c20b78b29ba3-0" class="displacy" width="1100" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Hadoop</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">stack (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">HIVE,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">Pig,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">Hadoop</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">streaming)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9612d1da7d5341a7b262c20b78b29ba3-0-0" stroke-width="2px" d="M70,177.0 C70,89.5 220.0,89.5 220.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9612d1da7d5341a7b262c20b78b29ba3-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9612d1da7d5341a7b262c20b78b29ba3-0-1" stroke-width="2px" d="M245,177.0 C245,89.5 395.0,89.5 395.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9612d1da7d5341a7b262c20b78b29ba3-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">appos</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M395.0,179.0 L403.0,167.0 387.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9612d1da7d5341a7b262c20b78b29ba3-0-2" stroke-width="2px" d="M420,177.0 C420,89.5 570.0,89.5 570.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9612d1da7d5341a7b262c20b78b29ba3-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">npadvmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M570.0,179.0 L578.0,167.0 562.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9612d1da7d5341a7b262c20b78b29ba3-0-3" stroke-width="2px" d="M770,177.0 C770,89.5 920.0,89.5 920.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9612d1da7d5341a7b262c20b78b29ba3-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,179.0 L762,167.0 778,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9612d1da7d5341a7b262c20b78b29ba3-0-4" stroke-width="2px" d="M245,177.0 C245,2.0 925.0,2.0 925.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9612d1da7d5341a7b262c20b78b29ba3-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">parataxis</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M925.0,179.0 L933.0,167.0 917.0,167.0" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# # testing on 300 sample

# %%
ind = 0

total_link_list = []
total_link_set = set()

for root,dirs,files in os.walk(r"../JD_files"):
    for file in files:
        ind += 1
        
        my_file = open( os.path.join(root,file),encoding = 'utf-8' )
        my_string = my_file.readlines()
        
        doc_sentences = '\n'.join(my_string[1:])
        doc_sentences = remove_urls(doc_sentences)
        
        doc_sentences = doc_sentences.replace('www.','https://www.')
        doc_sentences = remove_urls(doc_sentences)

        doc_sentences = doc_sentences.replace('e.g.','like').replace('i.e.','like').replace('.)',')')
        
        delimiters = "？","?", "！","!",".","。","；",";","\n","\r","·","•"," -","*"
        regexPattern = '|'.join(map(re.escape, delimiters))
        
        sentences = [str(sentence).strip() for sentence in re.split( regexPattern, doc_sentences ) if len(str(sentence).strip()) > 0]
        
        for string in sentences:
            if (string[0] == '-' or string[0] == '*') and len(string) > 1:
                string = string[1:]
            
            doc = nlp( str(string) )
            
            my_chunks_list = []
            roor_chunks_dict = {}

            for chunk in doc.ents:
                if chunk.root.ent_type_ == 'SKILL' : # and chunk.text.lower() in skill_set_lower
                    my_chunks_list.append( chunk.root )
                    roor_chunks_dict[ chunk.root ] = chunk
                    
            
            if len( my_chunks_list ) > 1:            
                Total_List = []
                for word in my_chunks_list:
                    #####################################################################################
                    ## prep --> pobj
                    if word.dep_ == 'pobj' and word.head.dep_ == 'prep':
                        root_word = word.head.head
                        
                        if root_word in my_chunks_list:
#                             print( roor_chunks_dict[word] + '-->' + roor_chunks_dict[word.head.head] )
                            Total_List.append( ( word, root_word ) )
                    
                        if 'N' in word.tag_:
                            for tt in my_chunks_list:
                                if tt.head == root_word and (tt.dep_ == 'compound' or tt.dep_ == 'conj'):
    #                                     print( roor_chunks_dict[word] + '-->' + roor_chunks_dict[tt] )
                                    Total_List.append( ( word, tt) )
        
                    
                    #####################################################################################
                    ## appos
                    elif word.dep_ == 'appos' and ( if_doc_id_is_left_punct( doc, word.idx-1 ) or if_doc_id_is_right_punct( doc, word.idx+1 ) ):
                        root_word = word.head
                        
                        if root_word in my_chunks_list:
#                             print( roor_chunks_dict[word] + '-->' + roor_chunks_dict[word.head.head] )
                            Total_List.append( ( word, root_word ) )
                    
                        if 'N' in word.tag_:
                            for tt in my_chunks_list:
                                if tt.head == root_word and (tt.dep_ == 'compound' or tt.dep_ == 'conj'):
    #                                     print( roor_chunks_dict[word] + '-->' + roor_chunks_dict[tt] )
                                    Total_List.append( ( word, tt) )
                    

                
                Total_List_expend = []
                for tup in Total_List:
                    for tem in my_chunks_list:
                        if is_conj_or_appos( tem, tup[0] ):
                            Total_List_expend.append( ( tem, tup[1] ) )
                    
                Total_List = Total_List + Total_List_expend
                
                print_flag = True
                for tup in Total_List:
                    if str(roor_chunks_dict[tup[0]]).lower() in skill_set_lower and str(roor_chunks_dict[tup[1]]).lower() in skill_set_lower and 'degree' not in str(roor_chunks_dict[tup[1]]).lower() and 'master' not in str(roor_chunks_dict[tup[1]]).lower() and 'phd' not in str(roor_chunks_dict[tup[1]]).lower() and 'ms' != str(roor_chunks_dict[tup[1]]).lower() and 'bs' != str(roor_chunks_dict[tup[1]]).lower():
                        if  str(roor_chunks_dict[tup[0]]).lower() + '-->' + str(roor_chunks_dict[tup[1]]).lower() not in total_link_set:       
                    
                            if print_flag:
                                print( '=' * 120 )
                                print( 'SENTENCE:', string )
#                                 print( 'my_chunks_list', [str(roor_chunks_dict[tem]) for tem in my_chunks_list] )
                                print()
                                print_flag = False

                            print( str(roor_chunks_dict[tup[0]]) + '-->' + str(roor_chunks_dict[tup[1]]) )
                            total_link_set.add( str(roor_chunks_dict[tup[0]]).lower() + '-->' + str(roor_chunks_dict[tup[1]]).lower() )
                            total_link_list.append( ( str(roor_chunks_dict[tup[0]]) , str(roor_chunks_dict[tup[1]]) ) )

        my_file.close()

        if ind % 500 == 0:
            print( '=' * 120 ,ind )
            
        if ind > 100:
            break
# Out:
# ========================================================================================================================
# SENTENCE: Experience with predictive modeling (classification, regression, parameter tuning, feature selection, validation, performance reporting), preferably with multiple techniques
#
# classification-->predictive modeling
# regression-->predictive modeling
# ========================================================================================================================
# SENTENCE: Bachelor’s degree in Finance, Mathematics (Economics) or a closely related quantitative field
#
# Economics-->Mathematics
# Economics-->quantitative field
# ========================================================================================================================
# SENTENCE: Design, build and support algorithms of data transformation, conversion, computation on Hadoop, Spark and other distributed Big Data Systems
#
# Hadoop-->algorithms
# Spark-->algorithms
# ========================================================================================================================
# SENTENCE: Hadoop stack (HIVE, Pig, Hadoop streaming) and MapReduce
#
# HIVE-->Hadoop
# HIVE-->MapReduce
# Pig-->Hadoop
# Pig-->MapReduce
# ========================================================================================================================
# SENTENCE: Knowledge of one or more machine learning or statistical modeling tools such as R, SAS, MATLAB, or Python (scikit-learn, Theano)
#
# R-->machine learning
# SAS-->machine learning
# MATLAB-->machine learning
# Python-->machine learning
# ========================================================================================================================
# SENTENCE: Applied machine learning experience on large datasets/sparse data with structured and unstructured data
#
# structured and unstructured data-->machine learning
# ========================================================================================================================
# SENTENCE: Knowledge of statistical tools and business reporting (Qlikview, Tableau, DataMiner, R)
#
# R-->Tableau
# ========================================================================================================================
# SENTENCE: Big data technologies such as Hadoop, MapReduce, Hive, Pig
#
# Hadoop-->Big data technologies
# MapReduce-->Big data technologies
# Hive-->Big data technologies
# Pig-->Big data technologies
# ========================================================================================================================
# SENTENCE: RxDataScience, Inc is a premier data science company based on analytics as a software service model and provides Artificial Intelligence (AI) based advanced analytics solutions and services
#
# AI-->Artificial Intelligence
# ========================================================================================================================
# SENTENCE: Data Scientist Required Experience & Qualifications: Familiar with Hadoop, Spark or other Big Data Platforms Familiar with Cloud-based Machine Learning platforms such as Azure ML or Spark MLib etc
#
# Spark-->Machine Learning
# ========================================================================================================================
# SENTENCE: Familiar with data visualization and exploration tools, such as Tableau and Power BI Experience with building and deploying Machine Learning models on Microsoft Azure Experience with Databricks Environment Experience with writing SQL queries on structured and unstructured data sets Proficiency in statistical packages and standard libraries in Python and R Proficiency with Machine Learning Algorithms (supervised and unsupervised) Familiar with connecting different types of datasets in various forms and can handle potentially incomplete data sources Benefits: Unlimited PTO 401K match program (4%) Health/Medical/Dental benefits Real Opportunity for growth Bonus structure Send your resume to k
#
# Tableau-->data visualization
# Power BI-->data visualization
# SQL-->data visualization
# structured and unstructured data-->data visualization
# ========================================================================================================================
# SENTENCE: Excellent programming skills in Python
#
# Python-->programming skills
# ========================================================================================================================
# SENTENCE: This position requires the individual to work with large data sets using programming languages such as R, Python, SQL while thriving in a team-based, fast paced start-up environment
#
# R-->programming languages
# Python-->programming languages
# SQL-->programming languages
# ========================================================================================================================
# SENTENCE: Experienced with scripting languages such as R, Shiny apps, Python
#
# R-->scripting languages
# Python-->scripting languages
# ========================================================================================================================
# SENTENCE: Qualifications:BA/BS in Data Science, Math, Statistics Computer Science, Actuarial Science or related disciplineProfessional certifications in the fields of Data Science, Machine Learning, Predictive Analytics, AI, Healthcare analysis, and other related disciplines, preferred5 – 8 years of relevant work experience, preferably in a healthcare environment, requiredA minimum of 3 years’ experience in building & maintaining enterprise-level analytics and business intelligence solutions, requiredExtensive experience in using/managing large amounts of disparate data within a healthcare payer, requiredStrong health care payer domain knowledge, requiredStrong experience in performing provider and specialty vendor analytics, membership analytics, and financial analytics, preferredStrong experience and competency using statistical tools and programming packages (R, Python, SAS Enterprise Miner), requiredWorking knowledge of and experience with Big Data implementations, preferredKnowledge of Apache Spark, Hadoop & related native machine learning libraries, and other specialty modules, preferredGood presentation skills and the ability to comfortably tell a story based on analytics and findings to a broad audience, preferredPossess exceptional written and verbal communication skills, requiredStrong desire to change things up, to challenge the old ways of doing analytics, and willing to train and mentor others, requiredKnowledge of emerging big data technologies, on building data pipelines, and on predictive and machine learning techniques, requiredGood domain knowledge in the healthcare payer world
#
# Apache Spark-->written and verbal communication skills
# Hadoop-->written and verbal communication skills
# ========================================================================================================================
# SENTENCE: Machine learning (ML) has been strategic to Amazon from the early years
#
# ML-->Machine learning
# ========================================================================================================================
# SENTENCE: Substantial experience in SAS or SQL, and other programming languages
#
# SAS-->programming languages
# ========================================================================================================================
# SENTENCE: Advanced, in-depth specialization in mathematical analysis methods, predictive modeling, statistical analyses, and big data technologies such as Python, R, Hadoop or Hive
#
# Python-->big data technologies
# R-->big data technologies
# ========================================================================================================================
# SENTENCE: Extensive background in data mining and statistical analysis and skills, such as distributions, statistical testing, regression, etc)
#
# regression-->data mining
# regression-->statistical analysis
# ========================================================================================================================
# SENTENCE: Experience building machine learning training and inference pipelines in the cloud using on or more major programming language (Python, Java), ML libraries (XGBoost, etc) and one Deep Learning Framework (PyTorch, Tensor Flow, MXNet, etc)
#
# Python-->programming language
# ========================================================================================================================
# SENTENCE: Have experience with Big Data including Hadoop, Spark, Kafka
#
# Hadoop-->Big Data
# Spark-->Big Data
# Kafka-->Big Data
# ========================================================================================================================
# SENTENCE: MINIMUM EDUCATIONAL REQUIREMENTS Advanced degree in Data Science or Quantitative field (or Bachelor's degree with 5+ years' experience) ESSENTIAL SKILLS REQUIRED Passion for solving complex problems and searching for the best approach to a problem Strong critical thinking skills Strong ability to quickly grasp deep understanding of our business Expert in building machine learning and statistical models (classification, regression, clustering, etc) Profound understanding of statistics and machine learning Advanced proficiency in a high-level programming language such as Python Advanced proficiency working with databases (NoSQL) and applications to create ETL pipelines in SQL and other languages High skills in using data science languages and frameworks such as Python (pandas, scikit-learn, etc) R, etc
#
# programming language-->machine learning
# NoSQL-->databases
# SQL-->ETL
# pandas-->Python
# scikit-learn-->Python
# R-->Python
# ========================================================================================================================
# SENTENCE: Experience in stochastic modeling, machine learning, and other advanced mathematical techniques (like, neural nets, simulation, graph analysis)
#
# machine learning-->simulation
# ========================================================================================================================
# SENTENCE: Experience with building natural language processing (NLP) algorithms
#
# NLP-->natural language processing
# ========================================================================================================================
# SENTENCE: 150kLocation: Detroit, MichiganSkills and Experience:-Minimum of 9 years of advanced analytics-Fluent in Python (Development) and R-Experience working with Agile a plus Experience with AWZ, Spark, Databricks, and other cloud tools and platforms-Data Extraction-Data Mining ( PowerBi, SAS, JMP)-Data Reducing-Predictive Modeling-Statistical Foundations-Developing Analytic models (word2vec, LDA)-Correlation Analysis-Education, Licenses, Certifications-System Simulation (Markov, Monte Carlo)-MapReduce Benefits-401(k) Retirement Savings Plan-Cash Balance Pension Plan-Medical/Dental/Life Insurance-Health Savings Account-Domestic Partners Coverage-Full complement of personal and professional benefitsIf you are interested in this position, please contact me (Marie Alexandra Osmena) at (646)863-7573 and send your resume to my email address
#
# Development-->Python
# ========================================================================================================================
# SENTENCE: Fluent in Python (Development) and R
#
# Development-->R
# ========================================================================================================================
# SENTENCE: At least 5 years of programming experience in Python or Scala
#
# Python-->Scala
# ========================================================================================================================
# SENTENCE: Researches and identifies Machine Learning (ML) and Natural Language Processing (NLP) methods and algorithms to solve specific problems to improve user experience on IP & Science data and websites
#
# ML-->Natural Language Processing
# ========================================================================================================================
# SENTENCE: Experience with programming languages such as Java and Python
#
# Java-->programming languages
# ========================================================================================================================
# SENTENCE: Required Education: Bachelors in Analytics, Data Science, Statistics, Mathematics, Computer Science or a related field
#
# Analytics-->Bachelors
# Data Science-->Bachelors
# Statistics-->Bachelors
# Mathematics-->Bachelors
# Computer Science-->Bachelors
# ========================================================================================================================
# SENTENCE: Can include all components from data checks and manipulation through to modelling and other advanced analytics (typically done in Spark / Scala or Teradata for data preparation and Spark / Scala or R for advanced analytics)
#
# advanced analytics-->Scala
# ========================================================================================================================
# SENTENCE: A degree in a quantitative discipline like actuarial studies, mathematics / statistics, engineering, computer science etc
#
# mathematics-->quantitative discipline
# statistics-->quantitative discipline
# engineering-->quantitative discipline
# computer science-->quantitative discipline
# ========================================================================================================================
# SENTENCE: Good grasp of classical statistical methods, such as fitting regression models, inference testing and sampling Strong programming skills in Python
#
# Python-->statistical methods
# ========================================================================================================================
# SENTENCE: Support the development of consulting products such as proprietary customer experience scores and marketing optimization solutions Maintain our stellar reputation with our clients and drive >80 client NPSLeverage a mixture of data science methods such as SVM, neural nets, decision trees, and regression models to deliver proprietary uplift model solutionsSupport the introduction and advancement of decision science throughout our contact center engagementRecommend and introduce new methods where relevant Resource planningRecommend required resources to managersAlign required resources to client schedulesMentor data engineers and architects on requirements Develop requirements and technical specifications documents for use by engineers DeliveryRecommend project timelines to managersDrive on-time delivery and identify and escalate risks to managersSupport attainment of annual goals for client satisfactionDeliver your own solutions while collaborating on other projects What you’ll bring to us :Masters in Statistics, Economics, IE/OR, Computer Science, Applied Mathematics or related field is required
#
# data engineers-->identify
# ========================================================================================================================
# SENTENCE: Familiarity with data visualization (like R, ggplot, ggobi, Tableau)
#
# R-->data visualization
# ========================================================================================================================
# SENTENCE: Experience with traditional as well as modern machine learning/statistical techniques, including Regression, Classification, Regularization, Ensemble Methods, Deep Neural Network, Causal Inference, and Hypothesis Testing
#
# Regression-->statistical techniques
# Classification-->statistical techniques
# Hypothesis Testing-->statistical techniques
# ========================================================================================================================
# SENTENCE: 3+ years experience with programming languages, such as Python, R, Java, C/C++
#
# C/C++-->programming languages
# ========================================================================================================================
# SENTENCE: Research and develop statistical models for data analysis
#
# data analysis-->statistical models
# ========================================================================================================================
# SENTENCE: Employ sophisticated analytics programs, machine learning, and statistical methods for predictive and prescriptive modeling, forecasting, and simulations
#
# forecasting-->statistical methods
# ========================================================================================================================
# SENTENCE: Proficient in machine learning and data mining packages in Python
#
# Python-->data mining
# ========================================================================================================================
# SENTENCE: Knowledge of the latest ML techniques like deep learning is a plus, but not a requirement
#
# deep learning-->ML
# ========================================================================================================================
# SENTENCE: Expertise in one or more scripting languages such as Perl or Python and one or more programming languages such as Java or Scala
#
# scripting languages-->programming languages
# Perl-->scripting languages
# Scala-->programming languages
# ========================================================================================================================
# SENTENCE: Able to select several potential appropriate modeling approaches for a given analytic problem (machine learning methods such as ensemble models, decision trees
#
# decision trees-->machine learning
# ========================================================================================================================
# SENTENCE: If you have experience with Salesforce, Marketo, Google Analytics, and/or Tableau… great
#
# Google Analytics-->Tableau
# ========================================================================================================================
# SENTENCE: Python (Scala, Unix)
#
# Scala-->Python
# ========================================================================================================================
# SENTENCE: Applied experience with machine learning on large datasets (Spark)
#
# large datasets-->machine learning
# ========================================================================================================================
# SENTENCE: Roles & Responsibilities Work with the data science team to analyze large data sets and develop custom models/algorithms to uncover trends, patterns and insights Support the development and evolution of a cutting-edge data warehouse and BI platform Interact with product and service teams to identify questions and issues for data analysis and experiments Design models and statistical analyses to answer specific questions for internal and external customers Requirements Azure Big Data implementation experience Data Visualization experience using Power BI Master's Degree in Data Science or equivalent Development experience in Python, Java, C or equivalent programming language SQL Server, SQL queries and experience in System Integration and Data Transformation/ETL Proficiency in data mining, statistical analysis and modeling of large scale, complex data sets Critical thinking and problem solving Experience working in a team-oriented, collaborative environment This is an opportunity for an established Cloud Data Scientist to work with a growing industry leader
#
# data mining-->ETL
# statistical analysis-->ETL
# modeling-->ETL
# ========================================================================================================================
# SENTENCE: Prepares complex data sets for use in advanced analytics (in design and testing of statistical models and complex measurement)
#
# statistical models-->design
# statistical models-->testing
# ========================================================================================================================
# SENTENCE: Familiarity with Linux and/or Spark preferred
#
# Linux-->Spark
# ========================================================================================================================
# SENTENCE: Experience with machine learning methods like random forests, logistic regression, neural networks, k-nearest neighbors, etc…
#
# neural networks-->machine learning

# %% [markdown]
# # print all

# %%
ind = 0

total_link_list = []
total_link_set = set()

for root,dirs,files in os.walk(r"../JD_files"):
    for file in files:
        ind += 1
        
        my_file = open( os.path.join(root,file),encoding = 'utf-8' )
        my_string = my_file.readlines()
        
        doc_sentences = '\n'.join(my_string[1:])
        doc_sentences = remove_urls(doc_sentences)
        
        doc_sentences = doc_sentences.replace('www.','https://www.')
        doc_sentences = remove_urls(doc_sentences)

        doc_sentences = doc_sentences.replace('e.g.','like').replace('i.e.','like').replace('.)',')')
        
        delimiters = "？","?", "！","!",".","。","；",";","\n","\r","·","•"," -","*"
        regexPattern = '|'.join(map(re.escape, delimiters))
        
        sentences = [str(sentence).strip() for sentence in re.split( regexPattern, doc_sentences ) if len(str(sentence).strip()) > 0]
        
        for string in sentences:
            if (string[0] == '-' or string[0] == '*') and len(string) > 1:
                string = string[1:]
            
            doc = nlp( str(string) )
            
            my_chunks_list = []
            roor_chunks_dict = {}

            for chunk in doc.ents:
                if chunk.root.ent_type_ == 'SKILL' : # and chunk.text.lower() in skill_set_lower
                    my_chunks_list.append( chunk.root )
                    roor_chunks_dict[ chunk.root ] = chunk
                    
            
            if len( my_chunks_list ) > 1:            
                Total_List = []
                for word in my_chunks_list:
                    #####################################################################################
                    ## prep --> pobj
                    if word.dep_ == 'pobj' and word.head.dep_ == 'prep':
                        root_word = word.head.head
                        
                        if root_word in my_chunks_list:
#                             print( roor_chunks_dict[word] + '-->' + roor_chunks_dict[word.head.head] )
                            Total_List.append( ( word, root_word ) )
                    
                        elif 'N' in word.tag_:
                            for tt in my_chunks_list:
                                if tt.head == root_word and (tt.dep_ == 'compound'):
    #                                     print( roor_chunks_dict[word] + '-->' + roor_chunks_dict[tt] )
                                    Total_List.append( ( word, tt) )
        
                    
                    #####################################################################################
                    ## appos
                    elif word.dep_ == 'appos' and ( if_doc_id_is_left_punct( doc, word.idx-1 ) or if_doc_id_is_right_punct( doc, word.idx+1 ) ):
                        root_word = word.head
                        
                        if root_word in my_chunks_list:
#                             print( roor_chunks_dict[word] + '-->' + roor_chunks_dict[word.head.head] )
                            Total_List.append( ( word, root_word ) )
                    
                        elif 'N' in word.tag_:
                            for tt in my_chunks_list:
                                if tt.head == root_word and (tt.dep_ == 'compound'):
    #                                     print( roor_chunks_dict[word] + '-->' + roor_chunks_dict[tt] )
                                    Total_List.append( ( word, tt) )
                    

                
                Total_List_expend = []
                for tup in Total_List:
                    for tem in my_chunks_list:
                        if is_conj_or_appos( tem, tup[0] ):
                            Total_List_expend.append( ( tem, tup[1] ) )
                    
                Total_List = Total_List + Total_List_expend
                
                print_flag = True
                for tup in Total_List:
                    if str(roor_chunks_dict[tup[0]]).lower() in skill_set_lower and str(roor_chunks_dict[tup[1]]).lower() in skill_set_lower and 'degree' not in str(roor_chunks_dict[tup[1]]).lower() and 'master' not in str(roor_chunks_dict[tup[1]]).lower() and 'bachelor' not in str(roor_chunks_dict[tup[1]]).lower() and 'phd' not in str(roor_chunks_dict[tup[1]]).lower() and 'ms' != str(roor_chunks_dict[tup[1]]).lower() and 'bs' != str(roor_chunks_dict[tup[1]]).lower():
                        if  str(roor_chunks_dict[tup[0]]).lower() + '-->' + str(roor_chunks_dict[tup[1]]).lower() not in total_link_set:       
                    
#                         if print_flag:
#                             print( '=' * 120 )
#                             print( 'SENTENCE:', string )
#                             print( 'my_chunks_list', [str(roor_chunks_dict[tem]) for tem in my_chunks_list] )
#                             print_flag = False

                            print( str(roor_chunks_dict[tup[0]]) + '-->' + str(roor_chunks_dict[tup[1]]) )
                            total_link_set.add( str(roor_chunks_dict[tup[0]]).lower() + '-->' + str(roor_chunks_dict[tup[1]]).lower() )
                            total_link_list.append( ( str(roor_chunks_dict[tup[0]]) , str(roor_chunks_dict[tup[1]]) ) )

        my_file.close()

        if ind % 500 == 0:
            print( '=' * 120 ,ind )
# Out:
# classification-->predictive modeling
# regression-->predictive modeling
# Economics-->Mathematics
# Hadoop-->algorithms
# Spark-->algorithms
# HIVE-->Hadoop
# Pig-->Hadoop
# R-->machine learning
# SAS-->machine learning
# MATLAB-->machine learning
# Python-->machine learning
# structured and unstructured data-->machine learning
# Hadoop-->Big data technologies
# MapReduce-->Big data technologies
# Hive-->Big data technologies
# Pig-->Big data technologies
# AI-->Artificial Intelligence
# Spark-->Machine Learning
# Tableau-->data visualization
# Power BI-->data visualization
# SQL-->data visualization
# structured and unstructured data-->data visualization
# Python-->programming skills
# R-->programming languages
# Python-->programming languages
# SQL-->programming languages
# R-->scripting languages
# Python-->scripting languages
# ML-->Machine learning
# Python-->big data technologies
# R-->big data technologies
# regression-->data mining
# Python-->programming language
# Hadoop-->Big Data
# Spark-->Big Data
# Kafka-->Big Data
# programming language-->machine learning
# NoSQL-->databases
# SQL-->ETL
# pandas-->Python
# scikit-learn-->Python
# R-->Python
# NLP-->natural language processing
# Development-->Python
# Java-->programming languages
# mathematics-->quantitative discipline
# statistics-->quantitative discipline
# engineering-->quantitative discipline
# computer science-->quantitative discipline
# Python-->statistical methods
# R-->data visualization
# Regression-->statistical techniques
# Classification-->statistical techniques
# Hypothesis Testing-->statistical techniques
# C/C++-->programming languages
# data analysis-->statistical models
# forecasting-->statistical methods
# Python-->data mining
# deep learning-->ML
# Perl-->scripting languages
# Scala-->programming languages
# decision trees-->machine learning
# Scala-->Python
# large datasets-->machine learning
# data mining-->ETL
# statistical analysis-->ETL
# modeling-->ETL
# statistical models-->design
# neural networks-->machine learning
# Spark-->big data technologies
# processing-->analysis
# analysis-->analysis
# dashboards-->reporting
# MS-->SQL
# predictive modeling-->Data Scientist
# advanced analytics-->Data Scientist
# Azure-->ML
# AWS-->ML
# machine learning-->modeling
# Scala-->SQL
# Python-->Data Science
# Python-->automation
# hypothesis testing-->statistics
# quantitative discipline-->quantitative discipline
# operations research-->quantitative discipline
# econometrics-->quantitative discipline
# quantitative analysis-->quantitative discipline
# scikit-learn-->quantitative discipline
# TensorFlow-->quantitative discipline
# SAS-->quantitative discipline
# R-->quantitative discipline
# statistical models-->quantitative discipline
# Spark-->Data Science
# Tensorflow-->Data Science
# R-->Data Science
# JavaScript-->programming languages
# Tableau-->reporting
# predictive analytics-->marketing
# Spark-->distributed computing
# Hadoop-->distributed computing
# Pig-->distributed computing
# SAS-->statistical modeling
# R-->statistical modeling
# Hadoop-->scripting languages
# Linux-->scripting languages
# UNIX-->scripting languages
# Python-->Data Scientist
# TensorFlow-->programming languages
# R-->Data Scientist
# Spark-->programming languages
# Tableau-->visualization tools
# advanced analytics-->design
# ETL-->Extract
# statistical analysis-->identify
# Machine Learning-->Data Science
# Scala-->Machine Learning
# training-->machine learning
# testing-->machine learning
# Spark-->programming skills
# Scala-->programming skills
# implementation-->consulting
# computer science-->applied math
# statistics-->applied math
# HDFS-->Information Retrieval
# Power BI-->data visualization tools
# Tableau-->data visualization tools
# SAS-->statistical software
# Redshift-->AWS
# SAS-->Data processing
# SQL-->Data processing
# regression-->statistical analysis
# numpy-->Python
# SVM-->Classification
# random forest-->Classification
# Python-->data visualization tools
# data manipulation-->AWS
# Tableau-->Spark
# machine learning-->AWS
# C++-->programming languages
# visualization tools-->C++
# problem solving-->data scientist
# SQL-->scikit-learn
# anomaly detection-->Natural Language Processing
# data visualizations-->implementation
# data models-->implementation
# Python-->implementation
# data analysis-->development
# data science-->development
# BI-->Business Intelligence
# predictive models-->data
# algorithms-->Computer Science
# Teradata-->databases
# Oracle-->databases
# SQL-->databases
# race-->receive consideration
# color-->receive consideration
# religion-->receive consideration
# creed-->receive consideration
# gender-->receive consideration
# origin-->receive consideration
# age-->receive consideration
# disability-->receive consideration
# marital-->receive consideration
# sexual orientation-->receive consideration
# Python-->data visualization
# SAS-->data visualization
# Hive-->data visualization
# Supply Chain-->Data Scientist
# programming language-->programming skills
# A/B Testing-->statistics
# Regression-->statistics
# SQL-->statistics
# machine learning-->statistics
# Decision Trees-->statistics
# Random Forest-->statistics
# Clustering-->statistics
# Natural Language Processing-->statistics
# data engineering-->statistics
# Hadoop-->statistics
# MapReduce-->statistics
# AWS-->statistics
# Spark-->data analysis
# R-->data analysis
# classification-->Machine Learning
# clustering-->Machine Learning
# optimization-->Machine Learning
# structured and unstructured data-->natural language processing
# classification-->statistical methods
# regression-->statistical methods
# SAS-->data manipulation
# R-->data manipulation
# SQL-->data manipulation
# TensorFlow-->Python
# North America-->AWS
# Scala-->Spark
# Java-->Spark
# Keras-->Deep Learning
# SAS-->data warehouse
# statistical software-->testing
# optimization-->machine learning techniques
# Python-->data processing
# data management-->design
# Hadoop-->databases
# predictive modeling-->data science
# Tableau-->data visualizations
# statistics-->quantitative field
# machine learning-->quantitative field
# artificial intelligence-->quantitative field
# operations research-->quantitative field
# Hive-->programming languages
# data analysis-->Tableau
# North America-->consulting
# Unix-->C++
# data collection-->data processing
# data management-->data processing
# processing-->data processing
# R-->statistical software
# AWS-->Amazon
# Machine Learning-->supply chain
# hypothesis testing-->A/B testing
# mathematics-->quantitative field
# econometrics-->quantitative field
# data science-->quantitative field
# computer science-->quantitative field
# engineering-->quantitative field
# marketing-->quantitative field
# Data Science-->ML
# neural networks-->machine learning methods
# deep learning-->machine learning methods
# SVM-->machine learning methods
# Random Forest-->machine learning methods
# S3-->SQL
# physics-->quantitative discipline
# economics-->quantitative discipline
# Python-->Analytics
# R-->Analytics
# SAS-->Statistical Analysis
# Keras-->machine learning
# git-->development
# Hadoop-->Predictive Analytics
# Mapreduce-->Predictive Analytics
# Hive-->Predictive Analytics
# Spark-->Predictive Analytics
# Java-->programming language
# statistical modeling-->predictive analytics
# R-->C++
# data analysis-->C++
# Hadoop-->C++
# Spark-->C++
# MongoDB-->C++
# economics-->quantitative field
# physics-->quantitative field
# MySQL-->relational databases
# Python-->Software development
# data structures-->data analysis
# Java-->programming skills
# C++-->programming skills
# relational databases-->programming skills
# SQL-->programming skills
# Hadoop-->programming skills
# random forest-->machine learning models
# statistical modeling-->statistics
# classification-->statistics
# Scala-->programming language
# C++-->programming language
# classification-->artificial intelligence
# regression-->artificial intelligence
# data science-->programming
# Apache Spark-->data analytics
# Tableau-->visualization
# data analysis-->R
# simulation-->predictive analytics
# Perl-->programming languages
# MapReduce-->Hadoop
# Spark-->Hadoop
# Kafka-->Hadoop
# Oracle-->relational databases
# Hadoop-->programming languages
# Tableau-->Business Intelligence
# NLP-->text mining
# deep learning-->machine learning
# NLP-->deep learning
# SPARK-->predictive models
# SQL-->predictive models
# Python-->predictive models
# S3-->AWS
# Applied Mathematics-->quantitative field
# deep learning-->Python
# SQL-->Python
# statistical analysis-->development
# Oracle-->SAS
# Teradata-->SAS
# Hadoop-->SAS
# applied math-->quantitative field
# finance-->quantitative field
# reporting-->quantitative field
# analytics-->quantitative field
# modeling-->quantitative field
# ======================================================================================================================== 500
# Python-->Spark
# Pandas-->data analysis
# scikit-learn-->data analysis
# Spark-->analysis
# SAS-->analysis
# Tensorflow-->analysis
# Hadoop-->analysis
# classification-->machine learning models
# clustering-->machine learning models
# forecasting-->machine learning models
# time series analysis-->machine learning models
# Matplotlib-->visualization tools
# AWS-->big data technologies
# R-->programming skills
# data structures-->data mining
# predictive modeling-->data mining
# design-->quantitative field
# implementation-->quantitative field
# relational databases-->design
# regression-->machine learning
# data mining-->big data
# statistical analysis-->big data
# predictive modeling-->big data
# data manipulation-->big data
# NLP-->Data Scientist
# R-->databases
# Python-->databases
# MySQL-->databases
# Java-->software development
# R-->programming language
# data structures-->Computer Science
# problem solving-->Computer Science
# CA-->Data Scientist
# communication skills-->Data Scientist
# data mining-->data analytics
# statistical analysis-->data analytics
# SQL-->data warehouse
# ETL-->data warehouse
# Python-->Mathematics
# Python-->software engineering
# SQL-->software engineering
# random forest-->machine learning
# Excel-->Data Visualization
# Matlab-->scripting languages
# C++-->scripting languages
# Java-->scripting languages
# mathematics-->computer science
# physics-->computer science
# SQL Server-->databases
# MATLAB-->programming languages
# Machine Learning-->Python
# BS-->quantitative discipline
# Python-->quantitative discipline
# Perl-->quantitative discipline
# distributed computing-->quantitative discipline
# Clustering-->machine learning techniques
# Forecasting-->machine learning techniques
# NoSQL-->Big Data technologies
# Python-->statistical software
# Apache Spark-->model development
# data analysis-->Data Scientist
# AWS-->Services
# modeling-->data science
# analysis-->data science
# data manipulation-->data science
# ETL-->data analytics
# analysis-->data analytics
# PyTorch-->Deep Learning
# Hadoop-->Tableau
# statistical-->scripting languages
# R-->statistical analysis
# Python-->statistical analysis
# Scala-->statistical analysis
# Tableau-->statistical modeling
# Tableau-->Google analytics
# regression-->Google analytics
# Spark-->SQL
# forecasting-->statistics
# predictive analytics-->statistics
# data mining-->statistics
# Python-->data analytics
# R-->data analytics
# Java-->data analytics
# Scala-->data analytics
# Python-->matplotlib
# Tensorflow-->Deep Learning
# statistics-->data science
# econometrics-->data science
# visualization-->data science
# supply chain-->data science
# machine learning-->statistical methods
# data modeling-->statistical methods
# machine learning models-->A/B testing
# machine learning-->Information Technology
# data analytics-->Information Technology
# SVM-->Machine learning
# mining-->databases
# neural networks-->machine learning models
# Tableau-->data science
# SQL-->data science
# machine learning-->advanced analytics
# relational databases-->Extract
# Cassandra-->big data technologies
# MongoDB-->big data technologies
# Kafka-->big data technologies
# natural language processing-->machine learning methods
# data visualization-->design
# SQL-->visualization tools
# classification-->statistical models
# optimization-->statistical models
# Spark-->ML
# Python-->ML
# PyTorch-->ML
# TensorFlow-->ML
# visualization tools-->ML
# Tableau-->ML
# Decision Trees-->Predictive Analytics
# Random Forest-->Predictive Analytics
# Spark-->statistical modeling
# Hive-->statistical modeling
# data analysis-->algorithms
# SPSS-->statistical software
# MatLab-->statistical software
# predictive analytics-->machine learning models
# USA-->Consulting
# classification-->data mining
# anomaly detection-->data mining
# NLP-->neural networks
# Python-->Hadoop
# R-->Hadoop
# HDFS-->Hadoop
# math-->training
# computer science-->training
# statistics-->training
# regression-->predictive models
# feature engineering-->algorithms
# Python-->modeling
# R-->modeling
# machine learning-->design
# deep learning-->design
# training-->design
# testing-->design
# ML-->Artificial Intelligence
# deep learning-->Artificial Intelligence
# data mining-->Artificial Intelligence
# Pandas-->data management
# SQL-->data management
# Excel-->Microsoft Office
# Hadoop-->SQL
# Tableau-->Hadoop
# C/C++-->Computer Science
# Python-->Computer Science
# Tensorflow-->machine learning
# Predictive Analytics-->data visualization tools
# forecasting-->data visualization tools
# optimization-->data visualization tools
# Predictive models-->statistical models
# data analysis-->Scala
# Teradata-->data analysis
# Hive-->data analysis
# SQL-->Scala
# Machine Learning-->Docker
# Kafka-->Scala
# Natural Language Processing-->Docker
# SAS-->Statistics
# development-->data scientists
# testing-->data scientists
# machine learning-->predictive analytics
# optimization-->predictive analytics
# hypothesis testing-->data mining
# machine learning-->data mining
# Python-->algorithms
# operations research-->machine learning
# engineering-->machine learning
# R-->analysis
# Python-->analysis
# Matlab-->analysis
# Java-->analysis
# Scala-->analysis
# SQL-->AWS
# Python-->data analysis
# Scala-->data analysis
# SQL-->Data engineering
# classification-->data science
# clustering-->data science
# natural language processing-->data science
# Data Mining-->data scientists
# Predictive Modeling-->data scientists
# ======================================================================================================================== 1000
# analytical skills-->programming language
# Hadoop-->Python
# Spark-->Python
# AWS-->Python
# Teradata-->SQL
# software development-->engineering
# testing-->engineering
# optimization-->data analysis
# MongoDB-->natural language processing
# Cassandra-->natural language processing
# analytics-->data scientists
# natural language processing-->data scientists
# machine learning-->data scientists
# information retrieval-->data scientists
# Azure-->big data
# AWS-->big data
# Oracle-->big data
# math-->quantitative field
# data analysis-->statistical techniques
# analysis-->statistical techniques
# experimental design-->artificial intelligence
# HIVE-->data manipulation
# Big Data technologies-->SQL
# machine learning-->data analysis
# artificial intelligence-->data analysis
# statistics-->data analysis
# TensorFlow-->data analysis
# Power BI-->visualization tools
# natural language processing-->deep learning
# neural networks-->machine learning techniques
# random forest-->machine learning techniques
# Python-->business intelligence
# SAS-->business intelligence
# MATLAB-->business intelligence
# C++-->business intelligence
# R-->business intelligence
# Java-->business intelligence
# big data-->statistical analysis
# SQL-->TensorFlow
# Oracle-->SQL
# SAS-->data science
# Decision Trees-->Deep Learning
# Math-->quantitative discipline
# quantitative discipline-->Computer Science
# quantitative analysis-->Computer Science
# scikit-learn-->Computer Science
# TensorFlow-->Computer Science
# SAS-->Computer Science
# R-->Computer Science
# modeling-->Data analysis
# Finance-->Predictive Modeling
# classification-->machine learning algorithms
# regression-->machine learning algorithms
# clustering-->machine learning algorithms
# NLP-->machine learning algorithms
# Natural Language processing-->machine learning
# Statistics-->data visualization
# Mathematics-->data visualization
# Operations Research-->data visualization
# Computer Science-->data visualization
# Data Science-->quantitative discipline
# Predictive Analytics-->quantitative discipline
# machine learning models-->design
# technology-->STEM
# engineering-->STEM
# mathematics-->STEM
# decision trees-->machine learning algorithms
# SVM-->machine learning algorithms
# neural networks-->machine learning algorithms
# Random forest-->machine learning algorithms
# reporting-->data manipulation
# visualization-->data manipulation
# data mining-->statistical analysis
# pandas-->R
# visualization-->analysis
# deep learning-->statistical techniques
# machine learning-->statistical techniques
# Spark-->programming language
# Perl-->programming language
# reporting-->design
# analytics-->design
# data management-->R
# regression-->quantitative analysis
# classification-->quantitative analysis
# clustering-->quantitative analysis
# data-->data analytics
# visualizations-->data analytics
# statistics-->math
# data-->patterns
# anomaly detection-->patterns
# statistical modeling-->data analysis
# data analytics-->data analysis
# visualization-->data analysis
# implementation-->AI
# analysis-->quantitative field
# anomaly detection-->Automation
# data-->regression
# S3-->Data warehouse
# Pandas-->data science
# Numpy-->data science
# R-->Keras
# SAS-->Keras
# Tableau-->Keras
# Python-->Keras
# Perl-->Keras
# Hadoop-->large datasets
# data mining-->large datasets
# Pandas-->data visualization tools
# programming languages-->Machine Learning
# SQL-->big data technologies
# MySQL-->big data technologies
# Git-->big data technologies
# A/B testing-->experimental design
# statistical analysis-->R
# predictive modeling-->machine learning
# anomaly detection-->machine learning
# data visualization-->data analytics
# data structures-->SQL
# Hadoop-->data manipulation
# programming-->data manipulation
# Python-->data manipulation
# JavaScript-->data manipulation
# ETL-->data manipulation
# R-->ML
# TensorFlow-->machine learning techniques
# Pandas-->Hive
# Scikit-learn-->Hive
# data analytics-->data engineers
# reports-->data engineers
# SPSS-->large datasets
# SAS-->large datasets
# Excel-->large datasets
# Python-->Statistics
# R-->Statistics
# programming language-->Statistics
# marketing-->data scientist
# data management-->Hadoop
# Big Data-->data mining
# Matlab-->data manipulation
# C++-->data manipulation
# Time Series Analysis-->modeling
# Random Forest-->modeling
# Clustering-->modeling
# Neural Networks-->modeling
# Teradata-->Relational Databases
# Mathematics-->machine learning techniques
# Statistics-->machine learning techniques
# Computer Science-->machine learning techniques
# Engineering-->machine learning techniques
# data models-->design
# statistical analysis-->SAS
# ======================================================================================================================== 1500
# data mining-->statistical techniques
# SAS-->programming language
# SQL-->statistical software
# Excel-->statistical software
# Hadoop-->statistical software
# data mining-->statistical software
# predictive analytics-->statistical software
# data mining-->SAS
# predictive analytics-->SAS
# anomaly detection-->predictive analytics
# data analytics-->design
# Matplotlib-->Python
# Power BI-->Visualization
# technology-->data scientist
# finance-->data scientist
# Scala-->data scientist
# SQL-->data scientist
# predictive models-->implementation
# data mining-->quantitative
# data analysis-->quantitative
# forecasting-->model development
# data structures-->Software engineering
# data manipulation-->SQL
# analysis-->SQL
# HDFS-->big data technologies
# Tableau-->data analysis
# Python-->statistical models
# R-->statistical models
# decision trees-->machine learning models
# regression-->machine learning models
# clustering-->statistical models
# predictive analytics-->Data Scientist
# AI-->AZURE
# structured and unstructured data-->processing
# data-->structured and unstructured data
# engineering-->training
# Python-->physics
# AWS-->Data Science
# scripting languages-->data analysis
# statistical modeling-->machine learning
# SQL-->statistical modeling
# Python-->statistical modeling
# Java-->statistical modeling
# scripting languages-->data science
# Javascript-->scripting languages
# SQL-->scripting languages
# processing-->data scientists
# analysis-->data scientists
# statistics-->SQL
# mining-->mining
# research-->experimental design
# Linux-->R
# machine learning-->Data Scientist
# Spark-->scripting languages
# Decision Trees-->Time series analysis
# random forest-->Time series analysis
# deep learning-->Time series analysis
# Amazon-->R
# Business Intelligence-->data visualization tools
# Reporting-->data visualization tools
# SVM-->regression
# neural networks-->regression
# data collection-->data engineering
# time series analysis-->statistical methods
# Linux-->statistical models
# C++-->statistical software
# NLP-->Machine Learning
# programming languages-->Python
# statistical models-->development
# python-->Programming
# SQL-->database
# R-->Programming
# Javascript-->Programming
# C++-->Programming
# data-->modeling
# R-->Visualization
# git-->software engineering
# data mining-->data visualization
# Hadoop-->data visualization
# Spark-->data visualization
# SAS-->data mining
# SPSS-->data mining
# R-->data mining
# SQL-->analysis
# data processing-->data analysis
# Java-->R
# Analytics-->quantitative discipline
# data warehouse-->predictive models
# business intelligence-->design
# ======================================================================================================================== 2000
# analytics-->Data modeling
# SPSS-->visualization tools
# Keras-->Python
# experimental design-->Statistics
# statistics-->analytical skills
# predictive modeling-->analytical skills
# experimental design-->analytical skills
# R-->SQL
# Python-->SQL
# research-->analytics
# development-->analytics
# implementation-->analytics
# testing-->analytics
# large datasets-->SQL
# statistical analysis-->Statistical modeling
# SAS-->programming languages
# SPSS-->programming languages
# visualization-->analytical
# prediction-->statistical models
# Random Forest-->regression
# algorithms-->Analysis
# Analytics-->data scientist
# Reporting-->data scientist
# data mining-->R
# AI-->Analytics
# Spark-->AWS
# Python-->AWS
# R-->AWS
# simulation-->Advanced analytics
# artificial intelligence-->Advanced analytics
# natural language processing-->algorithms
# modeling-->statistical methods
# Big Data-->data science
# experimental design-->statistical methods
# decision trees-->predictive modeling
# statistical analysis-->predictive modeling
# R-->predictive modeling
# Python-->predictive modeling
# SQL-->predictive modeling
# SQL-->relational databases
# AWS-->data warehouse
# data modeling-->data scientist
# data management-->data scientist
# data mining-->hypothesis testing
# modeling-->hypothesis testing
# advanced analytics-->development
# Azure-->data science
# Redshift-->data science
# clustering-->data mining
# prediction-->data mining
# machine learning-->quantitative discipline
# applied mathematics-->quantitative discipline
# C/C++-->programming language
# business problems-->data mining
# data manipulation-->R
# analysis-->R
# business intelligence-->marketing
# SQL Server-->visualization
# Python-->visualization
# data mining-->Computer Science
# machine learning-->Computer Science
# SAS-->data analysis
# data processing-->automation
# data pipelines-->implementation
# Forecasting-->Data Scientist
# AWS-->Docker
# services-->consulting
# consulting-->consulting
# quantitative field-->Applied Math
# data analysis-->machine learning
# visualization-->Linux
# training-->development
# Tensorflow-->quantitative field
# Keras-->quantitative field
# ======================================================================================================================== 2500
# Hadoop-->machine learning algorithms
# Hive-->machine learning algorithms
# Hbase-->machine learning algorithms
# programming skills-->modeling
# data collection-->machine learning models
# statistical analysis-->data mining
# predictive modeling-->development
# Tableau-->BI
# Power BI-->dashboards
# Scala-->data mining
# Hadoop-->Spark
# Cassandra-->Spark
# position-->Contact
# deep learning-->machine learning algorithms
# A/B testing-->Testing
# Machine Learning-->programming languages
# decision trees-->machine learning techniques
# Python-->quantitative field
# SQL-->quantitative field
# SVM-->machine learning techniques
# statistical analysis-->scripting languages
# MatLab-->statistical analysis
# time series analysis-->machine learning algorithms
# forecasting-->machine learning algorithms
# classification-->analytical skills
# communication-->analytical skills
# quantitative analysis-->analytical skills
# research-->analytical skills
# big data-->AI
# SQL Server-->SQL
# Javascript-->programming language
# analysis-->machine learning models
# Hive-->data mining
# Pig-->data mining
# Spark-->data mining
# R-->SAS
# clustering-->statistical methods
# decision trees-->statistical methods
# SVM-->statistical methods
# deep learning-->statistical methods
# analyze-->statistical methods
# STEM-->statistical methods
# statistics-->statistical methods
# engineers-->training
# python-->visualization tools
# AI-->Machine Learning
# Hive-->Big Data
# NLP-->NLP
# Azure-->SQL
# Spark-->statistical analysis
# matplotlib-->data visualization tools
# SAS-->data analytics
# SQL-->data analytics
# Matlab-->data analytics
# algorithms-->design
# Power BI-->visualizations
# artificial intelligence-->data analytics
# Linux-->data analysis
# Java-->SQL
# statistical modeling-->SQL
# machine learning-->SQL
# test-->design
# big data-->SQL
# statistics-->Python
# Pandas-->SVM
# scikit-learn-->SVM
# Tensorflow-->SVM
# C/C++-->Python
# Anomaly Detection-->Data Science
# SPSS-->modeling
# Tableau-->modeling
# data visualization tools-->MatLab
# dashboards-->data visualization
# decision making-->analytics
# statistical analysis-->analytics
# Tableau-->analytics
# design-->analytics
# ======================================================================================================================== 3000
# data analysis-->SAS
# HDFS-->Python
# patterns-->Data Mining
# HBase-->Hadoop
# Tableau-->data analytics
# Statistical-->SAS
# statistics-->Matlab
# NoSQL-->Database
# Data Science-->Analytics
# data warehouse-->data modeling
# SQL-->data modeling
# Machine Learning-->statistical
# Artificial Intelligence-->statistical
# data analysis-->SPSS
# design-->automation
# MongoDB-->SQL
# data models-->data modeling
# A/B testing-->data pipelines
# model development-->data pipelines
# time series analysis-->statistical techniques
# Extract-->ETL
# ML-->data analysis
# NLP-->data analysis
# machine learning-->data management
# SQL-->data analysis
# Google Analytics-->Natural language processing
# Google Analytics-->text mining
# Tableau-->large datasets
# Azure-->AWS
# prediction-->machine learning techniques
# classification-->machine learning techniques
# matplotlib-->Data Visualization
# IoT-->machine learning
# R-->Big Data
# Python-->Big Data
# machine learning-->Big Data
# SAS-->Big Data
# NumPy-->visualization
# Pandas-->visualization
# Matplotlib-->visualization
# statistical analysis-->modeling
# data mining-->modeling
# Statistics-->Statistics
# Data Science-->Statistics
# Mathematics-->Statistics
# Engineering-->Statistics
# Kafka-->patterns
# Teradata-->Data analytics
# prediction-->ML
# optimization-->ML
# SQL-->Programming
# Tensorflow-->Predictive modeling
# large datasets-->data mining
# Python-->NLP
# Power BI-->data analysis
# SQL-->data mining
# ======================================================================================================================== 3500
# decision trees-->data mining
# optimization-->data mining
# simulation-->data mining
# deep learning-->data mining
# visualization-->Tableau
# data science-->data science
# big data-->machine learning
# NLP-->statistical techniques
# Neural Networks-->statistical techniques
# data manipulation-->Excel
# classification-->quantitative field
# clustering-->quantitative field
# Hadoop-->quantitative field
# Statistics-->R
# A/B testing-->data mining
# Scala-->Kafka
# Java-->Kafka
# Integrity-->Analytics
# Master’s Degree-->quantitative discipline
# Pandas-->HDFS
# data visualizations-->SQL
# Linux-->machine learning models
# Docker-->machine learning models
# distributed computing-->machine learning models
# data analysis-->data visualizations
# Mathematics-->data science
# Computer Science-->data science
# data exploration-->R
# modeling-->R
# Teradata-->big data
# Statistical Analysis-->data science
# Hive-->SQL
# MapReduce-->ML
# databases-->data models
# mining-->data models
# Tensorflow-->Keras
# deep learning-->data science
# Java-->programming
# Scala-->programming
# SAS-->reporting
# Tableau-->Machine Learning
# SQL-->statistical analysis
# Tableau-->statistical analysis
# GCP-->statistical analysis
# A/B testing-->statistical analyses
# machine learning algorithms-->implementation
# statistical methods-->implementation
# data science-->quantitative analysis
# economics-->quantitative analysis
# physics-->quantitative analysis
# mathematics-->quantitative analysis
# statistics-->quantitative analysis
# computer science-->quantitative analysis
# engineering-->quantitative analysis
# Machine Learning-->problem solving
# Deep Learning-->problem solving
# Natural language processing-->problem solving
# Statistics-->problem solving
# Python-->R
# scala-->ML
# STEM-->quantitative discipline
# data engineering-->Data Science
# data mining-->Data Science
# processing-->Data Science
# prediction-->Data Science
# decision trees-->Data Science
# MS-->Data Scientist
# quantitative field-->Data Scientist
# Machine Learning-->statistical analysis
# algorithms-->optimization
# SVM-->Data Science
# optimization-->predictive models
# large datasets-->statistical analysis
# algorithms-->research
# modeling-->research
# physics-->machine learning
# natural language processing-->design
# IoT-->Big Data
# SQL-->numpy
# natural language processing-->numpy
# machine learning-->numpy
# R-->operations research
# SQL-->operations research
# Python-->operations research
# Matlab-->analytics
# Kafka-->data science
# Hadoop-->data science
# agile-->data science
# Machine Learning-->Applied Mathematics
# Cassandra-->NoSQL
# MongoDB-->NoSQL
# HBase-->NoSQL
# marketing-->machine learning
# visualization-->R
# machine learning-->R
# artificial Intelligence-->data science
# text mining-->data science
# ======================================================================================================================== 4000
# Python-->natural language processing
# R-->natural language processing
# Scala-->natural language processing
# SAS-->natural language processing
# data visualization-->scripting languages
# data exploration-->SQL
# visualization-->SQL
# BI-->SQL
# data visualization-->SQL
# Tableau-->SQL
# R-->Data visualization tools
# training-->quantitative field
# data visualization-->Training
# experimental design-->quantitative discipline
# statistical methods-->data
# analysis-->Spark
# programming languages-->data analytics
# NumPy-->Spark
# Pandas-->Spark
# feature engineering-->modeling
# testing-->modeling
# Statistics-->Mathematics
# Keras-->Data Scientists
# STATISTICAL MODELING-->DATA SCIENTIST
# reports-->automation
# experimental design-->clustering
# implementation-->software development
# testing-->software development
# AI-->quantitative field
# classification-->R
# MapReduce-->AWS
# problem solving-->algorithms
# natural language processing-->AI
# machine learning algorithms-->AI
# AI-->data science
# econometrics-->Training
# Hadoop-->data processing
# Spark-->data processing
# R-->machine learning models
# Python-->machine learning models
# HBase-->Big Data
# Cassandra-->Big Data
# algorithms-->development
# finance-->Analytics
# marketing-->Analytics
# modeling-->Data mining
# SAS-->regression
# SQL-->regression
# R-->software development
# C++-->software development
# Hadoop-->data management
# Hive-->data management
# Python-->data management
# SQL-->statistical analyses
# integrity-->testing
# data warehouse-->reporting
# automation-->SAS
# data manipulation-->SAS
# reporting-->SAS
# statistical analysis-->quantitative discipline
# data processing-->programming languages
# analysis-->programming languages
# statistics-->Applied Mathematics
# Extract-->predictive models
# analysis-->predictive models
# ======================================================================================================================== 4500
# modeling-->machine learning techniques
# data mining-->machine learning techniques
# statistical analyses-->machine learning techniques
# Tableau-->relational databases
# anomaly detection-->machine learning models
# data science-->machine learning models
# machine learning-->data warehouse
# NLP-->data warehouse
# databases-->data science
# data visualization-->data science
# Kafka-->Programming languages
# predictive models-->statistical methods
# Excel-->SAS
# Master's degree-->quantitative field
# R-->software engineering
# AWS-->software engineering
# Docker-->software engineering
# reporting-->statistical software
# analytics-->statistical software
# scripting languages-->communication skills
# R-->statistical analyses
# communication skills-->Data Science
# Hive-->distributed computing
# feature engineering-->machine learning
# Python-->data structures
# Java-->data structures
# SAS-->SAS
# data analysis-->programming skills
# regression-->statistical modeling
# neural networks-->statistical modeling
# clustering-->statistical modeling
# software engineering-->data scientists
# regression-->machine learning techniques
# Java-->NLP
# Javascript-->NLP
# Scala-->NLP
# Pandas-->NLP
# Numpy-->NLP
# PyTorch-->NLP
# Keras-->NLP
# TensorFlow-->NLP
# Neural Networks-->ML
# Linux-->Java
# data visualization-->implementation
# Excel-->Python
# data visualization tools-->Python
# python-->Python
# Tableau-->Python
# Power BI-->Python
# machine learning-->optimization
# Hive-->optimization
# Spark-->optimization
# Oracle-->technology
# NLP-->statistics
# ======================================================================================================================== 5000
# data analysis-->Python
# Data Visualization-->AWS
# GCP-->Amazon
# R-->data management
# SAS-->data management
# ETL-->SAS
# physics-->data science
# applied mathematics-->data science
# economics-->data science
# HBase-->big data technologies
# Unix-->programming languages
# data scientist-->Reporting
# statistical analysis-->statistical methods
# R-->statistical methods
# SPSS-->statistical methods
# Statistics-->Machine Learning
# ML-->Analytics
# NLP-->AI
# Text Mining-->AI
# machine learning models-->Feature engineering
# data analysis-->statistical modeling
# SAS-->scripting languages
# statistical software-->relational databases
# Hive-->data processing
# data science-->Machine Learning
# identify-->data mining
# analysis-->Building
# Python-->Advanced analytics
# R-->Advanced analytics
# SAS-->Advanced analytics
# SPSS-->Advanced analytics
# data analysis-->programming languages
# NumPy-->R
# data mining-->predictive analytics
# MapReduce-->Big Data
# PIG-->Big Data
# JavaScript-->R
# development-->databases
# analysis-->databases
# Redshift-->big data technologies
# Analytics-->Data Science
# finance-->quantitative discipline
# analytical-->Data Scientist
# ETL-->automation
# C/C++-->scripting languages
# statistical modeling-->scripting languages
# machine learning-->scripting languages
# data mining-->scripting languages
# business problems-->scripting languages
# SPSS-->data science
# JavaScript-->data science
# big data-->problem solving
# regression-->Statistical models
# predictive models-->design
# ======================================================================================================================== 5500
# data science-->advanced analytics
# statistics-->advanced analytics
# Apache Spark-->Big Data technologies
# programming languages-->programming skills
# statistics-->Information Technology
# Scala-->scripting languages
# decision trees-->statistical techniques
# PyTorch-->Machine Learning
# JavaScript-->Visualization
# Teradata-->big data technologies
# visualization tools-->SQL
# R-->Predictive models
# Matplotlib-->statistics
# NLP-->machine learning techniques
# SQL Server-->relational databases
# NumPy-->statistical analysis
# classification-->statistical analyses
# Machine learning-->Big Data Technologies
# Text Mining-->Big Data Technologies
# visualization tools-->Agile
# Docker-->Linux
# machine learning-->Mathematics
# forecasting-->statistical modeling
# technology-->statistical modeling
# Big Data technologies-->predictive analytics
# statistical modeling-->programming skills
# SAS-->programming skills
# MATLAB-->Python
# Statistical-->Data Scientist
# Data Science-->Python
# data mining-->SQL
# building-->Data Scientist
# testing-->Data Scientist
# Tableau-->analysis
# prediction-->Neural Networks
# statistical models-->decision making
# SQL-->data visualization tools
# SPSS-->Python
# SAS-->Python
# ======================================================================================================================== 6000
# predictive analytics-->machine learning methods
# visualization-->dashboards
# machine learning-->data structures
# data visualization tools-->R
# statistical modeling-->data science
# analysis-->analytical skills
# big data-->analysis
# modeling-->analytical skills
# statistics-->analysis
# A/B testing-->analysis
# experimental design-->analysis
# R-->Tableau
# Python-->PyTorch
# Java-->PyTorch
# statistics-->SCI
# data mining-->SCI
# modeling-->SCI
# SQL-->Machine Learning
# Hadoop-->Machine Learning
# Hive-->Machine Learning
# machine learning techniques-->data mining
# regression-->predictive analytics
# Python-->SAS
# Perl-->SAS
# Java-->Machine Learning
# R-->data processing
# ETL-->Machine Learning
# neural networks-->predictive models
# SCI-->Data Scientist
# R-->AI
# Python-->AI
# HBase-->MapReduce
# statistics-->algorithms
# data mining-->algorithms
# predictive modeling-->algorithms
# database-->MapReduce
# automation-->building
# IoT-->analytics
# R-->visualization tools
# deep learning-->machine learning models
# Scala-->Big Data technologies
# programming-->R
# ======================================================================================================================== 6500
# Supply Chain-->machine learning algorithms
# data-->extract
# SQL-->R
# research-->data science
# natural language processing-->data mining
# deep learning-->deep learning
# text mining-->deep learning
# MS-->Statistics
# quantitative field-->Statistics
# analysis-->statistical methods
# statistical models-->visualization tools
# Data Mining-->visualization tools
# modeling-->visualization tools
# Excel-->Visualization tools
# development-->machine learning models
# statistical modeling-->quantitative field
# data mining-->quantitative field
# ======================================================================================================================== 7000
# data-->statistical analysis
# numpy-->pandas
# Scikit-Learn-->data mining
# NumPy-->data mining
# Pandas-->data mining
# neural networks-->Deep Learning
# Regression-->Deep Learning
# NLP-->data science
# forecasting-->Time Series Analysis
# Python-->forecasting
# Spark-->forecasting
# Spark-->data analytics
# decision trees-->machine learning methods
# Cassandra-->SQL
# machine learning-->Power BI
# Big Data-->statistical models
# IoT-->statistical models
# Supply Chain-->statistical models
# statistical techniques-->design
# natural language processing-->predictive analytics
# NLP-->predictive analytics
# artificial intelligence-->predictive analytics
# analysis-->automation
# visualization-->automation
# scripting languages-->machine learning techniques
# Python-->machine learning techniques
# R-->machine learning techniques
# predictive modeling-->statistics
# Pig-->programming languages
# PyTorch-->Python
# Excel-->visualizations
# Tableau-->visualizations
# quantitative discipline-->quantitative field
# Redshift-->relational databases
# testing-->genetic information
# Python-->model development
# statistics-->model development
# Oracle-->Database
# Hadoop-->data engineering
# Spark-->data engineering
# big data-->quantitative field
# ======================================================================================================================== 7500
# implementation-->programming
# simulation-->optimization
# data analysis-->predictive models
# SQL-->programming language
# Matlab-->programming language
# algorithms-->testing
# Technology-->quantitative field
# statistical analysis-->data processing
# statistical analysis-->Statistics
# text mining-->Statistics
# optimization-->Statistics
# Matlab-->Statistics
# Perl-->Statistics
# Java-->Statistics
# data analysis-->Statistics
# Spark-->Statistics
# NoSQL-->Statistics
# MySQL-->Statistics
# Hive-->Statistics
# Pig-->Statistics
# Data Science-->optimization
# Excel-->data visualization tools
# regression-->SQL
# statistics-->Data Scientist
# mathematics-->Data Scientist
# econometrics-->Data Scientist
# computer science-->Data Scientist
# engineering-->Data Scientist
# marketing-->data analysis
# programming-->machine learning techniques
# design-->software development
# simulation-->machine learning
# prediction-->machine learning algorithms
# Scala-->software development
# database-->Python
# AWS-->Scala
# mining-->data analysis
# ======================================================================================================================== 8000
# data science-->predictive modeling
# advanced analytics-->predictive modeling
# artificial intelligence-->predictive modeling
# modeling-->data management
# operations research-->analysis
# Master's Degree-->analysis
# Teradata-->Hadoop
# Artificial Intelligence-->programming languages
# ML-->Spark
# data analysis-->Spark
# data visualization-->Spark
# MongoDB-->databases
# Cassandra-->databases
# Linux-->programming skills
# NOSQL-->data modeling
# SAS-->databases
# scikit-learn-->databases
# Keras-->databases
# TensorFlow-->databases
# Pytorch-->databases
# statistical modeling-->Java
# data mining-->data analysis
# data mining-->design
# statistical analysis-->design
# Math-->Data Scientist
# programming languages-->modeling
# database-->modeling
# data analytics-->data science
# software engineering-->data science
# SPSS-->Data analysis
# ======================================================================================================================== 8500
# ETL-->data processing
# scikit-learn-->ML
# distributed computing-->predictive modeling
# programming languages-->predictive models
# data structures-->design
# data modeling-->design
# data quality-->design
# Analytics-->statistical analysis
# Java-->data analysis
# programming languages-->data analysis
# physics-->mathematics
# operations research-->mathematics
# optimization-->advanced analytics
# prediction-->anomaly detection
# data manipulation-->anomaly detection
# Machine Learning-->AI
# Scikit-Learn-->machine learning
# Data Warehouse-->Agile
# Power BI-->Data Scientist
# computer science-->R
# numPy-->Statistical modeling
# Matlab-->Statistical modeling
# econometrics-->R
# mathematics-->R
# machine learning-->clustering
# AI-->advanced analytics
# git-->software development
# Big Data technologies-->engineering
# natural language processing-->Python
# AI-->Python
# clustering-->statistical techniques
# ML-->quantitative discipline
# relational databases-->A/B testing
# SQL-->A/B testing
# R-->A/B testing
# Python-->A/B testing
# data modeling-->SAS
# Math-->R
# quantitative discipline-->R
# Linux-->engineering
# programming languages-->engineering
# C++-->engineering
# analysis-->Statistics
# Matlab-->machine learning models
# SAS-->machine learning models
# marketing-->mathematics
# computer science-->mathematics
# engineering-->mathematics
# ======================================================================================================================== 9000
# classification-->Building
# regression-->Building
# big data technologies-->Hadoop
# big data technologies-->big data technologies
# Tableau-->R
# natural language processing-->modeling
# data visualization-->modeling
# data manipulation-->data manipulation
# Technology-->Job
# Java-->algorithms
# SAS-->algorithms
# SPSS-->algorithms
# R-->algorithms
# Excel-->algorithms
# statistical models-->statistical analysis
# SQL-->SQL
# ETL-->Data Scientist
# SQL-->SAS
# quantitative field-->quantitative field
# Data Science-->vision
# statistical analysis-->mining
# machine learning-->deep learning
# Python-->deep learning
# predictive analytics-->SQL
# business problems-->Deep Learning
# Pandas-->analytics
# Numpy-->analytics
# Scikit-learn-->analytics
# data visualization-->statistical analysis
# SQL-->Keras
# ======================================================================================================================== 9500
# reporting-->visualizations
# mysql-->SQL
# machine learning-->data analytics
# Natural Language Processing-->data analytics
# a/b testing-->statistical modeling
# development-->scikit-learn
# classification-->development
# regression-->development
# anomaly detection-->statistical methods
# statistical software-->SAS
# structured and unstructured data-->analysis
# Data Scientist-->ML
# Optimization-->Algorithmic
# Data Mining-->Algorithmic
# natural language processing-->information retrieval
# A/B testing-->statistical techniques
# Hadoop-->relational databases
# Hive-->AWS
# Text Mining-->Neural Networks
# Hadoop-->NoSQL
# Spark-->NoSQL
# data collection-->consulting
# data analysis-->visualization
# Hadoop-->technology
# R-->technology
# Python-->technology
# SQL-->technology
# ML-->data science
# SQL-->modeling
# SAS-->modeling
# ======================================================================================================================== 10000

# %%
link_df = pd.DataFrame( total_link_list )
link_df = link_df.rename( columns = {0:'node1',1:'node2'} )
link_df = link_df.drop_duplicates()
link_df_temp = link_df
# link_df = link_df.sample(500)
link_df
# Out:
#                node1                node2
# 0     classification  predictive modeling
# 1         regression  predictive modeling
# 2          Economics          Mathematics
# 3             Hadoop           algorithms
# 4              Spark           algorithms
# ...              ...                  ...
# 1512          Python           technology
# 1513             SQL           technology
# 1514              ML         data science
# 1515             SQL             modeling
# 1516             SAS             modeling
#
# [1517 rows x 2 columns]

# %% [markdown]
# # Skill Graph

# %%
temp_skill_set = skill_set.copy()

# %%
max_size = 0
min_size = 0
for k,v in skill_set.items():
    if v > max_size:
        max_size = v
    
    if v < min_size:
        min_size = v
        
for k,v in skill_set.items():
    skill_set[k] = 15 + 85 * ( (v - min_size)/ (max_size -min_size) )

# %%
from unittest.mock import patch
from nose.tools import assert_equal, assert_in
from pyecharts import options as opts
from pyecharts.charts.basic_charts.graph import Graph

from pyecharts import options as opts
from pyecharts.charts import Graph

nodes = []
links = []

nodes_set = []

for ind, row in link_df.iterrows():
    
    if row['node1'] != row['node2']:
        
        if row['node1'] not in nodes_set:
            nodes_set.append( row['node1'] )
            nodes.append( {'name': row['node1'] , "symbolSize":  skill_set[row['node1']] } )
            
        if row['node2'] not in nodes_set:
            nodes_set.append( row['node2'] )
            nodes.append( {'name': row['node2'] , "symbolSize": skill_set[row['node2']]  } )
        
        links.append({"source": row['node2'], "target": row['node1']})

Graph().add(
    "", 
    nodes, 
    links, 
    repulsion=8000,
#     linestyle_opts=opts.LineStyleOpts(width=2, curve=0.1, opacity=0.9),
    linestyle_opts=opts.LineStyleOpts(width=0.5, curve=0.3, opacity=0.7),
    label_opts=opts.LabelOpts( ),
    categories=None,
    is_focusnode=True,
#     layout="none",
    is_roam=True
    
).set_global_opts(title_opts=opts.TitleOpts(title="")).render_notebook()
# Out:
# /home/lothar/anaconda3/lib/python3.7/site-packages/pyecharts/charts/chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="ba374e285dfc4991a4416b2f383a12e1" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_ba374e285dfc4991a4416b2f383a12e1 = echarts.init(
#                     document.getElementById('ba374e285dfc4991a4416b2f383a12e1'), 'white', {renderer: 'canvas'});
#                 var option_ba374e285dfc4991a4416b2f383a12e1 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "graph",
#             "layout": "force",
#             "symbolSize": 10,
#             "circular": {
#                 "rotateLabel": false
#             },
#             "force": {
#                 "repulsion": 8000,
#                 "edgeLength": 50,
#                 "gravity": 0.2
#             },
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 0.5,
#                 "opacity": 0.7,
#                 "curveness": 0.3,
#                 "type": "solid"
#             },
#             "roam": true,
#             "draggable": false,
#             "focusNodeAdjacency": true,
#             "data": [
#                 {
#                     "name": "classification",
#                     "symbolSize": 23.283191628515368
#                 },
#                 {
#                     "name": "predictive modeling",
#                     "symbolSize": 31.332897318508827
#                 },
#                 {
#                     "name": "regression",
#                     "symbolSize": 26.941137998691957
#                 },
#                 {
#                     "name": "Economics",
#                     "symbolSize": 24.973185088293
#                 },
#                 {
#                     "name": "Mathematics",
#                     "symbolSize": 36.72531066056246
#                 },
#                 {
#                     "name": "Hadoop",
#                     "symbolSize": 42.884892086330936
#                 },
#                 {
#                     "name": "algorithms",
#                     "symbolSize": 29.242642249836493
#                 },
#                 {
#                     "name": "Spark",
#                     "symbolSize": 43.45192936559843
#                 },
#                 {
#                     "name": "HIVE",
#                     "symbolSize": 16.667756703727928
#                 },
#                 {
#                     "name": "Pig",
#                     "symbolSize": 19.81425768476128
#                 },
#                 {
#                     "name": "R",
#                     "symbolSize": 77.98561151079136
#                 },
#                 {
#                     "name": "machine learning",
#                     "symbolSize": 73.11576193590582
#                 },
#                 {
#                     "name": "SAS",
#                     "symbolSize": 37.00327011118378
#                 },
#                 {
#                     "name": "MATLAB",
#                     "symbolSize": 18.924787442773056
#                 },
#                 {
#                     "name": "Python",
#                     "symbolSize": 100.0
#                 },
#                 {
#                     "name": "structured and unstructured data",
#                     "symbolSize": 17.479398299542183
#                 },
#                 {
#                     "name": "Big data technologies",
#                     "symbolSize": 15.066710268149118
#                 },
#                 {
#                     "name": "MapReduce",
#                     "symbolSize": 19.18051013734467
#                 },
#                 {
#                     "name": "Hive",
#                     "symbolSize": 28.56442119032047
#                 },
#                 {
#                     "name": "AI",
#                     "symbolSize": 30.109875735775017
#                 },
#                 {
#                     "name": "Artificial Intelligence",
#                     "symbolSize": 20.637017658600392
#                 },
#                 {
#                     "name": "Machine Learning",
#                     "symbolSize": 40.91693917593198
#                 },
#                 {
#                     "name": "Tableau",
#                     "symbolSize": 38.23741007194245
#                 },
#                 {
#                     "name": "data visualization",
#                     "symbolSize": 26.91890124264225
#                 },
#                 {
#                     "name": "Power BI",
#                     "symbolSize": 18.402223675604972
#                 },
#                 {
#                     "name": "SQL",
#                     "symbolSize": 70.96991497710923
#                 },
#                 {
#                     "name": "programming skills",
#                     "symbolSize": 17.93525179856115
#                 },
#                 {
#                     "name": "programming languages",
#                     "symbolSize": 22.604970568999345
#                 },
#                 {
#                     "name": "scripting languages",
#                     "symbolSize": 18.16873773708306
#                 },
#                 {
#                     "name": "ML",
#                     "symbolSize": 23.583387835186397
#                 },
#                 {
#                     "name": "Machine learning",
#                     "symbolSize": 17.334859385219097
#                 },
#                 {
#                     "name": "big data technologies",
#                     "symbolSize": 17.868541530412035
#                 },
#                 {
#                     "name": "data mining",
#                     "symbolSize": 39.58273381294964
#                 },
#                 {
#                     "name": "programming language",
#                     "symbolSize": 18.502289077828646
#                 },
#                 {
#                     "name": "Big Data",
#                     "symbolSize": 21.115107913669064
#                 },
#                 {
#                     "name": "Kafka",
#                     "symbolSize": 19.2916939175932
#                 },
#                 {
#                     "name": "NoSQL",
#                     "symbolSize": 19.669718770438195
#                 },
#                 {
#                     "name": "databases",
#                     "symbolSize": 19.836494440810988
#                 },
#                 {
#                     "name": "ETL",
#                     "symbolSize": 20.759319816873774
#                 },
#                 {
#                     "name": "pandas",
#                     "symbolSize": 18.680183126226293
#                 },
#                 {
#                     "name": "scikit-learn",
#                     "symbolSize": 19.469587965990844
#                 },
#                 {
#                     "name": "NLP",
#                     "symbolSize": 26.45192936559843
#                 },
#                 {
#                     "name": "natural language processing",
#                     "symbolSize": 22.50490516677567
#                 },
#                 {
#                     "name": "Development",
#                     "symbolSize": 15.789404839764552
#                 },
#                 {
#                     "name": "Java",
#                     "symbolSize": 39.249182472204055
