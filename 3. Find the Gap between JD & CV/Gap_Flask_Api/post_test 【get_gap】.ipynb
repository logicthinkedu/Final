# %% [markdown]
# # get_gap

# %%
import requests,json
from pprint import pprint

url='http://0.0.0.0:6001/gap'
res = requests.post(url, data= 
                    json.dumps(
                                {"cv":{"cv_id": "7612907945528279464",
                                 "cv_desc": '''
                                 Data Science,"Skills * Programming Languages: Python (pandas, numpy, scipy, scikit-learn, matplotlib), Sql, Java, JavaScript/JQuery. * Machine learning: Regression, SVM, NaÃ¯ve Bayes, KNN, Random Forest, Decision Trees, Boosting techniques, Cluster Analysis, Word Embedding, Sentiment Analysis, Natural Language processing, Dimensionality reduction, Topic Modelling (LDA, NMF), PCA & Neural Nets. * Database Visualizations: Mysql, SqlServer, Cassandra, Hbase, ElasticSearch D3.js, DC.js, Plotly, kibana, matplotlib, ggplot, Tableau. * Others: Regular Expression, HTML, CSS, Angular 6, Logstash, Kafka, Python Flask, Git, Docker, computer vision - Open CV and understanding of Deep learning.Education Details 
                                 '''}, 
                                
                                 
                                 "jd":{
                                "jd_type": "Web Developer",
                                "jd_desc": 
                                     '''
                                     IT SKILLS Languages : C ( Basic ) , JAVA ( Basic ) Web Technologies : HTML5 , CSS3 , Bootstrap , JavaScript , jQuery , Corel Draw , Photoshop , Illustrator Databases : MySQL5.0 IDE & Tools : Sublime Text , Notepad Operating Systems : Windows XP , Windows 7Education Details September 2015 Bachelor of Engineer Information technology Nagpur , Maharashtra Nagpur University May 2011 HSC Secondary & Higher Secondary State Board of Secondary June 2009 SSC Secondary & Higher Secondary Maharashtra State Board of SecondaryWeb and Graphics DesignerWeb and Graphics Designer - Virtuous Media Point , PuneSkill Details BOOTSTRAP- Exprience - 24 months HTML5- Exprience - 24 months JAVASCRIPT- Exprience - 24 months jQuery- Exprience - 24 months COREL DRAW- Exprience - 24 months Adobe Photoshop- Exprience - 24 months Adobe Illustrator- Exprience - 12 months CSS3- Exprience - 24 monthsCompany Details company - Virtuous Media Point description - company - CNC Web World description - Internship Program : At e - sense IT Solution pvt.ltd . Nagpur as a Web Designing and Developement . * Presented in Project Competition in Innovesta 15 of Priyadarshini Indira Gandhi College of Engineering , Nagpur . * Presented in National Level Paper Presentation in TECH - WAVE 2015 of S.R.M.C.E. , Nagpur . company - e - sense IT Solution pvt.ltd description - Key Result Areas : * Designed websites solutions by studying information needs , conferring with users , and studying systems flow , data usage , and work processes . * Understood process requirements and provided use cases for business , functional & technical requirements . * Interacted with users for requirement gathering , prepared functional specifications and low - level design documents . * Participated in the Software Development Life cycle ( SDLC ) and Agile methodology right from requirement analysis , * Performed detailed design of modules along with their implementation , and documentation integrated software modules Developed by other team members . Highlights : * Developed various modules as per customer requirement and identified and fixed number of bugs related to code , Database connectivity , UI Defects and so on . * Analyzed and modified existing codes to incorporate a number of changes in the application / user requirements , wrote new codes as required . * Coded , implemented and integrated complex programs using technologies such as HTML5 , CSS3 , JavaScript , jQuery , bootstrap . * Having good command on Graphics designing with effective ideas . PROJECTS * www.nitka.com , Nagpur united corporation ( admin ) , Mintmetrix.com , Tagline videos ( admin ) , Smartbadge ( admin ) : - In all projects I have used technologies like HTML5 , CSS3 , Bootstrap , JavaScript , jQuery and text editor as sublime text . * www.shreekiaspack.co.in , www.3staragroproducts.com , www.luckystationery.co.in : - used technologies like HTML5 , CSS3 , Bootstrap , javascript and text editor as notepad++ . * Design various Logos , Brochures , Advertising Banners , Visiting Cards , Pamphlet , Hoardings etc . B.E. FINAL YEAR PROJECT * Major Project : - Title : WEB BASED DISEASE DIAGNOSIS EXPERT SYSTEM . Duration : 1 Year Description : In this project we provide a website in which doctor gives online consultation for particular disease . System gives better suggestions for any health problems . * Mini Project Development- * SHOPPING MANAGEMENT SYSTEM Developed in C++ . CURRICULUM & EXTRA CURRICULUM ACTIVITIES company - FACE - IT description - Co - ordinator in project competition .                                     '''    ,                                  
                                     "jd_id": "313663"
                                        }
                                }
                    )
)

print(res)
pprint( eval(res.text) )
# Out:
# <Response [200]>
# {'docGap': {'cvHtml': '<html>\n'
#                       '                                  <span '
#                       "style='background:yellow'>Data </span><span "
#                       'style=\'background:yellow\'>Science,"Skills </span>* '
#                       'Programming Languages : Python ( pandas , numpy , scipy '
#                       ', scikit - learn , <span '
#                       "style='background:yellow'>matplotlib </span>) , <span "
#                       "style='background:yellow'>Sql </span>, <span "
#                       "style='background:yellow'>Java </span>, <span "
#                       "style='background:yellow'>JavaScript </span><span "
#                       "style='background:yellow'>/ </span><span "
#                       "style='background:yellow'>JQuery </span>. * Machine "
#                       'learning : Regression , SVM , <span '
#                       "style='background:yellow'>NaÃ¯ve </span><span "
#                       "style='background:yellow'>Bayes </span>, <span "
#                       "style='background:yellow'>KNN </span>, <span "
#                       "style='background:yellow'>Random </span><span "
#                       "style='background:yellow'>Forest </span>, <span "
#                       "style='background:yellow'>Decision </span><span "
#                       "style='background:yellow'>Trees </span>, Boosting "
#                       'techniques , Cluster Analysis , <span '
#                       "style='background:yellow'>Word </span><span "
#                       "style='background:yellow'>Embedding </span>, <span "
#                       "style='background:yellow'>Sentiment </span><span "
#                       "style='background:yellow'>Analysis </span>, <span "
#                       "style='background:yellow'>Natural </span>Language "
#                       "processing <span style='background:yellow'>, "
#                       "</span><span style='background:yellow'>Dimensionality "
#                       '</span>reduction , <span '
#                       "style='background:yellow'>Topic </span><span "
#                       "style='background:yellow'>Modelling </span>( <span "
#                       "style='background:yellow'>LDA </span>, <span "
#                       "style='background:yellow'>NMF </span>) , PCA & Neural "
#                       'Nets . * Database Visualizations : <span '
#                       "style='background:yellow'>Mysql </span>, <span "
#                       "style='background:yellow'>SqlServer </span>, <span "
#                       "style='background:yellow'>Cassandra </span>, Hbase , "
#                       'ElasticSearch D3.js , <span '
#                       "style='background:yellow'>DC.js </span>, Plotly , "
#                       'kibana , matplotlib , ggplot , Tableau . * Others : '
#                       'Regular Expression , HTML , <span '
#                       "style='background:yellow'>CSS </span>, Angular 6 , "
#                       "Logstash , <span style='background:yellow'>Kafka "
#                       "</span>, <span style='background:yellow'>Python "
#                       "</span><span style='background:yellow'>Flask </span>, "
#                       "<span style='background:yellow'>Git </span>, <span "
#                       "style='background:yellow'>Docker </span>, computer "
#                       'vision - Open CV and understanding of Deep learning . '
#                       'Education Details \n'
#                       '                                  </html>',
#             'gapTerms': ['corel',
#                          'languages',
#                          'world',
#                          'visiting',
#                          'text',
#                          'secondary',
#                          'c++',
#                          'technologies',
#                          'xp',
#                          'tagline',
#                          'html5',
#                          'ide',
#                          'bootstrap',
#                          'notepad',
#                          'systems',
#                          'sublime',
#                          'draw',
#                          'photoshop',
#                          'skills',
#                          'videos',
#                          'css3',
#                          'tools',
#                          'basic',
#                          'illustrator',
#                          'mintmetrix.com',
#                          'web',
#                          'c',
#                          'operating',
#                          '7education',
#                          'details',
#                          'windows',
#                          'it',
#                          'mysql5.0'],
#             'jd': {'jd_desc': '\n'
#                               '                                     IT SKILLS '
#                               'Languages : C ( Basic ) , JAVA ( Basic ) Web '
#                               'Technologies : HTML5 , CSS3 , Bootstrap , '
#                               'JavaScript , jQuery , Corel Draw , Photoshop , '
#                               'Illustrator Databases : MySQL5.0 IDE & Tools : '
#                               'Sublime Text , Notepad Operating Systems : '
#                               'Windows XP , Windows 7Education Details '
#                               'September 2015 Bachelor of Engineer Information '
#                               'technology Nagpur , Maharashtra Nagpur '
#                               'University May 2011 HSC Secondary & Higher '
#                               'Secondary State Board of Secondary June 2009 '
#                               'SSC Secondary & Higher Secondary Maharashtra '
#                               'State Board of SecondaryWeb and Graphics '
#                               'DesignerWeb and Graphics Designer - Virtuous '
#                               'Media Point , PuneSkill Details BOOTSTRAP- '
#                               'Exprience - 24 months HTML5- Exprience - 24 '
#                               'months JAVASCRIPT- Exprience - 24 months '
#                               'jQuery- Exprience - 24 months COREL DRAW- '
#                               'Exprience - 24 months Adobe Photoshop- '
#                               'Exprience - 24 months Adobe Illustrator- '
#                               'Exprience - 12 months CSS3- Exprience - 24 '
#                               'monthsCompany Details company - Virtuous Media '
#                               'Point description - company - CNC Web World '
#                               'description - Internship Program : At e - sense '
#                               'IT Solution pvt.ltd . Nagpur as a Web Designing '
#                               'and Developement . * Presented in Project '
#                               'Competition in Innovesta 15 of Priyadarshini '
#                               'Indira Gandhi College of Engineering , Nagpur . '
#                               '* Presented in National Level Paper '
#                               'Presentation in TECH - WAVE 2015 of S.R.M.C.E. '
#                               ', Nagpur . company - e - sense IT Solution '
#                               'pvt.ltd description - Key Result Areas : * '
#                               'Designed websites solutions by studying '
#                               'information needs , conferring with users , and '
#                               'studying systems flow , data usage , and work '
#                               'processes . * Understood process requirements '
#                               'and provided use cases for business , '
#                               'functional & technical requirements . * '
#                               'Interacted with users for requirement gathering '
#                               ', prepared functional specifications and low - '
#                               'level design documents . * Participated in the '
#                               'Software Development Life cycle ( SDLC ) and '
#                               'Agile methodology right from requirement '
#                               'analysis , * Performed detailed design of '
#                               'modules along with their implementation , and '
#                               'documentation integrated software modules '
#                               'Developed by other team members . Highlights : '
#                               '* Developed various modules as per customer '
#                               'requirement and identified and fixed number of '
#                               'bugs related to code , Database connectivity , '
#                               'UI Defects and so on . * Analyzed and modified '
#                               'existing codes to incorporate a number of '
#                               'changes in the application / user requirements '
#                               ', wrote new codes as required . * Coded , '
#                               'implemented and integrated complex programs '
#                               'using technologies such as HTML5 , CSS3 , '
#                               'JavaScript , jQuery , bootstrap . * Having good '
#                               'command on Graphics designing with effective '
#                               'ideas . PROJECTS * www.nitka.com , Nagpur '
#                               'united corporation ( admin ) , Mintmetrix.com , '
#                               'Tagline videos ( admin ) , Smartbadge ( admin ) '
#                               ': - In all projects I have used technologies '
#                               'like HTML5 , CSS3 , Bootstrap , JavaScript , '
#                               'jQuery and text editor as sublime text . * '
#                               'www.shreekiaspack.co.in , '
#                               'www.3staragroproducts.com , '
#                               'www.luckystationery.co.in : - used technologies '
#                               'like HTML5 , CSS3 , Bootstrap , javascript and '
#                               'text editor as notepad++ . * Design various '
#                               'Logos , Brochures , Advertising Banners , '
#                               'Visiting Cards , Pamphlet , Hoardings etc . '
#                               'B.E. FINAL YEAR PROJECT * Major Project : - '
#                               'Title : WEB BASED DISEASE DIAGNOSIS EXPERT '
#                               'SYSTEM . Duration : 1 Year Description : In '
#                               'this project we provide a website in which '
#                               'doctor gives online consultation for particular '
#                               'disease . System gives better suggestions for '
#                               'any health problems . * Mini Project '
#                               'Development- * SHOPPING MANAGEMENT SYSTEM '
#                               'Developed in C++ . CURRICULUM & EXTRA '
#                               'CURRICULUM ACTIVITIES company - FACE - IT '
#                               'description - Co - ordinator in project '
#                               'competition '
#                               '.                                     ',
#                    'jd_id': '313663',
#                    'jd_type': 'Web Developer',
#                    'terms': ['corel',
#                              'languages',
#                              'world',
#                              'visiting',
#                              'text',
#                              'secondary',
#                              'c++',
#                              'technologies',
#                              'xp',
#                              'tagline',
#                              'html5',
#                              'ide',
#                              'bootstrap',
#                              'notepad',
#                              'jquery',
#                              'javascript',
#                              'systems',
#                              'sublime',
#                              'draw',
#                              'photoshop',
#                              'skills',
#                              'videos',
#                              'java',
#                              'css3',
#                              'tools',
#                              'basic',
#                              'illustrator',
#                              'mintmetrix.com',
#                              'web',
#                              'c',
#                              'operating',
#                              '7education',
#                              'details',
#                              'windows',
#                              'it',
#                              'mysql5.0']},
#             'jdHtml': '<html>\n'
#                       '                                      <span '
#                       "style='background:red'>IT </span><span "
#                       "style='background:red'>SKILLS </span><span "
#                       "style='background:red'>Languages </span>: <span "
#                       "style='background:red'>C </span>( <span "
#                       "style='background:red'>Basic </span>) , <span "
#                       "style='background:yellow'>JAVA </span>( <span "
#                       "style='background:red'>Basic </span>) <span "
#                       "style='background:red'>Web </span><span "
#                       "style='background:red'>Technologies </span>: <span "
#                       "style='background:red'>HTML5 </span>, <span "
#                       "style='background:red'>CSS3 </span>, <span "
#                       "style='background:red'>Bootstrap </span>, <span "
#                       "style='background:yellow'>JavaScript </span>, <span "
#                       "style='background:yellow'>jQuery </span>, <span "
#                       "style='background:red'>Corel </span><span "
#                       "style='background:red'>Draw </span>, <span "
#                       "style='background:red'>Photoshop </span>, <span "
#                       "style='background:red'>Illustrator </span>Databases : "
#                       "<span style='background:red'>MySQL5.0 </span><span "
#                       "style='background:red'>IDE </span>& <span "
#                       "style='background:red'>Tools </span>: <span "
#                       "style='background:red'>Sublime </span><span "
#                       "style='background:red'>Text </span>, <span "
#                       "style='background:red'>Notepad </span><span "
#                       "style='background:red'>Operating </span><span "
#                       "style='background:red'>Systems </span>: <span "
#                       "style='background:red'>Windows </span><span "
#                       "style='background:red'>XP </span>, <span "
#                       "style='background:red'>Windows </span><span "
#                       "style='background:red'>7Education </span><span "
#                       "style='background:red'>Details </span>September 2015 "
#                       'Bachelor of Engineer Information technology Nagpur , '
#                       'Maharashtra Nagpur University May 2011 HSC <span '
#                       "style='background:red'>Secondary </span>& Higher "
#                       'Secondary State Board of Secondary June 2009 SSC '
#                       'Secondary & Higher Secondary Maharashtra State Board of '
#                       'SecondaryWeb and Graphics DesignerWeb and Graphics '
#                       'Designer - Virtuous Media Point , PuneSkill Details '
#                       'BOOTSTRAP- Exprience - 24 months HTML5- Exprience - 24 '
#                       'months JAVASCRIPT- Exprience - 24 months jQuery- '
#                       'Exprience - 24 months COREL DRAW- Exprience - 24 months '
#                       'Adobe Photoshop- Exprience - 24 months Adobe '
#                       'Illustrator- Exprience - 12 months CSS3- Exprience - 24 '
#                       'monthsCompany Details company - Virtuous Media Point '
#                       'description - company - CNC <span '
#                       "style='background:red'>Web </span><span "
#                       "style='background:red'>World </span>description - "
#                       'Internship Program : At e - sense IT Solution pvt.ltd . '
#                       'Nagpur as a Web Designing and Developement . * '
#                       'Presented in Project Competition in Innovesta 15 of '
#                       'Priyadarshini Indira Gandhi College of Engineering , '
#                       'Nagpur . * Presented in National Level Paper '
#                       'Presentation in TECH - WAVE 2015 of S.R.M.C.E. , Nagpur '
#                       '. company - e - sense IT Solution pvt.ltd description - '
#                       'Key Result Areas : * Designed websites solutions by '
#                       'studying information needs , conferring with users , '
#                       'and studying systems flow , data usage , and work '
#                       'processes . * Understood process requirements and '
#                       'provided use cases for business , functional & '
#                       'technical requirements . * Interacted with users for '
#                       'requirement gathering , prepared functional '
#                       'specifications and low - level design documents . * '
#                       'Participated in the Software Development Life cycle ( '
#                       'SDLC ) and Agile methodology right from requirement '
#                       'analysis , * Performed detailed design of modules along '
#                       'with their implementation , and documentation '
#                       'integrated software modules Developed by other team '
#                       'members . Highlights : * Developed various modules as '
#                       'per customer requirement and identified and fixed '
#                       'number of bugs related to code , Database connectivity '
#                       ', UI Defects and so on . * Analyzed and modified '
#                       'existing codes to incorporate a number of changes in '
#                       'the application / user requirements , wrote new codes '
#                       'as required . * Coded , implemented and integrated '
#                       'complex programs using technologies such as HTML5 , '
#                       "<span style='background:red'>CSS3 </span>, <span "
#                       "style='background:yellow'>JavaScript </span>, <span "
#                       "style='background:yellow'>jQuery </span>, <span "
#                       "style='background:red'>bootstrap </span>. * Having good "
#                       'command on Graphics designing with effective ideas . '
#                       'PROJECTS * www.nitka.com , Nagpur united corporation ( '
#                       "admin ) , <span style='background:red'>Mintmetrix.com "
#                       "</span>, <span style='background:red'>Tagline "
#                       "</span><span style='background:red'>videos </span>( "
#                       'admin ) , Smartbadge ( admin ) : - In all projects I '
#                       'have used technologies like <span '
#                       "style='background:red'>HTML5 </span>, <span "
#                       "style='background:red'>CSS3 </span>, <span "
#                       "style='background:red'>Bootstrap </span>, <span "
#                       "style='background:yellow'>JavaScript </span>, <span "
#                       "style='background:yellow'>jQuery </span>and text editor "
#                       'as sublime text . * www.shreekiaspack.co.in , '
#                       'www.3staragroproducts.com , www.luckystationery.co.in : '
#                       '- used technologies like HTML5 , <span '
#                       "style='background:red'>CSS3 </span>, <span "
#                       "style='background:red'>Bootstrap </span>, <span "
#                       "style='background:yellow'>javascript </span>and text "
#                       'editor as notepad++ . * Design various Logos , '
#                       'Brochures , Advertising Banners , <span '
#                       "style='background:red'>Visiting </span>Cards , Pamphlet "
#                       ', Hoardings etc . B.E. FINAL YEAR PROJECT * Major '
#                       'Project : - Title : WEB BASED DISEASE DIAGNOSIS EXPERT '
#                       'SYSTEM . Duration : 1 Year Description : In this '
#                       'project we provide a website in which doctor gives '
#                       'online consultation for particular disease . System '
#                       'gives better suggestions for any health problems . * '
#                       'Mini Project Development- * SHOPPING MANAGEMENT SYSTEM '
#                       "Developed in <span style='background:red'>C++ </span>. "
#                       'CURRICULUM & EXTRA CURRICULUM ACTIVITIES company - FACE '
#                       '- IT description - Co - ordinator in project '
#                       'competition .                                      '
#                       '</html>'},
#  'termedCv': {'cv_desc': '\n'
#                          '                                 Data '
#                          'Science,"Skills * Programming Languages: Python '
#                          '(pandas, numpy, scipy, scikit-learn, matplotlib), '
#                          'Sql, Java, JavaScript/JQuery. * Machine learning: '
#                          'Regression, SVM, NaÃ¯ve Bayes, KNN, Random Forest, '
#                          'Decision Trees, Boosting techniques, Cluster '
#                          'Analysis, Word Embedding, Sentiment Analysis, '
#                          'Natural Language processing, Dimensionality '
#                          'reduction, Topic Modelling (LDA, NMF), PCA & Neural '
#                          'Nets. * Database Visualizations: Mysql, SqlServer, '
#                          'Cassandra, Hbase, ElasticSearch D3.js, DC.js, '
#                          'Plotly, kibana, matplotlib, ggplot, Tableau. * '
#                          'Others: Regular Expression, HTML, CSS, Angular 6, '
#                          'Logstash, Kafka, Python Flask, Git, Docker, computer '
#                          'vision - Open CV and understanding of Deep '
#                          'learning.Education Details \n'
#                          '                                 ',
#               'cv_id': '7612907945528279464',
#               'terms': ['data',
#                         'topic',
#                         'modelling',
#                         'cassandra',
#                         'science,"skills',
#                         'lda',
#                         'git',
#                         'python',
#                         'analysis',
#                         'trees',
#                         'sqlserver',
#                         'dc.js',
#                         'knn',
#                         'natural',
#                         'jquery',
#                         'javascript',
#                         'embedding',
#                         'flask',
#                         '/',
#                         'word',
#                         'random',
#                         'dimensionality',
#                         'docker',
#                         'bayes',
#                         'kafka',
#                         'matplotlib',
#                         'java',
#                         'sentiment',
#                         'forest',
#                         'mysql',
#                         'css',
#                         'decision',
#                         ',',
#                         'nmf',
#                         'sql',
#                         'naã¯ve']}}

# %%
from IPython.core.display import display, HTML
display(HTML( eval(res.text)['docGap']['cvHtml']  ))
# Out:
# <html>
#                                   <span style='background:yellow'>Data </span><span style='background:yellow'>Science,"Skills </span>* Programming Languages : Python ( pandas , numpy , scipy , scikit - learn , <span style='background:yellow'>matplotlib </span>) , <span style='background:yellow'>Sql </span>, <span style='background:yellow'>Java </span>, <span style='background:yellow'>JavaScript </span><span style='background:yellow'>/ </span><span style='background:yellow'>JQuery </span>. * Machine learning : Regression , SVM , <span style='background:yellow'>NaÃ¯ve </span><span style='background:yellow'>Bayes </span>, <span style='background:yellow'>KNN </span>, <span style='background:yellow'>Random </span><span style='background:yellow'>Forest </span>, <span style='background:yellow'>Decision </span><span style='background:yellow'>Trees </span>, Boosting techniques , Cluster Analysis , <span style='background:yellow'>Word </span><span style='background:yellow'>Embedding </span>, <span style='background:yellow'>Sentiment </span><span style='background:yellow'>Analysis </span>, <span style='background:yellow'>Natural </span>Language processing <span style='background:yellow'>, </span><span style='background:yellow'>Dimensionality </span>reduction , <span style='background:yellow'>Topic </span><span style='background:yellow'>Modelling </span>( <span style='background:yellow'>LDA </span>, <span style='background:yellow'>NMF </span>) , PCA & Neural Nets . * Database Visualizations : <span style='background:yellow'>Mysql </span>, <span style='background:yellow'>SqlServer </span>, <span style='background:yellow'>Cassandra </span>, Hbase , ElasticSearch D3.js , <span style='background:yellow'>DC.js </span>, Plotly , kibana , matplotlib , ggplot , Tableau . * Others : Regular Expression , HTML , <span style='background:yellow'>CSS </span>, Angular 6 , Logstash , <span style='background:yellow'>Kafka </span>, <span style='background:yellow'>Python </span><span style='background:yellow'>Flask </span>, <span style='background:yellow'>Git </span>, <span style='background:yellow'>Docker </span>, computer vision - Open CV and understanding of Deep learning . Education Details
#                                   </html>

# %%
from IPython.core.display import display, HTML
display(HTML( eval(res.text)['docGap']['jdHtml']  ))
# Out:
# <html>
#                                       <span style='background:red'>IT </span><span style='background:red'>SKILLS </span><span style='background:red'>Languages </span>: <span style='background:red'>C </span>( <span style='background:red'>Basic </span>) , <span style='background:yellow'>JAVA </span>( <span style='background:red'>Basic </span>) <span style='background:red'>Web </span><span style='background:red'>Technologies </span>: <span style='background:red'>HTML5 </span>, <span style='background:red'>CSS3 </span>, <span style='background:red'>Bootstrap </span>, <span style='background:yellow'>JavaScript </span>, <span style='background:yellow'>jQuery </span>, <span style='background:red'>Corel </span><span style='background:red'>Draw </span>, <span style='background:red'>Photoshop </span>, <span style='background:red'>Illustrator </span>Databases : <span style='background:red'>MySQL5.0 </span><span style='background:red'>IDE </span>& <span style='background:red'>Tools </span>: <span style='background:red'>Sublime </span><span style='background:red'>Text </span>, <span style='background:red'>Notepad </span><span style='background:red'>Operating </span><span style='background:red'>Systems </span>: <span style='background:red'>Windows </span><span style='background:red'>XP </span>, <span style='background:red'>Windows </span><span style='background:red'>7Education </span><span style='background:red'>Details </span>September 2015 Bachelor of Engineer Information technology Nagpur , Maharashtra Nagpur University May 2011 HSC <span style='background:red'>Secondary </span>& Higher Secondary State Board of Secondary June 2009 SSC Secondary & Higher Secondary Maharashtra State Board of SecondaryWeb and Graphics DesignerWeb and Graphics Designer - Virtuous Media Point , PuneSkill Details BOOTSTRAP- Exprience - 24 months HTML5- Exprience - 24 months JAVASCRIPT- Exprience - 24 months jQuery- Exprience - 24 months COREL DRAW- Exprience - 24 months Adobe Photoshop- Exprience - 24 months Adobe Illustrator- Exprience - 12 months CSS3- Exprience - 24 monthsCompany Details company - Virtuous Media Point description - company - CNC <span style='background:red'>Web </span><span style='background:red'>World </span>description - Internship Program : At e - sense IT Solution pvt.ltd . Nagpur as a Web Designing and Developement . * Presented in Project Competition in Innovesta 15 of Priyadarshini Indira Gandhi College of Engineering , Nagpur . * Presented in National Level Paper Presentation in TECH - WAVE 2015 of S.R.M.C.E. , Nagpur . company - e - sense IT Solution pvt.ltd description - Key Result Areas : * Designed websites solutions by studying information needs , conferring with users , and studying systems flow , data usage , and work processes . * Understood process requirements and provided use cases for business , functional & technical requirements . * Interacted with users for requirement gathering , prepared functional specifications and low - level design documents . * Participated in the Software Development Life cycle ( SDLC ) and Agile methodology right from requirement analysis , * Performed detailed design of modules along with their implementation , and documentation integrated software modules Developed by other team members . Highlights : * Developed various modules as per customer requirement and identified and fixed number of bugs related to code , Database connectivity , UI Defects and so on . * Analyzed and modified existing codes to incorporate a number of changes in the application / user requirements , wrote new codes as required . * Coded , implemented and integrated complex programs using technologies such as HTML5 , <span style='background:red'>CSS3 </span>, <span style='background:yellow'>JavaScript </span>, <span style='background:yellow'>jQuery </span>, <span style='background:red'>bootstrap </span>. * Having good command on Graphics designing with effective ideas . PROJECTS * www.nitka.com , Nagpur united corporat ...
