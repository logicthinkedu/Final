# %% [markdown]
# # predict cv

# %%
import requests,json
from pprint import pprint

url='http://127.0.0.1:6001/predict_cv'
res = requests.post(url, data= 
                    json.dumps({
            "cv_id": "7612907945528279464",
            "cv_desc": " IT SKILLS Languages : C ( Basic ) , JAVA ( Basic ) Web Technologies : HTML5 , CSS3 , Bootstrap , JavaScript , jQuery , Corel Draw , Photoshop , Illustrator Databases : MySQL5.0 IDE & Tools : Sublime Text , Notepad Operating Systems : Windows XP , Windows 7Education Details September 2015 Bachelor of Engineer Information technology Nagpur , Maharashtra Nagpur University May 2011 HSC Secondary & Higher Secondary State Board of Secondary June 2009 SSC Secondary & Higher Secondary Maharashtra State Board of SecondaryWeb and Graphics DesignerWeb and Graphics Designer - Virtuous Media Point , PuneSkill Details BOOTSTRAP- Exprience - 24 months HTML5- Exprience - 24 months JAVASCRIPT- Exprience - 24 months jQuery- Exprience - 24 months COREL DRAW- Exprience - 24 months Adobe Photoshop- Exprience - 24 months Adobe Illustrator- Exprience - 12 months CSS3- Exprience - 24 monthsCompany Details company - Virtuous Media Point description - company - CNC Web World description - Internship Program : At e - sense IT Solution pvt.ltd . Nagpur as a Web Designing and Developement . * Presented in Project Competition in Innovesta 15 of Priyadarshini Indira Gandhi College of Engineering , Nagpur . * Presented in National Level Paper Presentation in TECH - WAVE 2015 of S.R.M.C.E. , Nagpur . company - e - sense IT Solution pvt.ltd description - Key Result Areas : * Designed websites solutions by studying information needs , conferring with users , and studying systems flow , data usage , and work processes . * Understood process requirements and provided use cases for business , functional & technical requirements . * Interacted with users for requirement gathering , prepared functional specifications and low - level design documents . * Participated in the Software Development Life cycle ( SDLC ) and Agile methodology right from requirement analysis , * Performed detailed design of modules along with their implementation , and documentation integrated software modules Developed by other team members . Highlights : * Developed various modules as per customer requirement and identified and fixed number of bugs related to code , Database connectivity , UI Defects and so on . * Analyzed and modified existing codes to incorporate a number of changes in the application / user requirements , wrote new codes as required . * Coded , implemented and integrated complex programs using technologies such as HTML5 , CSS3 , JavaScript , jQuery , bootstrap . * Having good command on Graphics designing with effective ideas . PROJECTS * www.nitka.com , Nagpur united corporation ( admin ) , Mintmetrix.com , Tagline videos ( admin ) , Smartbadge ( admin ) : - In all projects I have used technologies like HTML5 , CSS3 , Bootstrap , JavaScript , jQuery and text editor as sublime text . * www.shreekiaspack.co.in , www.3staragroproducts.com , www.luckystationery.co.in : - used technologies like HTML5 , CSS3 , Bootstrap , javascript and text editor as notepad++ . * Design various Logos , Brochures , Advertising Banners , Visiting Cards , Pamphlet , Hoardings etc . B.E. FINAL YEAR PROJECT * Major Project : - Title : WEB BASED DISEASE DIAGNOSIS EXPERT SYSTEM . Duration : 1 Year Description : In this project we provide a website in which doctor gives online consultation for particular disease . System gives better suggestions for any health problems . * Mini Project Development- * SHOPPING MANAGEMENT SYSTEM Developed in C++ . CURRICULUM & EXTRA CURRICULUM ACTIVITIES company - FACE - IT description - Co - ordinator in project competition . "
        }
                    )
)

print(res)
pprint( eval(res.text) )
# Out:
# <Response [200]>
# {'results': [{'jd_desc': '<b>Job Classification: </b> Contract '
#                          '\\r\\n\\r\\nPosition: Senior Software Application & '
#                          'Integration Engineer\\nLocation: Washington, D.C. '
#                          '\\n\\nResponsibilities:\\n- Integrate Our client’s '
#                          'products with customer applications and third party '
#                          'software\\n- Design and implement Web-based '
#                          'applications of the Our client’s Discovery/Alert '
#                          'distributed software platform using a mixed language '
#                          'development environment\\n- Make changes to existing '
#                          'code and new code enhancements following developed '
#                          'software design and requirement specifications\\n- '
#                          'Serve as technical lead for software integrations '
#                          'efforts, mentoring other team members\\n- Analyze '
#                          'and design for large scale hardware architecture '
#                          'including storage and virtualization based on '
#                          'customer infrastructure\\n- Analyze and design '
#                          'security architecture based on customer '
#                          'infrastructure\\n- Team lead for various tasks among '
#                          'field and application/integration engineers '
#                          'including project management\\n- Interact with '
#                          'decision makers at customer sites for requirements, '
#                          'delivery, and progress\\n- Interact with various '
#                          'groups and users in customer sites to understand '
#                          'user needs and provide solutions using Our client’s '
#                          'products and services\\n\\nRequirements:\\n- BS or '
#                          'MS in Computer Science or equivalent\\n- 5+ years '
#                          'experience in Java development on distributed Web '
#                          'application environments\\n- Excellent written and '
#                          'verbal communication skills \\n- Experience '
#                          'architecting and managing solutions for hundreds of '
#                          'machines, storage, virtualization and cloud '
#                          'computing especially with a search engine '
#                          'infrastructure\\n- Development and integration '
#                          'experience with high performance search, analysis, '
#                          'indexing, and alerting software including open '
#                          'source software such as Lucene and Solr\\n- '
#                          'Experience architecting and implementing caching '
#                          'frameworks and Web application caching schemes\\n- '
#                          'Experience with analysis and diagnosis of '
#                          'large-scale infrastructure for networking and I/O '
#                          'bottlenecks\\n- Strong experience in J2EE and '
#                          'Internet technologies including Web Services, '
#                          'Enterprise Service Bus (ESB), SOA, REST, SOAP, AJAX, '
#                          'JMX, JMS, Java Servlets, Flex, Flash, HTML, XML, '
#                          'CSS, Javascript and other web-based frameworks (e.g. '
#                          'JQuery, DoJo, Stripes, Struts, YUI)\\n- Experience '
#                          'in understanding, designing and implementing '
#                          'security solutions inside and across secure networks '
#                          'including federated LDAP, PKI, Kerberos. . .\\n- '
#                          'Experience in Access Control (DAC), Role-Based '
#                          'Access Control (RBAC), AGDLP, Federated Identity '
#                          'Management\\n- Experience designing and implementing '
#                          'Java Security Technologies including Java '
#                          'Cryptography Extensions (JCE) Java Authentication '
#                          'and Authorization Service (JAAS), and Java Secure '
#                          'Socket Extension (JSSE)\\n- Experience using and '
#                          'implementing security standards such as eXtensible '
#                          'Access Control Markup Language (XACML), Security '
#                          'Assertion Markup Language (SAML), WS-Federation.\\n- '
#                          'Experience using and implementing single sign-on '
#                          'solutions\\n- Experience as team lead for '
#                          'integration and O&M\\n- Experience interacting with '
#                          'various user groups at customer sites to understand '
#                          'their requirements and provide relevant solutions by '
#                          'coordinating with core development\\n- Project '
#                          'management experience\\n- Experience integrating '
#                          'software packages into existing systems\\n- In-depth '
#                          'understanding of entire development process, '
#                          'including specification, documentation and quality '
#                          'assurance\\n- Knowledge of object design and '
#                          'analysis, socket programming, file I/O, '
#                          'multi-threaded code debugging\\n- Strong programming '
#                          'background in Windows, Linux and Solaris '
#                          'environment\\n- Knowledge of scripting languages '
#                          '(Perl, Python, Awk/Sed, Bash, etc.)\\n- Experience '
#                          'with multiple application servers (Tomcat, JBoss, '
#                          'WebLogic, WebSphere)\\n- Able to self-manage\\n- '
#                          'Willingness for some regional travel, possible '
#                          'national or international travel\\n- Database and '
#                          'SQL experience with systems such as Oracle, SQL '
#                          'Server, MySQL, Apache '
#                          'Derby\\n\\n\\t\\t\\t\\t\\t\\t\\r\\r\\r\\n\\t\\t\\t\\t\\t\\tJoin '
#                          'TEKsystems<sup>®</sup> and get your career on the '
#                          'fast track. As the leading technology staffing and '
#                          'services firm, we are passionate about deploying '
#                          'high-caliber IT and communications expertise. To '
#                          'satisfy our constant need for expertise, we actively '
#                          'seek talented Technical Professionals with all '
#                          'levels of information technology and communications '
#                          'skills. TEKsystems knows that every professional has '
#                          "different needs, so we'll work together to determine "
#                          'a suitable benefits package. We offer options to our '
#                          'Technical Professionals that could include: a health '
#                          'plan, 401k, provisions for vacation and holiday pay, '
#                          'and technical and professional training. With a '
#                          "foundation as the nation's largest IT staffing firm, "
#                          "we've become a billion-dollar services company by "
#                          'blending superior client service with an unrivaled '
#                          'ability to source and manage talent to precise '
#                          'specifications, resulting in successful technology '
#                          'executions. Allegis Group and its subsidiaries are '
#                          'equal opportunity employers. M/F/D/V',
#               'jd_id': '633224',
#               'jd_type': 'Java Developer'}],
#  'total_results': 1}

# %% [markdown]
# # find gap

# %%
import requests,json
from pprint import pprint

url='http://0.0.0.0:6001/gap'
res = requests.post(url, data= 
                    json.dumps(
                                {"cv":{"cv_id": "7612907945528279464",
                                 "cv_desc": '''
                                       IT SKILLS Languages : C ( Basic ) , JAVA ( Basic ) Web Technologies : HTML5 , CSS3 , Bootstrap , JavaScript , jQuery , Corel Draw , Photoshop , Illustrator Databases : MySQL5.0 IDE & Tools : Sublime Text , Notepad Operating Systems : Windows XP , Windows 7Education Details September 2015 Bachelor of Engineer Information technology Nagpur , Maharashtra Nagpur University May 2011 HSC Secondary & Higher Secondary State Board of Secondary June 2009 SSC Secondary & Higher Secondary Maharashtra State Board of SecondaryWeb and Graphics DesignerWeb and Graphics Designer - Virtuous Media Point , PuneSkill Details BOOTSTRAP- Exprience - 24 months HTML5- Exprience - 24 months JAVASCRIPT- Exprience - 24 months jQuery- Exprience - 24 months COREL DRAW- Exprience - 24 months Adobe Photoshop- Exprience - 24 months Adobe Illustrator- Exprience - 12 months CSS3- Exprience - 24 monthsCompany Details company - Virtuous Media Point description - company - CNC Web World description - Internship Program : At e - sense IT Solution pvt.ltd . Nagpur as a Web Designing and Developement . * Presented in Project Competition in Innovesta 15 of Priyadarshini Indira Gandhi College of Engineering , Nagpur . * Presented in National Level Paper Presentation in TECH - WAVE 2015 of S.R.M.C.E. , Nagpur . company - e - sense IT Solution pvt.ltd description - Key Result Areas : * Designed websites solutions by studying information needs , conferring with users , and studying systems flow , data usage , and work processes . * Understood process requirements and provided use cases for business , functional & technical requirements . * Interacted with users for requirement gathering , prepared functional specifications and low - level design documents . * Participated in the Software Development Life cycle ( SDLC ) and Agile methodology right from requirement analysis , * Performed detailed design of modules along with their implementation , and documentation integrated software modules Developed by other team members . Highlights : * Developed various modules as per customer requirement and identified and fixed number of bugs related to code , Database connectivity , UI Defects and so on . * Analyzed and modified existing codes to incorporate a number of changes in the application / user requirements , wrote new codes as required . * Coded , implemented and integrated complex programs using technologies such as HTML5 , CSS3 , JavaScript , jQuery , bootstrap . * Having good command on Graphics designing with effective ideas . PROJECTS * www.nitka.com , Nagpur united corporation ( admin ) , Mintmetrix.com , Tagline videos ( admin ) , Smartbadge ( admin ) : - In all projects I have used technologies like HTML5 , CSS3 , Bootstrap , JavaScript , jQuery and text editor as sublime text . * www.shreekiaspack.co.in , www.3staragroproducts.com , www.luckystationery.co.in : - used technologies like HTML5 , CSS3 , Bootstrap , javascript and text editor as notepad++ . * Design various Logos , Brochures , Advertising Banners , Visiting Cards , Pamphlet , Hoardings etc . B.E. FINAL YEAR PROJECT * Major Project : - Title : WEB BASED DISEASE DIAGNOSIS EXPERT SYSTEM . Duration : 1 Year Description : In this project we provide a website in which doctor gives online consultation for particular disease . System gives better suggestions for any health problems . * Mini Project Development- * SHOPPING MANAGEMENT SYSTEM Developed in C++ . CURRICULUM & EXTRA CURRICULUM ACTIVITIES company - FACE - IT description - Co - ordinator in project competition . 
                                       '''}, 
                                
                                 
                                 
                                 "jd":{
                                            "jd_type": "Maintenance Technician",
                                            "jd_desc": 
                                     '''
                                     Experience with analysis and diagnosis of large-scale infrastructure for networking and I/O bottlenecks\\n- Strong experience in J2EE and Internet technologies including Web Services, Enterprise Service Bus (ESB), SOA, REST, SOAP, AJAX, '
            JMX, JMS, Java Servlets, Flex, Flash, HTML, XML,CSS, Javascript and other web-based frameworks (e.g.)
            JQuery, DoJo, Stripes, Struts, YUI)\\n- Experience in understanding, designing and implementing security solutions inside and across secure networks including federated LDAP, PKI, Kerberos. . .'       
                                     
                                     '''    ,
                                     "jd_id": "313663"
                                        }
                                }
                    )
)

print(res)
pprint( eval(res.text) )
# Out:
# <Response [200]>
# {'docGap': {'cvHtml': '<html>\n'
#                       '                                        <span '
#                       "style='background:yellow'>IT </span><span "
#                       "style='background:yellow'>SKILLS </span><span "
#                       "style='background:yellow'>Languages </span>: <span "
#                       "style='background:yellow'>C </span>( <span "
#                       "style='background:yellow'>Basic </span>) , <span "
#                       "style='background:yellow'>JAVA </span>( <span "
#                       "style='background:yellow'>Basic </span>) <span "
#                       "style='background:yellow'>Web </span><span "
#                       "style='background:yellow'>Technologies </span>: <span "
#                       "style='background:yellow'>HTML5 </span>, <span "
#                       "style='background:yellow'>CSS3 </span>, <span "
#                       "style='background:yellow'>Bootstrap </span>, <span "
#                       "style='background:yellow'>JavaScript </span>, <span "
#                       "style='background:yellow'>jQuery </span>, <span "
#                       "style='background:yellow'>Corel </span><span "
#                       "style='background:yellow'>Draw </span>, <span "
#                       "style='background:yellow'>Photoshop </span>, <span "
#                       "style='background:yellow'>Illustrator </span>Databases "
#                       ": <span style='background:yellow'>MySQL5.0 </span><span "
#                       "style='background:yellow'>IDE </span>& <span "
#                       "style='background:yellow'>Tools </span>: <span "
#                       "style='background:yellow'>Sublime </span><span "
#                       "style='background:yellow'>Text </span>, <span "
#                       "style='background:yellow'>Notepad </span><span "
#                       "style='background:yellow'>Operating </span><span "
#                       "style='background:yellow'>Systems </span>: <span "
#                       "style='background:yellow'>Windows </span><span "
#                       "style='background:yellow'>XP </span>, <span "
#                       "style='background:yellow'>Windows </span><span "
#                       "style='background:yellow'>7Education </span><span "
#                       "style='background:yellow'>Details </span>September 2015 "
#                       'Bachelor of Engineer Information technology Nagpur , '
#                       'Maharashtra Nagpur University May 2011 HSC <span '
#                       "style='background:yellow'>Secondary </span>& Higher "
#                       'Secondary State Board of Secondary June 2009 SSC '
#                       'Secondary & Higher Secondary Maharashtra State Board of '
#                       'SecondaryWeb and Graphics DesignerWeb and Graphics '
#                       'Designer - Virtuous Media Point , PuneSkill Details '
#                       'BOOTSTRAP- Exprience - 24 months HTML5- Exprience - 24 '
#                       'months JAVASCRIPT- Exprience - 24 months jQuery- '
#                       'Exprience - 24 months COREL DRAW- Exprience - 24 months '
#                       'Adobe Photoshop- Exprience - 24 months Adobe '
#                       'Illustrator- Exprience - 12 months CSS3- Exprience - 24 '
#                       'monthsCompany Details company - Virtuous Media Point '
#                       'description - company - CNC <span '
#                       "style='background:yellow'>Web </span><span "
#                       "style='background:yellow'>World </span>description - "
#                       'Internship Program : At e - sense IT Solution pvt.ltd . '
#                       'Nagpur as a Web Designing and Developement . * '
#                       'Presented in Project Competition in Innovesta 15 of '
#                       'Priyadarshini Indira Gandhi College of Engineering , '
#                       'Nagpur . * Presented in National Level Paper '
#                       'Presentation in TECH - WAVE 2015 of S.R.M.C.E. , Nagpur '
#                       '. company - e - sense IT Solution pvt.ltd description - '
#                       'Key Result Areas : * Designed websites solutions by '
#                       'studying information needs , conferring with users , '
#                       'and studying systems flow , data usage , and work '
#                       'processes . * Understood process requirements and '
#                       'provided use cases for business , functional & '
#                       'technical requirements . * Interacted with users for '
#                       'requirement gathering , prepared functional '
#                       'specifications and low - level design documents . * '
#                       'Participated in the Software Development Life cycle ( '
#                       'SDLC ) and Agile methodology right from requirement '
#                       'analysis , * Performed detailed design of modules along '
#                       'with their implementation , and documentation '
#                       'integrated software modules Developed by other team '
#                       'members . Highlights : * Developed various modules as '
#                       'per customer requirement and identified and fixed '
#                       'number of bugs related to code , Database connectivity '
#                       ', UI Defects and so on . * Analyzed and modified '
#                       'existing codes to incorporate a number of changes in '
#                       'the application / user requirements , wrote new codes '
#                       'as required . * Coded , implemented and integrated '
#                       'complex programs using technologies such as HTML5 , '
#                       "<span style='background:yellow'>CSS3 </span>, <span "
#                       "style='background:yellow'>JavaScript </span>, <span "
#                       "style='background:yellow'>jQuery </span>, <span "
#                       "style='background:yellow'>bootstrap </span>. * Having "
#                       'good command on Graphics designing with effective ideas '
#                       '. PROJECTS * www.nitka.com , Nagpur united corporation '
#                       '( admin ) , <span '
#                       "style='background:yellow'>Mintmetrix.com </span>, <span "
#                       "style='background:yellow'>Tagline </span><span "
#                       "style='background:yellow'>videos </span>( admin ) , "
#                       'Smartbadge ( admin ) : - In all projects I have used '
#                       "technologies like <span style='background:yellow'>HTML5 "
#                       "</span>, <span style='background:yellow'>CSS3 </span>, "
#                       "<span style='background:yellow'>Bootstrap </span>, "
#                       "<span style='background:yellow'>JavaScript </span>, "
#                       "<span style='background:yellow'>jQuery </span>and text "
#                       'editor as sublime text . * www.shreekiaspack.co.in , '
#                       'www.3staragroproducts.com , www.luckystationery.co.in : '
#                       '- used technologies like HTML5 , <span '
#                       "style='background:yellow'>CSS3 </span>, <span "
#                       "style='background:yellow'>Bootstrap </span>, <span "
#                       "style='background:yellow'>javascript </span>and text "
#                       'editor as notepad++ . * Design various Logos , '
#                       'Brochures , Advertising Banners , <span '
#                       "style='background:yellow'>Visiting </span>Cards , "
#                       'Pamphlet , Hoardings etc . B.E. FINAL YEAR PROJECT * '
#                       'Major Project : - Title : WEB BASED DISEASE DIAGNOSIS '
#                       'EXPERT SYSTEM . Duration : 1 Year Description : In this '
#                       'project we provide a website in which doctor gives '
#                       'online consultation for particular disease . System '
#                       'gives better suggestions for any health problems . * '
#                       'Mini Project Development- * SHOPPING MANAGEMENT SYSTEM '
#                       "Developed in <span style='background:yellow'>C++ "
#                       '</span>. CURRICULUM & EXTRA CURRICULUM ACTIVITIES '
#                       'company - FACE - IT description - Co - ordinator in '
#                       'project competition . \n'
#                       '                                        </html>',
#             'gapTerms': ['SOAP',
#                          'analysis',
#                          'REST',
#                          'JMS',
#                          'XML',
#                          'JQuery',
#                          'Stripes',
#                          'AJAX',
#                          "'",
#                          'DoJo',
#                          'Struts',
#                          'Java',
#                          'and',
#                          'JMX',
#                          'networking',
#                          'diagnosis'],
#             'jd': {'jd_desc': '\n'
#                               '                                     Experience '
#                               'with analysis and diagnosis of large-scale '
#                               'infrastructure for networking and I/O '
#                               'bottlenecks\\n- Strong experience in J2EE and '
#                               'Internet technologies including Web Services, '
#                               'Enterprise Service Bus (ESB), SOA, REST, SOAP, '
#                               "AJAX, '\n"
#                               '            JMX, JMS, Java Servlets, Flex, '
#                               'Flash, HTML, XML,CSS, Javascript and other '
#                               'web-based frameworks (e.g.)\n'
#                               '            JQuery, DoJo, Stripes, Struts, '
#                               'YUI)\\n- Experience in understanding, designing '
#                               'and implementing security solutions inside and '
#                               'across secure networks including federated '
#                               "LDAP, PKI, Kerberos. . .'       \n"
#                               '                                     \n'
#                               '                                     ',
#                    'jd_id': '313663',
#                    'jd_type': 'Maintenance Technician',
#                    'terms': ['SOAP',
#                              'analysis',
#                              'HTML',
#                              'REST',
#                              'JMS',
#                              'XML',
#                              'JQuery',
#                              'Stripes',
#                              'AJAX',
#                              "'",
#                              'DoJo',
#                              'Struts',
#                              'Java',
#                              'and',
#                              'JMX',
#                              'networking',
#                              'diagnosis',
#                              'CSS']},
#             'jdHtml': '<html>\n'
#                       '                                      Experience with '
#                       "<span style='background:yellow'>analysis </span><span "
#                       "style='background:yellow'>and </span><span "
#                       "style='background:yellow'>diagnosis </span>of large - "
#                       'scale infrastructure for <span '
#                       "style='background:yellow'>networking </span>and I / O "
#                       '<br/>bottlenecks\\n- Strong experience in J2EE and '
#                       'Internet technologies including Web Services , '
#                       'Enterprise Service Bus ( ESB ) , SOA , <span '
#                       "style='background:yellow'>REST </span>, <span "
#                       "style='background:yellow'>SOAP </span>, <span "
#                       "style='background:yellow'>AJAX </span>, <span "
#                       "style='background:yellow'>' </span>\n"
#                       "             <span style='background:yellow'>JMX "
#                       "</span>, <span style='background:yellow'>JMS </span>, "
#                       "<span style='background:yellow'>Java </span>Servlets , "
#                       "Flex , Flash , <span style='background:yellow'>HTML "
#                       "</span>, <span style='background:yellow'>XML </span>, "
#                       "<span style='background:yellow'>CSS </span>, Javascript "
#                       'and other web - based frameworks ( e.g. ) \n'
#                       "             <span style='background:yellow'>JQuery "
#                       "</span>, <span style='background:yellow'>DoJo </span>, "
#                       "<span style='background:yellow'>Stripes </span>, <span "
#                       "style='background:yellow'>Struts </span>, <br/>YUI)\\n- "
#                       'Experience in understanding , designing and '
#                       'implementing security solutions inside and across '
#                       'secure networks including federated LDAP , PKI , '
#                       "Kerberos . . . '       \n"
#                       '                                     \n'
#                       '                                      </html>'},
#  'termedCv': {'cv_desc': '\n'
#                          '                                       IT SKILLS '
#                          'Languages : C ( Basic ) , JAVA ( Basic ) Web '
#                          'Technologies : HTML5 , CSS3 , Bootstrap , JavaScript '
#                          ', jQuery , Corel Draw , Photoshop , Illustrator '
#                          'Databases : MySQL5.0 IDE & Tools : Sublime Text , '
#                          'Notepad Operating Systems : Windows XP , Windows '
#                          '7Education Details September 2015 Bachelor of '
#                          'Engineer Information technology Nagpur , Maharashtra '
#                          'Nagpur University May 2011 HSC Secondary & Higher '
#                          'Secondary State Board of Secondary June 2009 SSC '
#                          'Secondary & Higher Secondary Maharashtra State Board '
#                          'of SecondaryWeb and Graphics DesignerWeb and '
#                          'Graphics Designer - Virtuous Media Point , PuneSkill '
#                          'Details BOOTSTRAP- Exprience - 24 months HTML5- '
#                          'Exprience - 24 months JAVASCRIPT- Exprience - 24 '
#                          'months jQuery- Exprience - 24 months COREL DRAW- '
#                          'Exprience - 24 months Adobe Photoshop- Exprience - '
#                          '24 months Adobe Illustrator- Exprience - 12 months '
#                          'CSS3- Exprience - 24 monthsCompany Details company - '
#                          'Virtuous Media Point description - company - CNC Web '
#                          'World description - Internship Program : At e - '
#                          'sense IT Solution pvt.ltd . Nagpur as a Web '
#                          'Designing and Developement . * Presented in Project '
#                          'Competition in Innovesta 15 of Priyadarshini Indira '
#                          'Gandhi College of Engineering , Nagpur . * Presented '
#                          'in National Level Paper Presentation in TECH - WAVE '
#                          '2015 of S.R.M.C.E. , Nagpur . company - e - sense IT '
#                          'Solution pvt.ltd description - Key Result Areas : * '
#                          'Designed websites solutions by studying information '
#                          'needs , conferring with users , and studying systems '
#                          'flow , data usage , and work processes . * '
#                          'Understood process requirements and provided use '
#                          'cases for business , functional & technical '
#                          'requirements . * Interacted with users for '
#                          'requirement gathering , prepared functional '
#                          'specifications and low - level design documents . * '
#                          'Participated in the Software Development Life cycle '
#                          '( SDLC ) and Agile methodology right from '
#                          'requirement analysis , * Performed detailed design '
#                          'of modules along with their implementation , and '
#                          'documentation integrated software modules Developed '
#                          'by other team members . Highlights : * Developed '
#                          'various modules as per customer requirement and '
#                          'identified and fixed number of bugs related to code '
#                          ', Database connectivity , UI Defects and so on . * '
#                          'Analyzed and modified existing codes to incorporate '
#                          'a number of changes in the application / user '
#                          'requirements , wrote new codes as required . * Coded '
#                          ', implemented and integrated complex programs using '
#                          'technologies such as HTML5 , CSS3 , JavaScript , '
#                          'jQuery , bootstrap . * Having good command on '
#                          'Graphics designing with effective ideas . PROJECTS * '
#                          'www.nitka.com , Nagpur united corporation ( admin ) '
#                          ', Mintmetrix.com , Tagline videos ( admin ) , '
#                          'Smartbadge ( admin ) : - In all projects I have used '
#                          'technologies like HTML5 , CSS3 , Bootstrap , '
#                          'JavaScript , jQuery and text editor as sublime text '
#                          '. * www.shreekiaspack.co.in , '
#                          'www.3staragroproducts.com , '
#                          'www.luckystationery.co.in : - used technologies like '
#                          'HTML5 , CSS3 , Bootstrap , javascript and text '
#                          'editor as notepad++ . * Design various Logos , '
#                          'Brochures , Advertising Banners , Visiting Cards , '
#                          'Pamphlet , Hoardings etc . B.E. FINAL YEAR PROJECT * '
#                          'Major Project : - Title : WEB BASED DISEASE '
#                          'DIAGNOSIS EXPERT SYSTEM . Duration : 1 Year '
#                          'Description : In this project we provide a website '
#                          'in which doctor gives online consultation for '
#                          'particular disease . System gives better suggestions '
#                          'for any health problems . * Mini Project '
#                          'Development- * SHOPPING MANAGEMENT SYSTEM Developed '
#                          'in C++ . CURRICULUM & EXTRA CURRICULUM ACTIVITIES '
#                          'company - FACE - IT description - Co - ordinator in '
#                          'project competition . \n'
#                          '                                       ',
#               'cv_id': '7612907945528279464',
#               'terms': ['jQuery',
#                         'Sublime',
#                         'Photoshop',
#                         'JAVA',
#                         'Operating',
#                         'Secondary',
#                         'Technologies',
#                         'World',
#                         'MySQL5.0',
#                         'Windows',
#                         'C++',
#                         'Visiting',
#                         'videos',
#                         'Corel',
#                         'IDE',
#                         'Tools',
#                         'Tagline',
#                         'Basic',
#                         'Systems',
#                         'IT',
#                         'Notepad',
#                         'Bootstrap',
#                         'CSS3',
#                         'C',
#                         'SKILLS',
#                         'JavaScript',
#                         'Draw',
#                         'javascript',
#                         'XP',
#                         'HTML5',
#                         'Languages',
#                         'Mintmetrix.com',
#                         'Illustrator',
#                         'Details',
#                         'Text',
#                         '7Education',
#                         'bootstrap',
#                         'Web']}}

# %%
from IPython.core.display import display, HTML
display(HTML( eval(res.text)['docGap']['jdHtml']  ))
# Out:
# <html>
#                                       Experience with <span style='background:yellow'>analysis </span><span style='background:yellow'>and </span><span style='background:yellow'>diagnosis </span>of large - scale infrastructure for <span style='background:yellow'>networking </span>and I / O <br/>bottlenecks\n- Strong experience in J2EE and Internet technologies including Web Services , Enterprise Service Bus ( ESB ) , SOA , <span style='background:yellow'>REST </span>, <span style='background:yellow'>SOAP </span>, <span style='background:yellow'>AJAX </span>, <span style='background:yellow'>' </span>
#              <span style='background:yellow'>JMX </span>, <span style='background:yellow'>JMS </span>, <span style='background:yellow'>Java </span>Servlets , Flex , Flash , <span style='background:yellow'>HTML </span>, <span style='background:yellow'>XML </span>, <span style='background:yellow'>CSS </span>, Javascript and other web - based frameworks ( e.g. )
#              <span style='background:yellow'>JQuery </span>, <span style='background:yellow'>DoJo </span>, <span style='background:yellow'>Stripes </span>, <span style='background:yellow'>Struts </span>, <br/>YUI)\n- Experience in understanding , designing and implementing security solutions inside and across secure networks including federated LDAP , PKI , Kerberos . . . '
#
#                                       </html>

# %%
from IPython.core.display import display, HTML
display(HTML( eval(res.text)['docGap']['cvHtml']  ))
# Out:
# <html>
#                                         <span style='background:yellow'>IT </span><span style='background:yellow'>SKILLS </span><span style='background:yellow'>Languages </span>: <span style='background:yellow'>C </span>( <span style='background:yellow'>Basic </span>) , <span style='background:yellow'>JAVA </span>( <span style='background:yellow'>Basic </span>) <span style='background:yellow'>Web </span><span style='background:yellow'>Technologies </span>: <span style='background:yellow'>HTML5 </span>, <span style='background:yellow'>CSS3 </span>, <span style='background:yellow'>Bootstrap </span>, <span style='background:yellow'>JavaScript </span>, <span style='background:yellow'>jQuery </span>, <span style='background:yellow'>Corel </span><span style='background:yellow'>Draw </span>, <span style='background:yellow'>Photoshop </span>, <span style='background:yellow'>Illustrator </span>Databases : <span style='background:yellow'>MySQL5.0 </span><span style='background:yellow'>IDE </span>& <span style='background:yellow'>Tools </span>: <span style='background:yellow'>Sublime </span><span style='background:yellow'>Text </span>, <span style='background:yellow'>Notepad </span><span style='background:yellow'>Operating </span><span style='background:yellow'>Systems </span>: <span style='background:yellow'>Windows </span><span style='background:yellow'>XP </span>, <span style='background:yellow'>Windows </span><span style='background:yellow'>7Education </span><span style='background:yellow'>Details </span>September 2015 Bachelor of Engineer Information technology Nagpur , Maharashtra Nagpur University May 2011 HSC <span style='background:yellow'>Secondary </span>& Higher Secondary State Board of Secondary June 2009 SSC Secondary & Higher Secondary Maharashtra State Board of SecondaryWeb and Graphics DesignerWeb and Graphics Designer - Virtuous Media Point , PuneSkill Details BOOTSTRAP- Exprience - 24 months HTML5- Exprience - 24 months JAVASCRIPT- Exprience - 24 months jQuery- Exprience - 24 months COREL DRAW- Exprience - 24 months Adobe Photoshop- Exprience - 24 months Adobe Illustrator- Exprience - 12 months CSS3- Exprience - 24 monthsCompany Details company - Virtuous Media Point description - company - CNC <span style='background:yellow'>Web </span><span style='background:yellow'>World </span>description - Internship Program : At e - sense IT Solution pvt.ltd . Nagpur as a Web Designing and Developement . * Presented in Project Competition in Innovesta 15 of Priyadarshini Indira Gandhi College of Engineering , Nagpur . * Presented in National Level Paper Presentation in TECH - WAVE 2015 of S.R.M.C.E. , Nagpur . company - e - sense IT Solution pvt.ltd description - Key Result Areas : * Designed websites solutions by studying information needs , conferring with users , and studying systems flow , data usage , and work processes . * Understood process requirements and provided use cases for business , functional & technical requirements . * Interacted with users for requirement gathering , prepared functional specifications and low - level design documents . * Participated in the Software Development Life cycle ( SDLC ) and Agile methodology right from requirement analysis , * Performed detailed design of modules along with their implementation , and documentation integrated software modules Developed by other team members . Highlights : * Developed various modules as per customer requirement and identified and fixed number of bugs related to code , Database connectivity , UI Defects and so on . * Analyzed and modified existing codes to incorporate a number of changes in the application / user requirements , wrote new codes as required . * Coded , implemented and integrated complex programs using technologies such as HTML5 , <span style='background:yellow'>CSS3 </span>, <span style='background:yellow'>JavaScript </span>, <span style='background:yellow'>jQuery </span>, <span style='background:yellow'>bootstrap </span>. * Having good c ...
#                                         </html>

# %%
res.text
# Out:
# '{"docGap": {"jdHtml": "<html>\\n             Experience with analysis and diagnosis of large - scale infrastructure for networking and I / O <br/>bottlenecks\\\\n- Strong experience in J2EE and Internet technologies including Web Services , Enterprise Service Bus ( ESB ) , SOA , REST , SOAP , AJAX , \' \\n             JMX , JMS , Java Servlets , Flex , Flash , HTML , <span style=\'background:yellow\'>XML </span>, <span style=\'background:yellow\'>CSS </span>, Javascript and other web - based frameworks ( e.g. ) \\n             <span style=\'background:yellow\'>JQuery </span>, DoJo , Stripes , Struts , <br/>YUI)\\\\n- Experience in understanding , designing and implementing security solutions inside and across secure networks including federated LDAP , PKI , Kerberos . . . \'       \\n         </html>", "cvHtml": "<html>\\n             IT SKILLS Languages : <span style=\'background:yellow\'>C </span>( Basic ) , <span style=\'background:yellow\'>JAVA </span>( Basic ) Web Technologies : <span style=\'background:yellow\'>HTML5 </span>, <span style=\'background:yellow\'>CSS3 </span>, <span style=\'background:yellow\'>Bootstrap </span>, <span style=\'background:yellow\'>JavaScript </span>, jQuery , Corel Draw , Photoshop , Illustrator Databases : MySQL5.0 IDE & Tools : Sublime Text , Notepad Operating Systems : <span style=\'background:yellow\'>Windows </span>XP , Windows 7Education Details September 2015 Bachelor of Engineer Information technology Nagpur , Maharashtra Nagpur University May 2011 HSC Secondary & Higher Secondary State Board of Secondary June 2009 SSC Secondary & Higher Secondary Maharashtra State Board of SecondaryWeb and Graphics DesignerWeb and Graphics Designer - Virtuous Media Point , PuneSkill Details BOOTSTRAP- Exprience - 24 months HTML5- Exprience - 24 months JAVASCRIPT- Exprience - 24 months jQuery- Exprience - 24 months COREL DRAW- Exprience - 24 months Adobe Photoshop- Exprience - 24 months Adobe Illustrator- Exprience - 12 months CSS3- Exprience - 24 monthsCompany Details company - Virtuous Media Point description - company - CNC Web World description - Internship Program : At e - sense IT Solution pvt.ltd . Nagpur as a Web Designing and Developement . * Presented in Project Competition in Innovesta 15 of Priyadarshini Indira Gandhi College of Engineering , Nagpur . * Presented in National Level Paper Presentation in TECH - WAVE 2015 of S.R.M.C.E. , Nagpur . company - e - sense IT Solution pvt.ltd description - Key Result Areas : * Designed websites solutions by studying information needs , conferring with users , and studying systems flow , data usage , and work processes . * Understood process requirements and provided use cases for business , functional & technical requirements . * Interacted with users for requirement gathering , prepared functional specifications and low - level design documents . * Participated in the Software Development Life cycle ( SDLC ) and Agile methodology right from requirement analysis , * Performed detailed design of modules along with their implementation , and documentation integrated software modules Developed by other team members . Highlights : * Developed various modules as per customer requirement and identified and fixed number of bugs related to code , Database connectivity , UI Defects and so on . * Analyzed and modified existing codes to incorporate a number of changes in the application / user requirements , wrote new codes as required . * Coded , implemented and integrated complex programs using technologies such as <span style=\'background:yellow\'>HTML5 </span>, <span style=\'background:yellow\'>CSS3 </span>, <span style=\'background:yellow\'>JavaScript </span>, jQuery , bootstrap . * Having good command on Graphics designing with effective ideas . PROJECTS * www.nitka.com , Nagpur united corporation ( admin ) , Mintmetrix.com , Tagline videos ( admin ) , Smartbadge ( admin ) : - In all projects I have used technologies like HTML5 , CSS3 , <span style=\'bac ...

# %%
from IPython.core.display import display, HTML
display(HTML( eval(res.text)['docGap']['cvHtml']  ))

# %%
display(HTML( eval(res.text)['docGap']['cvHtml']  ))
# Out:
# <html>
#              IT SKILLS Languages : <span style='background:yellow'>C </span>( Basic ) , <span style='background:yellow'>JAVA </span>( Basic ) Web Technologies : <span style='background:yellow'>HTML5 </span>, <span style='background:yellow'>CSS3 </span>, <span style='background:yellow'>Bootstrap </span>, <span style='background:yellow'>JavaScript </span>, jQuery , Corel Draw , Photoshop , Illustrator Databases : MySQL5.0 IDE & Tools : Sublime Text , Notepad Operating Systems : <span style='background:yellow'>Windows </span>XP , Windows 7Education Details September 2015 Bachelor of Engineer Information technology Nagpur , Maharashtra Nagpur University May 2011 HSC Secondary & Higher Secondary State Board of Secondary June 2009 SSC Secondary & Higher Secondary Maharashtra State Board of SecondaryWeb and Graphics DesignerWeb and Graphics Designer - Virtuous Media Point , PuneSkill Details BOOTSTRAP- Exprience - 24 months HTML5- Exprience - 24 months JAVASCRIPT- Exprience - 24 months jQuery- Exprience - 24 months COREL DRAW- Exprience - 24 months Adobe Photoshop- Exprience - 24 months Adobe Illustrator- Exprience - 12 months CSS3- Exprience - 24 monthsCompany Details company - Virtuous Media Point description - company - CNC Web World description - Internship Program : At e - sense IT Solution pvt.ltd . Nagpur as a Web Designing and Developement . * Presented in Project Competition in Innovesta 15 of Priyadarshini Indira Gandhi College of Engineering , Nagpur . * Presented in National Level Paper Presentation in TECH - WAVE 2015 of S.R.M.C.E. , Nagpur . company - e - sense IT Solution pvt.ltd description - Key Result Areas : * Designed websites solutions by studying information needs , conferring with users , and studying systems flow , data usage , and work processes . * Understood process requirements and provided use cases for business , functional & technical requirements . * Interacted with users for requirement gathering , prepared functional specifications and low - level design documents . * Participated in the Software Development Life cycle ( SDLC ) and Agile methodology right from requirement analysis , * Performed detailed design of modules along with their implementation , and documentation integrated software modules Developed by other team members . Highlights : * Developed various modules as per customer requirement and identified and fixed number of bugs related to code , Database connectivity , UI Defects and so on . * Analyzed and modified existing codes to incorporate a number of changes in the application / user requirements , wrote new codes as required . * Coded , implemented and integrated complex programs using technologies such as <span style='background:yellow'>HTML5 </span>, <span style='background:yellow'>CSS3 </span>, <span style='background:yellow'>JavaScript </span>, jQuery , bootstrap . * Having good command on Graphics designing with effective ideas . PROJECTS * www.nitka.com , Nagpur united corporation ( admin ) , Mintmetrix.com , Tagline videos ( admin ) , Smartbadge ( admin ) : - In all projects I have used technologies like HTML5 , CSS3 , <span style='background:yellow'>Bootstrap </span>, <span style='background:yellow'>JavaScript </span>, jQuery and text editor as sublime text . * www.shreekiaspack.co.in , www.3staragroproducts.com , www.luckystationery.co.in : - used technologies like HTML5 , CSS3 , <span style='background:yellow'>Bootstrap </span>, <span style='background:yellow'>javascript </span>and text editor as <span style='background:yellow'>notepad++ </span>. * Design various Logos , Brochures , Advertising Banners , Visiting Cards , Pamphlet , Hoardings etc . B.E. FINAL YEAR PROJECT * Major Project : - Title : WEB BASED DISEASE DIAGNOSIS EXPERT SYSTEM . Duration : 1 Year Description : In this project we provide a website in which doctor gives online consultation for particular disease . System gives better suggestions for any health problems . * Mini Project Development- * SHOPPING M ...
#          </html>
